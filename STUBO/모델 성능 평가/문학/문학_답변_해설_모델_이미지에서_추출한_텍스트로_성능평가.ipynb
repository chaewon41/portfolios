# %% [markdown]
# # **0. 패키지 설치**

# %%
# !pip install openai
# !pip install langchain
# !pip install -U langchain-community
# !pip install pypdf
# !pip install faiss-cpu
# !pip install tiktoken
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.96.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.26)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.69)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.4.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Collecting langchain-community
#   Downloading langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.69)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (8.5.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.4.6)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 41.3 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 4.0 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.5 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.1 langchain-community-0.3.27 marshmallow-3.26.1 mypy-extensions-1.1.0 pydantic-settings-2.10.1 python-dotenv-1.1.1 typing-inspect-0.9.0
# Collecting pypdf
#   Downloading pypdf-5.8.0-py3-none-any.whl.metadata (7.1 kB)
# Downloading pypdf-5.8.0-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.7/309.7 kB 9.1 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-5.8.0
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 76.0 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0.post1
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (0.9.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2025.7.14)

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings

# %% [markdown]
# # **0. 구글 드라이브 마운트 & api key**

# %%
from google.colab import drive
drive.mount('/content/drive')

import glob
import os
# Out:
# Mounted at /content/drive

# %%
import os
import openai
from langchain.chat_models import ChatOpenAI

#  API 키 설정
OPENAI_API_KEY = ""
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
client = openai.OpenAI(api_key=OPENAI_API_KEY)
openai.api_key = OPENAI_API_KEY

# %% [markdown]
# # **1. 문서 업로드 & Retriever**

# %%
import os
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders import UnstructuredPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings
from langchain.retrievers import ContextualCompressionRetriever, EnsembleRetriever
from langchain.retrievers.document_compressors import LLMChainExtractor

# 1. 📥 PDF 로딩 (하위 폴더 포함) + 출처 추적
def load_all_pdfs(root_dir):
    all_docs = []
    for dirpath, _, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.endswith(".pdf"):
                full_path = os.path.join(dirpath, filename)
                loader = UnstructuredPDFLoader(full_path)
                docs = loader.load()

                for doc in docs:
                    # 📎 source: 상대 경로 기준으로 저장 (예: RAG/작품A.pdf)
                    relative_path = os.path.relpath(full_path, root_dir)
                    doc.metadata["source"] = relative_path
                    doc.page_content = doc.page_content.strip().replace("\n", " ").replace("  ", " ")

                all_docs.extend(docs)
    return all_docs

# 2. 텍스트 분할기
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=100,
    separators=["\n\n", "\n", ".", " ", ""]
)

# 3. 임베딩
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# 4. 배치 임베딩
def embed_in_batches(docs, batch_size=100):
    vectorstore = None
    for i in range(0, len(docs), batch_size):
        batch = docs[i:i + batch_size]
        print(f"🔄 Embedding batch {i} ~ {i + len(batch)} / {len(docs)}")
        if vectorstore is None:
            vectorstore = FAISS.from_documents(batch, embedding=embeddings)
        else:
            vectorstore.add_documents(batch)
    return vectorstore

# 5. 저장 경로
VECTORSTORE_PATH = "/content/drive/MyDrive/Colab Notebooks/TAVE 프로젝트_STUBO/문학/faiss_index_답변해설"

# 6. 벡터스토어 생성 또는 로딩
def build_vectorstore():
    root_dir = "/content/drive/MyDrive/Colab Notebooks/TAVE 프로젝트_STUBO/문학/data/RAG"
    all_docs = load_all_pdfs(root_dir)
    split_docs = text_splitter.split_documents(all_docs)
    vectorstore = embed_in_batches(split_docs)
    vectorstore.save_local(VECTORSTORE_PATH)
    return vectorstore

# 7. 리트리버 생성
def get_retriever():
    if os.path.exists(VECTORSTORE_PATH):
        print("📁 기존 벡터스토어 불러오는 중...")
        vectorstore = FAISS.load_local(VECTORSTORE_PATH, embeddings, allow_dangerous_deserialization=True)
    else:
        print("🧠 새 벡터스토어 생성 중...")
        vectorstore = build_vectorstore()

    retriever = vectorstore.as_retriever(
        search_type="mmr",
        search_kwargs={
            "k": 5,
            "score_threshold": 0.5
        }
    )
    return retriever

# 🔄 최종 retriever
retriever = get_retriever()
# Out:
# /tmp/ipython-input-5-2237303118.py:37: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
# 📁 기존 벡터스토어 불러오는 중...

# %% [markdown]
# # **2. 개념 답변 QA chain**

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.3)

# 개념 설명 체인
concept_prompt = ChatPromptTemplate.from_template("""
너는 한국의 대학수학능력시험의 국어 과목 중 문학의 개념에 대해 설명해주는 튜터야. 아래 질문에 대해 간단명료하게 설명해줘.

질문:
{question}
""")

concept_chain = concept_prompt | llm | StrOutputParser()
# Out:
# /tmp/ipython-input-6-364772018.py:1: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.3)

# %% [markdown]
# # **3. 문제 답변&해설 QA 체인**
# - RAG를 활용해서 Retriever에서 찾은 문서 내용들을 prompt로 전달해서 참고하라고 llm에게 전달.
# - prompt <- 지문, 참고자료, 문제

# %%
# 문제 기반 QA RAG 체인
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain.chat_models import ChatOpenAI
from langchain_core.runnables import RunnableLambda

# LLM 설정
llm = ChatOpenAI(model="gpt-4o", temperature=0.3)

# 문제 기반 QA 체인용 프롬프트
qa_prompt = ChatPromptTemplate.from_template("""
당신은 한국 수능 국어 문학 전문 튜터입니다.

다음은 수능 국어 문학 객관식 문제입니다. ①, ②, ③, ④, ⑤ 중 하나를 고르는 객관식 문제이며,
정답은 반드시 지문 및 <보기>의 정확한 분석에 근거해 판단해야 합니다.

🟨 반드시 지켜야 할 분석 기준:

1. 지문 분석을 중심으로 판단하며, **선택지의 내용이 지문과 일치하는지** 엄밀히 검토하세요.
2. 문제에 <보기>가 있다면, <보기> 속 설명(구조, 시점, 표현, 인물 해석 등)을 **지문에 어떻게 적용했는지** 구체적으로 분석하세요.
3. **서술 방식, 인물 심리 표현, 문체, 시점 변화, 지시 표현, 병렬 구조** 등은 서술상·표현상 특징 문제에서 핵심 근거입니다.
4. 참고 자료는 반드시 보조적 용도로만 활용합니다. 절대 지문을 덮어쓰거나 대체해서는 안 됩니다.

📌 답변 형식:

[정답]
- (①, ②, ③, ④, ⑤ 중 하나)

[해설]
- 문제에서 요구한 핵심 요소(예: 표현 방식, 구조, 시점 등)에 따라 왜 정답인지 논리적으로 설명합니다.
- 지문 및 <보기>의 문장을 **직접 인용**하여 명확한 판단 근거를 제시하세요.
- 나머지 오답 선택지들은 각각 왜 틀렸는지를 간단히 설명하세요.

📖 [지문]
{context}

📚 [참고 자료] — 필요 시만 사용 (retriever 제공):
{reference}

🙋‍♂️ [문제 및 <보기>]
{question}
""")

def format_with_retrieved_docs(inputs):
    question = inputs["question"]
    context = inputs["context"]

    # 🔍 관련 문서 검색 (context와 question 모두 기준으로 검색)
    retrieved_docs = retriever.get_relevant_documents(f"{context}\n\n{question}")
    retrieved_context = "\n\n".join(doc.page_content for doc in retrieved_docs)

    return {
        "context": context,           # 지문 및 <보기>
        "reference": retrieved_context,  # 보조 자료
        "question": question
    }

# RAG QA 체인: 문항 지문 중심 + retriever 참고
rag_qa_chain = (
    RunnableLambda(format_with_retrieved_docs)
    | qa_prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# # **4. 문제 vs 개념 분류 함수**

# %%
def is_problem_question(question: str) -> bool:
    classification_prompt = ChatPromptTemplate.from_template("""
다음 질문이 문학 개념 질문인지, 지문 기반 문제인지 판별해줘. '개념' 또는 '문제' 중 하나로만 답해.

질문:
{question}
""")
    chain = classification_prompt | llm | StrOutputParser()
    result = chain.invoke({"question": question})
    return "문제" in result.strip()

# %% [markdown]
# # **5. 최종 질문 처리 함수**
# 문제 질문인지 개념 질문인지 분류 -> 개념 답변 / 문제 답변 해설

# %%
def tutor_response(question: str, passage: str = None):
    """
    문학 질문 또는 문항에 대한 응답을 처리합니다.

    Parameters:
    - question: 수험생 질문 또는 문학 개념 질문
    - passage: 선택적 입력. 문항 지문이 있는 경우 함께 제공
    """
    if is_problem_question(question):
        if not passage:
            print("❗ 오류: 문학 문제 풀이에는 지문(passage)이 필요합니다.")
            return

        print("📘 [문제에 대한 정답 및 해설]")

        # rag_qa_chain에 지문과 문제를 분리해서 입력
        response = rag_qa_chain.invoke({
            "context": passage,
            "question": question
        })
        print(response)

    else:
        print("📘 [문학 개념 설명]")
        response = concept_chain.invoke({"question": question})
        print(response)

# %% [markdown]
# # **6. 이미지(지문/문항)에서 텍스트 추출**
# - 지문 이미지에서 텍스트 추출할때 비용 문제 발생

# %% [markdown]
# ### **6.1 지문 텍스트 추출**
# 이미지 5등분 -> gpt-4o로 텍스트 추출 -> gpt-4o가 추출한 텍스트와 이미지를 비교하면 특수문자 삽입 -> gpt-4o가 특수문자 검토 -> gpt-4o가 지문 범위([A], [B] 등) 삽입

# %%
from PIL import Image
import openai
import base64
import io
from typing import List, Tuple

# ✅ 이미지 → base64
def image_to_base64(image: Image.Image) -> str:
    buffer = io.BytesIO()
    image.save(buffer, format="PNG")
    return f"data:image/png;base64,{base64.b64encode(buffer.getvalue()).decode()}"

# ✅ 이미지 수직 분할
def split_image_vertically(image: Image.Image, parts: int = 5) -> List[Image.Image]:
    width, height = image.size
    part_height = height // parts
    return [
        image.crop((0, i * part_height, width, height if i == parts - 1 else (i + 1) * part_height))
        for i in range(parts)
    ]

# ✅ GPT에게 OCR 시키는 함수
def gpt_ocr_text(image: Image.Image) -> str:
    base64_img = image_to_base64(image)

    system_prompt = """
    너는 수능 국어 문학의 지문 OCR 텍스트 추출 전문가야.

    아래 이미지를 보고 **OCR 텍스트를 그대로 추출**해.
    텍스트 추출만 하고, 절대 가공하거나 설명하지 마.

    📌 반드시 지킬 것:
    - 줄바꿈은 이미지에 보이는 그대로 살려야 해.
    - 띄어쓰기, 특수문자, 괄호, 마침표 등 모든 문장 부호도 그대로 유지해야 해.
    - 해석이나 부연 설명 없이 **순수한 OCR 결과만 출력**해야 해.
    """

    try:
        response = openai.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": system_prompt.strip()},
                {
                    "role": "user",
                    "content": [
                        {"type": "image_url", "image_url": {
                            "url": base64_img,
                            "detail": "high"
                        }}
                    ]
                }
            ],
            temperature=0,
            max_tokens=16000
        )
        output = response.choices[0].message.content.strip()
        if not output or "죄송하지만" in output:
            raise ValueError("GPT OCR 실패 또는 결과 없음")
        return output
    except Exception as e:
        return f"[❌ GPT OCR 실패]: {str(e)}"

# ✅ GPT-4o로 특수기호&괄호 삽입
def refine_text_with_gpt(image: Image.Image, ocr_output: str) -> str:
    base64_img = image_to_base64(image)

    system_prompt = """
    너는 수능 국어 문학 지문 정리 전문가야.

    다음은 OCR로 추출한 지문과 원본 이미지야. 너는 이 두 정보를 비교해서 다음과 같이 OCR 결과를 정확하게 수정해야 해.

    📌 반드시 지켜야 할 규칙:

    1. ✅ 이미지 안에서 특수기호(원형 문자/알파벳)를 정확히 식별하고, OCR 텍스트의 알맞은 위치에 삽입해야 해.
      - OCR 결과만 보면 안 돼. 반드시 이미지에서 특수기호 위치를 기준으로 판단해야 해.

    2. ✅ 삽입해야 할 특수기호는 다음과 같아:
      - 한글 원형 문자: ㉠, ㉡, ㉢, ㉣, ㉤
      - 원형 알파벳: ⓐ, ⓑ, ⓒ, ⓓ, ⓔ

    3. ✅ **모든 특수기호 뒤에는 밑줄로 강조된 문장이 반드시 있고**, 그 **강조된 문장 전체를 괄호 '( )'로 반드시 감싸야 해.**
      - 특수기호와 괄호는 붙여서 작성해: 예) ⓐ(강조된 문장)
      - 괄호는 해당 문장의 시작과 끝을 정확히 감싸야 하며, 줄바꿈이나 공백이 있어도 전체를 포함해야 해.

    4. ✅ 한 특수기호에 해당하는 강조 문장이 **여러 줄에 걸쳐 있더라도** 괄호로 정확히 감싸야 해.
      - 중간 줄바꿈이나 공백이 있더라도 강조 문장 전체가 괄호 안에 들어가야 해.

    5. ❌ 특수기호가 없는 문장은 수정하지 마.
      ❌ 철자 오류, 띄어쓰기 오류 등 OCR 자체 오류도 고치지 마.

    6. ✅ 출력은 반드시 지문 전체를 포함해야 하며, 특수기호 + 강조문장 부분만 수정해야 해.
      ❌ 설명, 해설, 추가 정보 없이 **지문 전체만 출력**해야 해.


     ⚠️ 반드시 특수기호 뒤에는 밑줄로 강조된 부분이 괄호'()'로 감싸져 있어야해.
     ⚠️ 특수기호 뒤에 괄호가 없다면 다시 밑줄로 강조된 부분을 다시 찾고 괄호를 추가해줘.
    """

    try:
        response = openai.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": system_prompt.strip()},
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": f"OCR 추출 결과:\n{ocr_output.strip()}"},
                        {"type": "image_url", "image_url": {
                            "url": base64_img,
                            "detail": "auto"
                        }}
                    ]
                }
            ],
            temperature=0.1,
            max_tokens=16000  # 가능한 최대값 사용
        )
        output = response.choices[0].message.content.strip()
        if not output or "죄송하지만" in output or "도와드릴 수 없습니다" in output:
            raise ValueError("GPT 응답 오류 또는 내용 없음")
        return output
    except Exception as e:
        return f"[❌ GPT 정교화 실패]: {str(e)}"

# %%
# ✅ 특수기호 위치 점검 및 보정 요청
def verify_special_symbols(original_image: Image.Image, restored_text: str) -> str:
    base64_img = image_to_base64(original_image)

    system_prompt = """
      너는 수능 국어 문학의 지문 OCR 복원 전문가야.

      다음은 OCR로 추출한 지문과 원본 이미지야. 너는 이 두 정보를 비교해서 다음과 같이 OCR 결과를 정확하게 수정해야 해.
      추출한 지문의 특수기호(㉠, ㉡, ㉢, ㉣, ㉤, ⓐ, ⓑ, ⓒ, ⓓ, ⓔ 등)가 원본 이미지의 특수기호와 다를 수 있어서 수정해줘.

      원본 이미지를 보고
      - 문장 앞 기호가 이미지와 정확히 일치하는지 확인하고,
      - 잘못된 기호는 올바른 특수기호로 수정해.
      - 이미지에는 특수기호가 없는데 텍스트에는 있는 경우는 특수기호를 삭제해줘.
      - **추출한 지문의 특수기호 뒤에 괄호'('가 없다면 이미지에서 밑줄로 강조된 부분을 찾아서 괄호로 감싸서 지문을 수정해줘.**

      ⚠️ ①, ②, ③, ④, ⑤ 이런 원형 숫자 특수기호는 지문에 있을 수 없어 반드시 다시 올바른 특수기호로 수정해줘.
      ⚠️ 동일한 특수기호가 또 나올 수 없어 다시 올바른 특수기호로 수정해줘.
      ⚠️ 반드시 특수기호 뒤에는 밑줄로 강조된 부분이 괄호'()'로 반드시 감싸져 있어야해.
      ⚠️ 추출한 지문의 특수기호 뒤에 괄호가 없다면 원본 이미지에서 특수기호 뒤에 다시 밑줄로 강조된 부분을 다시 찾고 지문 텍스트에 괄호'()'를 추가해줘.
      ⚠️ 이미지 기호 위치를 꼭 확인해 판단하고,
      ⚠️ 출력은 반드시 지문 전체를 출력해.
    """

    try:
        response = openai.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": system_prompt.strip()},
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": f"복원된 지문 일부:\n{restored_text.strip()}"},
                        {"type": "image_url", "image_url": {
                            "url": base64_img,
                            "detail": "high"
                        }}
                    ]
                }
            ],
            temperature=0.1,
            max_tokens=16000
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"[❌ GPT 기호 검토 실패]: {str(e)}"

# %%
# 이미지 우측 지문 범위 표시
def insert_passage_brackets_with_gpt(image: Image.Image, ocr_text: str) -> str:
    base64_img = image_to_base64(image)

    system_prompt = """
    너는 수능 국어 문학의 지문 OCR 복원 전문가야.

    다음은 OCR로 추출한 지문과 원본 이미지야.
    원본 이미지의 **좌측 혹은 우측에 [A], [B], [C] 등의 표시와 함께 특정 지문 범위를 나타내는 선들이 있는 경우가 있어.**
    이 시각적 정보는 어떤 지문 구간이 문제 풀이에서 중요한지를 알려주는 단서야.

    🔍 너의 임무는 다음과 같아:

    1. 지문 이미지의 맨 왼쪽과 맨 오른쪽을 잘 살펴보고,
      특정 지문 범위를 나타내는 선과 함께 [A], [B], [C] 등이 지문 내 **어디서부터 어디까지를 가리키는지** 판단해.
        - 각 범위는 반드시 **1줄 이상**이 되도록 하고, **문장이 끊기지 않게 자연스럽게 포함**해야 해.
        - 문장의 시작이나 끝이 잘리지 않도록, 지문 흐름에 맞게 해당 **시작 줄과 끝 줄 전체를 포함**해야 해.

    2. 만약 특정 지문 범위를 나타내는 선이 있다면, 판단된 범위를 지문 중 그대로 유지하되 아래 예시처럼 `[A]{}`로 감싸 강조해줘:
        ...
        [A] {
            (해당 범위 시작 줄)
            ...
            (해당 범위 끝 줄)
        }
        ...

    ⚠️ 유의사항:
    - 줄 단위로 판단하되, 의미 단위(문장 구조)를 최대한 유지해야 해.
    - 특정 지문 범위의 시작과 끝 위치는 이미지 오른쪽의 선과 시각적으로 정렬된 지문 줄을 찾아 판단해야 해.
    - 줄바꿈, 공백, 괄호, 특수기호 등은 OCR 텍스트 스타일을 그대로 유지해.
    """

    try:
        response = openai.chat.completions.create(
            model="gpt-4o",
            messages=[
                {"role": "system", "content": system_prompt.strip()},
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": f"OCR 결과:\n{ocr_text.strip()}"},
                        {"type": "image_url", "image_url": {
                            "url": base64_img,
                            "detail": "high"
                        }}
                    ]
                }
            ],
            temperature=0.1,
            max_tokens=16000
        )
        return response.choices[0].message.content.strip()
    except Exception as e:
        return f"[❌ GPT 지문 범위 삽입 실패]: {str(e)}"

# %%
import os
from PIL import Image

def run_split_pipeline(image_path: str, parts: int = 4):
    print("📂 이미지 로딩 중...")
    image = Image.open(image_path)

    # 1. 이미지 수직 분할
    print(f"🔀 이미지 {parts}등분 중...")
    split_images = split_image_vertically(image, parts=parts)

    # 2. 각 분할 이미지 OCR
    ocr_parts = []
    for idx, part_img in enumerate(split_images):
        print(f"🔍 [{idx + 1}/{parts}] 분할 이미지 OCR 중...")
        part_text = gpt_ocr_text(part_img)
        ocr_parts.append(part_text)

    # 3. OCR 결과 병합
    combined_ocr = "\n".join(ocr_parts).strip()

    # 4. GPT로 정교화(특수기호&괄호 삽입)
    print("🔧 GPT 정교화 단계 진행 중...")
    refined_text = refine_text_with_gpt(image, combined_ocr)

    # 5. 특수기호 위치 검토 및 보정 => 성공
    print("🧠 특수기호 위치 검토 및 보정 중...")
    symbol_corrected_text = verify_special_symbols(image, refined_text)

    # 6. 이미지 우측 지문 범위 표시
    print("🗂️ GPT 지문 범위 표시([A], [B] 등) 삽입 중...")
    final_result = insert_passage_brackets_with_gpt(image, symbol_corrected_text)

    return final_result.strip()

# %% [markdown]
# ### **6.2 문제 텍스트 추출**

# %%
def extract_question(question_path):
    import mimetypes

    # 파일 확장자에 맞게 MIME 타입 추정
    mime_type, _ = mimetypes.guess_type(question_path)
    if not mime_type:
        mime_type = "image/png"  # 기본값 fallback

    with open(question_path, "rb") as f:
        base64_img = base64.b64encode(f.read()).decode("utf-8")

    image_url = f"data:{mime_type};base64,{base64_img}"

    system_prompt = """
    너는 수능 국어 문학 문제 이미지를 텍스트로 정확하게 복원하는 OCR 모델이야.
    입력 이미지를 보고 **문제의 텍스트를 최대한 원문 그대로 추출**해야 해.

    입력 이미지에는 다음이 포함될 수 있어:
    - 문학 문제의 질문 문장
    - ①~⑤ 보기 선택지
    - 경우에 따라, 질문 문장 **뒤에** 제시되는 '<보기>' 문장

    🔹 반드시 지켜야 할 출력 규칙:

    1. 이미지에 '<보기>'가 존재하면, 질문 문장 **뒤에** <보기> 전체 내용을 정확히 포함해야 해.
    2. <보기>가 없다면, 질문 문장 다음에 바로 선택지를 출력해.
    3. 선택지는 항상 ①~⑤ 모두 빠짐없이 출력할 것.
    4. 출력 형식은 아래와 같아야 해:

    (질문 문장)

    <보기>
    (보기 내용)

    ① ...
    ② ...
    ③ ...
    ④ ...
    ⑤ ...

    ❗주의:
    - <보기>가 있다면 반드시 포함하고, **질문 뒤에 위치**시켜야 해.
    - 줄바꿈, 기호, 문장부호 등은 최대한 원문 그대로 복원해.
    - 절대 설명, 해설, 시스템 메시지 등 **추가 텍스트는 포함하지 마**.
    - 오직 이미지 속 문제 텍스트만 출력해.
    """

    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": system_prompt.strip()},
            {
                "role": "user",
                "content": [
                    {
                        "type": "image_url",
                        "image_url": {
                            "url": image_url
                        }
                    }
                ]
            }
        ],
        max_tokens=1500,
        temperature=0.1
    )

    return response.choices[0].message.content.strip()

# %% [markdown]
# # **<이미지에서 추출한 텍스트로 테스트>**
# - 2025학년도(2024년 시행) 6월, 9월 수능 테스트

# %%
import os
import re

# 🔹 정답 키
answer_key = {
    "2024-06-국어": {
        18: "4", 19: "3", 20: "3", 21: "4", 22: "1", 23: "2",
        24: "5", 25: "2", 26: "5", 27: "2", 28: "3", 29: "4",
        30: "3", 31: "5", 32: "4", 33: "3", 34: "3"
    },
    "2024-09-국어": {
        18: "1", 19: "3", 20: "5", 21: "5", 22: "3", 23: "1",
        24: "4", 25: "4", 26: "5", 27: "3", 28: "4", 29: "3",
        30: "5", 31: "2", 32: "1", 33: "3", 34: "3"
    },
    "2024-수능-국어": {
        18: "2", 19: "4", 20: "1", 21: "4", 22: "4", 23: "5",
        24: "2", 25: "2", 26: "1", 27: "1", 28: "4", 29: "3",
        30: "5", 31: "4", 32: "3", 33: "5", 34: "2"
    }
}

# 🔹 지문-문항 범위 매핑
passage_problem_mapping = {
    "2024-06-국어": {"p5": (18, 21), "p6": (22, 26), "p7": (27, 30), "p8": (31, 34)},
    "2024-09-국어": {"p5": (18, 21), "p6": (22, 27), "p7": (28, 31), "p8": (32, 34)},
    "2024-수능-국어": {"p5": (18, 21), "p6": (22, 27), "p7": (28, 31), "p8": (32, 34)},
}

# 🔹 OCR 및 평가 실행
def extract_and_evaluate_passage_and_questions(base_path, exam_name, page):
    if exam_name not in passage_problem_mapping or page not in passage_problem_mapping[exam_name]:
        print(f"❌ 매핑 정보 없음: {exam_name} {page}")
        return

    start, end = passage_problem_mapping[exam_name][page]
    passage_path = os.path.join(base_path, f"{exam_name}_{page}.png")
    if not os.path.exists(passage_path):
        print(f"\n⚠️ 지문 이미지 없음: {exam_name}_{page}.png")
        return

    print(f"\n📘 지문: {exam_name} {start}~{end}")
    print("=" * 60)

    passage_text = run_split_pipeline(passage_path)

    for num in range(start, end + 1):
        question_path = os.path.join(base_path, f"{exam_name}_{num}.png")
        if not os.path.exists(question_path):
            print(f"⚠️ 문제 이미지 없음: {exam_name}_{num}.png")
            continue

        print(f"\n--- ❓ 문제 {num} ---")
        question_text = extract_question(question_path)

        # 모델 응답 및 정답 비교
        correct = answer_key.get(exam_name, {}).get(num, "❓")
        try:
            print(f"📌 예측 결과: {tutor_response(question=question_text, passage=passage_text)}")
        except Exception as e:
            print(f"❌ 오류 발생: {e}")
        print(f"✅ 정답: {correct}")

# 🔹 전체 회차 실행
def run_tutor_inference(base_path, year, sessions=None):
    sessions = sessions or ["06", "09", "수능"]

    for 회차 in sessions:
        exam_name = f"{year}-{회차}-국어"
        for page in ["p5", "p6", "p7", "p8"]:
            extract_and_evaluate_passage_and_questions(base_path, exam_name, page)

# %%
base_path = "/content/drive/MyDrive/Colab Notebooks/TAVE 프로젝트_STUBO/문학/data/output_images"

# 전체 연도 평가
# run_tutor_inference(base_path, "2022")

# 2024년 6, 9, 수능만 평가
run_tutor_inference(base_path, "2024", sessions=["06"])
# Out:
# 📘 지문: 2024-06-국어 18~21
# ============================================================
# 📂 이미지 로딩 중...
# 🔀 이미지 4등분 중...
# 🔍 [1/4] 분할 이미지 OCR 중...
# 🔍 [2/4] 분할 이미지 OCR 중...
# 🔍 [3/4] 분할 이미지 OCR 중...
# 🔍 [4/4] 분할 이미지 OCR 중...
# 🔧 GPT 정교화 단계 진행 중...
# 🧠 특수기호 위치 검토 및 보정 중...
# 🗂️ GPT 지문 범위 표시([A], [B] 등) 삽입 중...
#
# --- ❓ 문제 18 ---
# 📘 [문제에 대한 정답 및 해설]
# /tmp/ipython-input-7-3533957196.py:50: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   retrieved_docs = retriever.get_relevant_documents(f"{context}\n\n{question}")
# [정답]
# - ③ ㉢은 장 한림 부부가 간신의 모해로 유배 간 공간이다.
#
# [해설]
# - 문제에서 요구한 것은 ㉠~㉤의 각 공간에 대한 설명입니다. 지문을 통해 각 공간의 역할과 사건을 파악해야 합니다.
#
# 1. ① ㉠은 이대봉이 이름의 영혼을 만나 갑옷과 칼을 얻은 공간이다.
#    - ㉠은 장 한림의 딸 애향이 제문을 읽는 장면으로, 이대봉이 영혼을 만나 갑옷과 칼을 얻은 공간이 아닙니다. 따라서 틀렸습니다.
#
# 2. ② ㉡은 흉노가 침범한 곳이자 이대봉이 흉노를 처단한 공간이다.
#    - ㉡은 용궁을 떠나 황성에 올라와 머물 곳을 정한 후의 장면으로, 흉노가 침범한 곳과는 관련이 없습니다. 따라서 틀렸습니다.
#
# 3. ③ ㉢은 장 한림 부부가 간신의 모해로 유배 간 공간이다.
#    - 지문에서 "부친은 대인의 억울함과 소첩의 안길이 그릇됨을 원통히 여겨 걱정과 분노가 병이 되어 중도에 세상을 버리시니"라는 부분에서 장 한림 부부가 유배 간 사실이 언급됩니다. 따라서 맞습니다.
#
# 4. ④ ㉣은 이대봉이 중원을 향하기 전에 머물던 공간이다.
#    - ㉣은 금릉으로 행차하는 장면으로, 중원을 향하기 전에 머물던 공간이 아닙니다. 따라서 틀렸습니다.
#
# 5. ⑤ ㉤은 동돌수가 이대봉을 피해 달아난 공간이다.
#    - ㉤은 지문에 직접적으로 언급되지 않았으며, 동돌수가 달아난 공간이라는 설명은 지문과 일치하지 않습니다. 따라서 틀렸습니다.
# 📌 예측 결과: None
# ✅ 정답: 4
#
# --- ❓ 문제 19 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③ 부친이 ‘세상을 버린’ 까닭은 혼약이 어그러진 것과 이 시랑의 죽음에 대한 분노 때문이라고 여겼다.
#
# [해설]
# - ③번 선택지는 지문에서 부친이 세상을 떠난 이유를 잘못 해석하고 있습니다. 지문에 따르면, "부친은 대인의 억울함과 소첩의 안길이 그릇됨을 원통히 여겨 걱정과 분노가 병이 되어 중도에 세상을 버리시니"라는 부분에서 부친이 세상을 떠난 이유는 이 시랑의 억울함과 혼약이 어그러진 것에 대한 원통함 때문이지, 이 시랑의 죽음 때문이 아닙니다. 따라서 이 선택지는 부친의 사망 원인을 잘못 이해하고 있습니다.
#
# - ①번 선택지는 지문에서 "부친이 신기한 꿈을 꾸고는 대인과 (진진지연)을 깊이 맺었더니"라는 부분을 통해 부친과 이 시랑의 혼약이 신기한 꿈에 영향을 받았음을 나타내고 있습니다.
#
# - ②번 선택지는 "슬프다, 양가 시운이 불리하여 대인은 간신의 모해를 입어"라는 부분에서 이 시랑이 간신의 모해를 입은 것이 시운이 좋지 않아서라고 장 소재가 생각했음을 보여줍니다.
#
# - ④번 선택지는 "간적 왕희가 첩의 고독함을 업신여겨 혼인을 강제하옵기로 변복 도주하였다가"라는 부분에서 왕희가 혼인을 강제하려 했다는 이유로 장 소재가 도주했음을 설명합니다.
#
# - ⑤번 선택지는 "비록 성혼 행례는 아니 하였사오나 어찌 시어머니와 며느리 사이가 아니리잇가"라는 부분에서 장 소재가 성혼 행례를 하지 않았지만 양씨를 시어머니로 대했음을 나타냅니다.
# 📌 예측 결과: None
# ✅ 정답: 3
#
# --- ❓ 문제 20 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④ ⓐ에서 글을 바치는 사람이 오해했던 사건의 실상이 ⓑ에서 드러나고 있어요.
#
# [해설]
# - 문제는 <보기>의 [A]에 들어갈 말로 적절하지 않은 것을 찾는 것입니다. ⓐ는 제문이고, ⓑ는 표문입니다. 제문은 망자에게 바치는 글로, 주로 고인의 넋을 위로하는 내용을 담고 있으며, 표문은 왕이나 높은 지위의 인물에게 올리는 글로, 사건의 경과를 알리고 조치를 요청하는 기능을 가집니다.
#
# 1. ①은 ⓐ가 망자에게 바치는 제문이고, ⓑ가 성상에게 바치는 표문이라는 점에서 적절합니다.
# 2. ②는 ⓐ가 상대의 원통함을 위로하기 위한 제문이고, ⓑ가 사건 경과를 알려 특별한 조치를 요청하기 위한 표문이라는 점에서 적절합니다.
# 3. ③은 ⓐ와 달리 ⓑ에는 글을 바치는 사람이 스스로를 낮추는 표현이 사용되었다는 점에서 적절합니다.
# 4. ④는 ⓐ에서 글을 바치는 사람이 오해했던 사건의 실상이 ⓑ에서 드러나고 있다고 했지만, 지문에서 ⓐ와 ⓑ는 각각 제문과 표문으로, 오해했던 사건의 실상이 드러나는 내용이 없습니다. 따라서 적절하지 않습니다.
# 5. ⑤는 ⓐ와 ⓑ 모두 글을 바치는 사람과 상대를 서두에서 밝히고 있다는 점에서 적절합니다.
#
# 따라서 ④번이 적절하지 않은 선택지입니다.
# 📌 예측 결과: None
# ✅ 정답: 3
#
# --- ❓ 문제 21 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ①
#
# [해설]
# - ① 선택지는 "장애황이 혼약을 이루기 위해 대금을 세웠다고 한 데에서, 혼약이 국가 차원의 사건에 참여하는 동력이 되었음을 알 수 있군."이라고 하였으나, 지문에서는 장애황이 혼약을 이루기 위해 대공을 세웠다고 언급된 부분이 없습니다. 따라서 이 선택지는 지문과 <보기>의 내용을 잘못 해석한 것입니다.
# - ② 선택지는 장애황이 난신 왕희를 국법으로 다스린 후 자신에게 내어 달라고 한 부분에서 공적 권위를 존중하면서도 사적 목표를 실현하고자 하는 마음을 드러내고 있습니다. 이는 <보기>에서 설명한 공적 가치와 사적 목표의 조화와 일치합니다.
# - ③ 선택지는 이대봉이 홍노의 침입에 대응하여 출전한 것을 국가 차원의 문제 해결에 참여하는 당위성으로 설명하고 있으며, 이는 <보기>의 설명과 일치합니다.
# - ④ 선택지는 이대봉이 비현실계의 존재인 천우신조로 인해 무인절도에서 이 시랑과 재회한 것을 언급하며, 이는 <보기>에서 언급된 비현실계의 존재가 주인공의 문제 해결에 조력하는 부분과 일치합니다.
# - ⑤ 선택지는 이대봉이 홍노 제압 후 성상에게 왕희의 처벌을 요구한 부분에서 충의 이념을 지키면서도 사적 목표의 정당성을 확보하려는 의중을 드러내고 있으며, 이는 <보기>의 설명과 일치합니다.
# 📌 예측 결과: None
# ✅ 정답: 4
#
# 📘 지문: 2024-06-국어 22~26
# ============================================================
# 📂 이미지 로딩 중...
# 🔀 이미지 4등분 중...
# 🔍 [1/4] 분할 이미지 OCR 중...
# 🔍 [2/4] 분할 이미지 OCR 중...
# 🔍 [3/4] 분할 이미지 OCR 중...
# 🔍 [4/4] 분할 이미지 OCR 중...
# 🔧 GPT 정교화 단계 진행 중...
# 🧠 특수기호 위치 검토 및 보정 중...
# 🗂️ GPT 지문 범위 표시([A], [B] 등) 삽입 중...
#
# --- ❓ 문제 22 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ① (가)는 열거의 방식을, (나)는 대조의 방식을 활용하여 주제를 부각하고 있다.
#
# [해설]
# - ① (가)에서는 꽁생원의 다양한 행동과 그로 인한 결과를 나열하여 그의 부정적인 삶의 태도를 부각하고 있습니다. 반면, (나)에서는 부지런한 농부와 게으른 농부의 대조를 통해 부지런함의 중요성을 강조하고 있습니다. 따라서 (가)는 열거의 방식을, (나)는 대조의 방식을 활용하여 주제를 부각하고 있다는 설명이 적절합니다.
# - ② (가)와 (나) 모두 대구적 표현을 활용하고 있지 않으며, 인물에 대한 태도의 변화를 드러내는 방식도 나타나지 않습니다.
# - ③ (나)에서는 반어적 표현이 사용되지 않았습니다. 오히려 농부들의 태도를 직접적으로 서술하며 그 결과를 보여줍니다.
# - ④ (가)와 (나) 모두 계절적 배경이 등장하지만, 이는 향토적 분위기를 조성하기 위한 것이 아니라 각각의 주제를 부각하기 위한 배경 설정입니다.
# - ⑤ (가)와 (나) 모두 해학적 표현을 통해 인물 간의 우호적 관계를 드러내고 있지 않습니다. 오히려 (가)는 꽁생원의 부정적 삶을, (나)는 농부들의 대조를 통해 교훈을 전달하고 있습니다.
# 📌 예측 결과: None
# ✅ 정답: 1
#
# --- ❓ 문제 23 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - ② ㉡은 "처자식을 흩어 놓고"라는 표현에서 볼 수 있듯이, 꽁생원이 자신의 가족을 돌보지 않고 무책임하게 행동하는 모습을 나타냅니다. 따라서 "재물을 모은 꽁생원이 함께 풍요로운 삶을 누리고 싶은 대상이다"라는 설명은 적절하지 않습니다. 이는 가족을 돌보지 않고 자신의 이익만을 추구하는 부정적인 태도를 나타내는 부분입니다.
#
# - ① ㉠은 "음양술수 현혹되어"라는 표현에서 볼 수 있듯이, 꽁생원이 집터나 묏자리를 통해 길운을 바라는 모습을 나타내고 있습니다. 이는 꽁생원이 길운을 바라는 대상에 관심을 보이는 것을 설명합니다.
#
# - ③ ㉢은 "재물을 경영하여 경향출입 싸다닐 제"라는 표현에서 볼 수 있듯이, 꽁생원이 재물을 경영하여 부를 증식하려는 모습을 나타내고 있습니다. 이는 권력가의 권세를 이용하기 위한 방법으로 적절합니다.
#
# - ④ ㉣은 "청질하다 봉변당해 물러서며"라는 표현에서 볼 수 있듯이, 꽁생원이 집이나 땅을 중개하여 이문을 취하려다 흥정 과정에서 부정적인 반응을 겪은 것을 설명합니다.
#
# - ⑤ ㉤은 "궐잔 들고 자빠지고"라는 표현에서 볼 수 있듯이, 부자의 재산으로 이익을 얻으려는 꽁생원이 부자를 피는 수단으로 적절합니다. 이는 부자를 꾀려는 행동을 나타냅니다.
# 📌 예측 결과: None
# ✅ 정답: 2
#
# --- ❓ 문제 24 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 ⓑ와 ⓒ에 대한 설명이 지문과 일치합니다. ⓑ는 '게으른 농부'로, "김을 매도 죽을 것이고 김을 매지 않아도 죽을 것이다"라고 하여 김매기를 하여도 작물이 죽을 것이라고 생각합니다. ⓒ는 학문에 힘을 쏟아도 부귀를 이루지 못할 수 있다고 생각하는 사람들로, "공명에는 분수가 있어서 학문으로 이를 수 있는 것이 아니며, 부귀는 운명에 달려 있으니 역시 학문으로 이를 수 있는 것이 아니다"라고 말합니다. 이는 지문에서 학문에 대한 노력을 포기하는 사람들의 태도를 설명하고 있습니다.
#
# - ①번 선택지는 ⓑ에 대한 설명이 틀렸습니다. ⓑ는 가뭄에 김을 매지 않은 게으른 농부로, 술에 취해 잠들어 있는 농부는 부지런한 농부입니다.
# - ②번 선택지는 ⓐ에 대한 설명이 틀렸습니다. ⓐ는 부모의 혜택을 받았으나 그 혜택을 제대로 활용하지 못하고 팔자를 원망하는 인물입니다.
# - ③번 선택지는 ⓒ에 대한 설명이 틀렸습니다. ⓒ는 과거 시험에서 뜻을 이루지 못하여 수치를 당하는 것이 아니라, 학문에 대한 노력을 포기하는 사람들을 지칭합니다.
# - ④번 선택지는 ⓑ에 대한 설명이 틀렸습니다. ⓑ는 가뭄에 김을 매지 않아 조롱을 받는 것이 아니라, 김매기를 하지 않고 천명을 기다리는 농부입니다.
# 📌 예측 결과: None
# ✅ 정답: 5
#
# --- ❓ 문제 25 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - ②번 선택지는 글쓴이의 주장과 그에 대한 반박을 제시하여 화제에 대한 상반된 입장을 나타내고 있다고 설명하고 있습니다. 그러나 (나) 지문에서는 글쓴이의 주장과 그에 대한 반박이 명시적으로 드러나지 않습니다. 대신, 부지런한 농부와 게으른 농부의 대조를 통해 부지런함의 중요성을 강조하고 있습니다. 따라서 ②번 선택지는 적절하지 않습니다.
#
# - ①번 선택지는 인물들의 말을 인용하여 특정 상황에 대한 서로 다른 태도를 드러내고 있다고 설명하고 있습니다. 이는 부지런한 농부와 게으른 농부의 대조적인 태도를 인용을 통해 드러내고 있는 (나) 지문과 일치합니다.
#
# - ③번 선택지는 물음에 답하는 인물을 통해 글쓴이가 관찰한 상황이 발생하게 된 이유를 제시하고 있다고 설명하고 있습니다. 이는 마을 노인이 황폐한 밭과 잘 가꾸어진 밭의 차이를 설명하는 부분과 일치합니다.
#
# - ④번 선택지는 다른 사람에게 교훈을 전달하고자 하는 글쓴이의 의도를 드러내며 글을 마무리하고 있다고 설명하고 있습니다. 이는 글쓴이가 학문과 농사의 노력을 비교하며 부지런함의 중요성을 강조하는 결론 부분과 일치합니다.
#
# - ⑤번 선택지는 글쓴이의 경험을 통해 얻은 깨달음을 바탕으로 논의의 대상을 다른 상황으로 확장하고 있다고 설명하고 있습니다. 이는 농사의 부지런함을 학문에 대한 노력으로 확장하여 설명하는 부분과 일치합니다.
# 📌 예측 결과: None
# ✅ 정답: 2
#
# --- ❓ 문제 26 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④
#
# [해설]
# - ④번 선택지는 (가)와 (나)의 내용을 잘못 해석하고 있습니다. (가)의 '돈천이나 가졌더니', '친구 대접 하였던가'는 재물을 베푸는 데 인색한 태도를 드러내는 것이 아니라, 꽁생원이 자신의 재산을 제대로 관리하지 못하고 허영심에 빠져 있다는 것을 나타냅니다. 또한, (나)의 '풀 뽑기를 쉬지 아니하여'는 한계 상황을 극복하고자 하는 의지를 나타내는 것이 맞지만, 이 부분은 긍정적인 평가를 받는 부지런한 농부의 행동을 설명하는 부분입니다. 따라서 이 선택지는 (가)와 (나)의 내용을 정확히 반영하지 못했습니다.
#
# - ①번 선택지는 (가)에서 '공것'과 '뜬재물'이 요행을 바라는 태도를 나타내는 소재로 적절히 해석되었습니다. 이는 정당한 노력을 기울이지 않고 얻으려는 태도를 비판하는 부분입니다.
#
# - ②번 선택지는 (나)에서 '비가 내리지 않아' '김을 멜 수가 없'는 상황이 농경에 부적합한 환경임을 나타내며, 이는 문제 상황에 대한 정확한 이해를 보여줍니다.
#
# - ③번 선택지는 (가)에서 '공납'을 유용하려는 것이 규범을 무시하는 태도임을, (나)에서 '그냥 쉬는 것이 나을 것'이라는 것이 운명론적 태도를 드러내는 것으로 적절히 해석되었습니다.
#
# - ⑤번 선택지는 (가)에서 '일가'와 '친구'에게 소외당한 꽁생원의 말로가 무책임한 삶에 대한 경계를 나타내고, (나)에서 '큰 일을 하면서 부지런하기를 촉구하는 것'이 게으른 농부에 대한 권면으로 적절히 해석되었습니다.
# 📌 예측 결과: None
# ✅ 정답: 5
#
# 📘 지문: 2024-06-국어 27~30
# ============================================================
# 📂 이미지 로딩 중...
# 🔀 이미지 4등분 중...
# 🔍 [1/4] 분할 이미지 OCR 중...
# 🔍 [2/4] 분할 이미지 OCR 중...
# 🔍 [3/4] 분할 이미지 OCR 중...
# 🔍 [4/4] 분할 이미지 OCR 중...
# 🔧 GPT 정교화 단계 진행 중...
# 🧠 특수기호 위치 검토 및 보정 중...
# 🗂️ GPT 지문 범위 표시([A], [B] 등) 삽입 중...
#
# --- ❓ 문제 27 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤ ㉤: "날짐승도 때가 되면 돌아올 줄 아는 법이다."라는 문장은 어머니의 발화로, 어머니가 말한 내용을 서술자가 전달하고 있습니다. 따라서 지각의 주체가 어머니라는 것이 명확히 드러나고 있으며, 누가 지각한 바를 서술한 것인지 모호하지 않습니다. 따라서 이 설명은 적절하지 않습니다.
#
# - ① ㉠: "뜻밖에도 아버지의 죄를 순순히 시인하는 그녀의 한마디가 내게는 그토록 엄청난 충격으로 깊이 남겨졌던 탓이리라."라는 부분에서 '나'의 지각 내용을 '나'가 서술하고 있습니다. 따라서 인물과 서술자가 겹쳐 있는 상황이 맞습니다.
#
# - ② ㉡: "언젠가 어머니의 낡은 반닫이 깊숙한 옷가지 밑에 숨겨져 있던 액자 속에서 학생복 차림으로 서 있던 그대로 그건 영락없는 그 사내였다."라는 부분은 서술의 주체가 '나'임이 명확히 드러나고 있습니다. 따라서 서술자와 지각의 주체가 뚜렷이 구분됩니다.
#
# - ③ ㉢: "저것 봐라."라는 발화는 '나'가 아니라 '나'가 지각하는 대상을 주어로 서술하여, 지각의 대상을 부각하는 효과가 있습니다.
#
# - ④ ㉣: "저것 봐라."라는 발화는 인용 부호 없이 서술되어 있지만, 어머니의 목소리가 드러납니다. 따라서 인물의 목소리가 드러나는 것이 맞습니다.
# 📌 예측 결과: None
# ✅ 정답: 2
#
# --- ❓ 문제 28 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ⓐ는 "노인은 몸통뼈에 묶인 줄을 풀어내기 시작했다"라는 부분으로, 이야기의 긴장감을 형성하는 요소입니다. 유해를 수습하는 과정에서 줄을 푸는 장면은 긴장감을 고조시키며, 독자로 하여금 이후 전개될 이야기에 대한 기대감을 높입니다.
# - ⓑ는 "우리는 관 대신에 신문지로 싼 유해를 맨 처음 그 자리에 다시 묻어 주었다"라는 부분으로, 이야기의 긴장감이 완화됨을 드러내는 표지입니다. 유해를 다시 묻고 장례식을 치르는 장면은 사건의 마무리를 의미하며, 긴장감이 해소되는 지점을 나타냅니다.
#
# - ① ⓐ와 ⓑ 모두 이야기의 주제를 직접적으로 구현하거나 가늠하도록 하는 요소로 보기 어렵습니다.
# - ② ⓐ는 이야기의 절정에 치닫도록 하는 추진력이라기보다는 긴장감을 형성하는 장면입니다.
# - ④ ⓐ는 위기감이 해소된 종착점이 아니라 긴장감을 형성하는 부분입니다.
# - ⑤ ⓐ는 이야기를 일으키는 시발점이 아니라 긴장감을 형성하는 부분입니다. ⓑ는 이야기의 전모가 드러나는 귀결점이라기보다는 긴장감이 완화되는 지점입니다.
# 📌 예측 결과: None
# ✅ 정답: 3
#
# --- ❓ 문제 29 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ② 가는 나와 달리, 시간과 공간에 관여되면서 이야기의 배경에 실감을 더하게 된다.
#
# [해설]
# - 지문에서 '가'는 주로 과거의 기억과 환영을 통해 '나'의 심리적 상태와 아버지에 대한 감정을 드러내는 데 중점을 두고 있습니다. '가'에서는 아버지의 죄책감과 불길한 예감이 '나'의 심리적 불안정에 영향을 미치고 있으며, 이는 주로 내면적이고 관념적인 요소로 표현됩니다. 반면, '나'는 실제로 유해를 수습하고 매장하는 사건을 통해 시간과 공간의 구체적인 변화를 겪고 있으며, 이는 이야기의 배경에 실감을 더하게 합니다. 따라서 '나'는 '가'와 달리 시간과 공간에 관여되어 이야기의 배경을 구체화하는 역할을 합니다.
#
# - ① '가'는 주로 내면적이고 관념적인 요소로 구성되어 있어, '나'보다 능동적이라고 보기 어렵습니다.
# - ③ '나'는 유해를 매장하는 과정에서 과거의 기억과 환영을 떠올리며, 희망적인 성격보다는 과거의 상처와 불안이 드러납니다.
# - ④ '나'에서 연상되는 상황이 현실이 될 경우, '가'에 투영된 염원이 실현 가능성이 사라진다고 보기 어렵습니다. '가'는 주로 과거의 기억과 환영을 통해 심리적 상태를 드러내고 있습니다.
# - ⑤ '가'와 '나' 모두 관념적 의미가 부여되지만, 인물이 이념에 편향되어 있음을 드러낸다고 보기는 어렵습니다. 이는 주로 심리적 상태와 과거의 기억을 다루고 있습니다.
# 📌 예측 결과: None
# ✅ 정답: 4
#
# --- ❓ 문제 30 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③번 선택지는 '줄 묶음'을 내던지는 '노인'의 행위와 '물 사발'을 올리는 '어머니'의 행위가 '나'의 기억을 재응고화하기 위한 노력으로 해석하고 있습니다. 그러나 지문에서는 '줄 묶음'을 내던지는 장면이 '어머니'의 행위와 직접적으로 연결되거나 '기억 재응고화'의 노력으로 제시되지 않습니다. '줄 묶음'을 내던지는 장면은 과거의 억압적 기억을 상징적으로 해소하는 장면일 수 있으나, '물 사발'과의 연결은 지문에서 명확히 드러나지 않으므로 부적절한 해석입니다.
#
# - ①번 선택지는 유년의 기억이 성인이 되어서도 영향을 미친다는 점을 지적하며, 이는 지문에서 '낙인'과 같은 유년의 기억이 '나'에게 지속적인 영향을 미친다는 내용과 일치합니다.
#
# - ②번 선택지는 '아버지'에 관한 기억이 '나'의 심리적 불안정을 초래한다는 점을 설명하고 있으며, 이는 지문에서 '아버지의 죄'와 관련된 기억이 '나'에게 죄악감과 불길한 예감을 유발한다는 내용과 부합합니다.
#
# - ④번 선택지는 '모래밭'에서의 '어머니'와 '사내의 환영'이 어우러지는 장면이 '아버지'에 대한 기억의 재편 가능성을 시사한다고 설명하고 있으며, 이는 지문에서 '사내의 환영'이 사라지는 장면을 통해 '아버지'에 대한 기억이 변화할 가능성을 암시하는 것으로 해석될 수 있습니다.
#
# - ⑤번 선택지는 '아버지'에 대한 이미지가 '유해'에 대응되면서 '나'의 정서적 반응에 변화가 생긴다는 점을 설명하고 있으며, 이는 지문에서 '유해'를 매장하는 장면이 '나'에게 정서적 변화를 일으키는 것으로 해석될 수 있습니다.
# 📌 예측 결과: None
# ✅ 정답: 3
#
# 📘 지문: 2024-06-국어 31~34
# ============================================================
# 📂 이미지 로딩 중...
# 🔀 이미지 4등분 중...
# 🔍 [1/4] 분할 이미지 OCR 중...
# 🔍 [2/4] 분할 이미지 OCR 중...
# 🔍 [3/4] 분할 이미지 OCR 중...
# 🔍 [4/4] 분할 이미지 OCR 중...
# 🔧 GPT 정교화 단계 진행 중...
# 🧠 특수기호 위치 검토 및 보정 중...
# 🗂️ GPT 지문 범위 표시([A], [B] 등) 삽입 중...
#
# --- ❓ 문제 31 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤ (가)와 (나)는 모두, 자연물에 화자의 정서를 투영함으로써 대상에 대한 친밀감을 드러내고 있다.
#
# [해설]
# - ⑤번 선택지는 적절하지 않습니다. (가)와 (나) 모두 자연물에 대한 언급이 있지만, 이는 화자의 정서를 투영하기보다는 각기 다른 방식으로 화자의 태도와 심리를 드러내는 데 사용됩니다. (가)에서는 자연 속에서의 경험과 관습에 대한 회의적인 태도를, (나)에서는 차를 마시는 행위를 통해 고독과 관습을 강조하고 있습니다. 따라서 자연물에 대한 친밀감을 드러낸다고 보기 어렵습니다.
#
# - ① (가)는 인격화한 대상을 통해 화자의 심리를 내포하고 있습니다. 예를 들어, "때까치들이 몰려와 모든 야성을 버리고 들 가운데 순결해진다"는 표현은 자연 속에서의 순수함과 화자의 심리적 변화를 암시합니다.
#
# - ② (나)는 "차의 질은 향기와는 관계 없이", "물과 같이 담담한 사실일 뿐" 등의 표현을 통해 대상을 한정하는 어휘를 사용하여 주제 의식을 강조하고 있습니다. 이는 차를 마시는 행위가 단순한 사실임을 강조하며, 절대자와의 관계에 대한 회의를 드러냅니다.
#
# - ③ (가)는 "손 흔들고 떠나갈 미련은 없다", "남방으로 가다 길을 놓치고" 등의 표현을 통해 공간의 이동에 따라 포착된 사물을 통해 화자의 태도를 드러내고 있습니다. 이는 자연 속에서의 경험을 통해 화자가 점차 자연에 동화되어 가는 과정을 보여줍니다.
#
# - ④ (나)는 "나는 차를 앞에 놓고", "내가 좋아하는 차를 마신다" 등 화자를 거듭 명시하면서 시상을 전개하고 있습니다. 이는 화자의 고독과 관습에 대한 인식을 강조하는 데 기여합니다.
# 📌 예측 결과: None
# ✅ 정답: 5
#
# --- ❓ 문제 32 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ㉠과 ㉡에 대한 이해를 묻는 문제입니다. 지문 (가)에서 ㉠은 "흐리던 산길이 잘 보인다"로 시작하여, "길을 가다가 자주 뒤를 돌아보게 하는 서른 번 다쳐 두고 서른 번 포기했던 관습들"과 연결됩니다. 이는 바라봄의 대상인 '서쪽 마을'과 관련되어 피안에 대한 지향을 드러냅니다. ㉡은 "가늘게 흩어지는 저녁 연기가 한 가정의 고민의 양식으로 피어오르고"라는 구절에서 일과를 마친 '저녁'과 관련되어 안식에 대한 지향을 드러냅니다. 따라서 ③번 선택지가 적절합니다.
#
# - ① ㉠은 '길을 가다가 자주 뒤를 돌아보게 하는' 것과 관련된 것이 아니라, '흐리던 산길이 잘 보인다'와 관련됩니다. 이는 그리움의 대상이라기보다는 피안에 대한 지향을 나타냅니다.
# - ② ㉡은 '호응로'와 관련된 것이 아니라, '가늘게 흩어지는 저녁 연기'와 관련됩니다. 이는 사회적 고립이 아니라 안식에 대한 지향을 나타냅니다.
# - ④ ㉠은 '서른 번 다져 두고 서른 번 포기'한 것과 관련된 것이 아니라, '흐리던 산길이 잘 보인다'와 관련됩니다. 이는 내면의 갈등보다는 피안에 대한 지향을 나타냅니다. ㉡은 '고즈넉한' 상황에서 이루어지는 '담담한 사실'이 아니라, '가늘게 흩어지는 저녁 연기'와 관련되어 안식에 대한 지향을 나타냅니다.
# - ⑤ ㉠은 '내려다보'아 축발된 것이 아니라, '흐리던 산길이 잘 보인다'와 관련됩니다. 이는 자기 연민이 아니라 피안에 대한 지향을 나타냅니다. ㉡은 '달갑고, 좋아하는' 것이 아니라, '가늘게 흩어지는 저녁 연기'와 관련되어 안식에 대한 지향을 나타냅니다.
# 📌 예측 결과: None
# ✅ 정답: 4
#
# --- ❓ 문제 33 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③ ㉢은 '맨살 비비는 돌돌과 함께 누워'라는 표현에서 '돌들'이 '세파에 시달리는 모습'을 나타낸다고 보기 어렵습니다. 이 표현은 자연 속에서 편안하게 누워 있는 모습을 나타내며, 세파에 시달리는 모습과는 거리가 있습니다. 따라서 이 선택지는 적절하지 않습니다.
#
# - ① ㉠은 '흐리던 산길이 잘 보인다'라는 표현에서 이전에는 산길이 흐려서 제대로 보이지 않았음을 드러내고 있습니다. 이는 대상이 이전에는 제대로 파악되지 않았음을 나타내는 표현으로 적절합니다.
#
# - ② ㉡은 '가늘게 흩어지는 저녁 연기'가 '한 가정의 고민의 양식으로 피어오르고' 있다는 표현에서 '저녁 연기'를 통해 '한 가정'의 상황과 처지를 시각화하고 있습니다. 이는 적절한 설명입니다.
#
# - ④ ㉣은 '스스로 달갑고 가장 즐거울 뿐'이라는 표현에서 '차를 마시는 것'이 화자의 선호에 따른 주체적 행위임을 드러내고 있습니다. 이는 적절한 설명입니다.
#
# - ⑤ ㉤은 '이제는 차를 마시는 나일 뿐'이라는 표현에서 '나'에 대한 현재의 인식이 이전과는 달라졌음을 드러내고 있습니다. 이는 적절한 설명입니다.
# 📌 예측 결과: None
# ✅ 정답: 3
#
# --- ❓ 문제 34 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③번 선택지는 (가)의 '밥을 푸니'라는 표현이 지문에 존재하지 않으며, '잘 보인다'는 표현은 자연에 친숙해지는 심리 상태를 나타내는 것이 아니라, 흐리던 산길이 잘 보이는 상황을 묘사한 것입니다. 또한, (나)의 '앞으로 남은 십 년을 더 살든지 죽든지'는 절대자에 대한 회의와 관련이 없고, '나에게도 나는 나일 뿐'이라는 자아 인식의 확고함을 드러내는 표현입니다.
#
# - ①번 선택지는 (가)에서 '쓰다 둔 편지 구절과 버린 칫솔을 생각한다'는 부분이 화자가 자연에 온전히 동화되지 못하고 세속적인 미련을 가지고 있음을 보여주는 표현으로 적절합니다.
#
# - ②번 선택지는 (나)에서 '차를 마시는' 행위가 '내가 아는 내게 대한 모든 것', '모든 것에 대한 모든 것'으로 확장되는 부분이 경험적 사실을 인식의 유일한 근거로 삼겠다는 의식을 반영하고 있어 적절합니다.
#
# - ④번 선택지는 (가)의 '여울물'과 '때까치들'이 자연에서 느끼는 화자의 심리를 투사하고 있으며, (나)의 '참새'의 떨어짐이 '누구'에 의한 것이 아니라는 표현이 절대자와의 관계에 대한 회의를 드러내고 있어 적절합니다.
#
# - ⑤번 선택지는 (가)의 '이 세상을 앙아 보지 않은 것들과 함께'가 자연에 동화되려는 태도를, (나)의 '물은 물일 뿐'이 경험적 사실로만 대상을 인식하겠다는 태도를 드러내고 있어 적절합니다.
# 📌 예측 결과: None
# ✅ 정답: 3

# %%
run_tutor_inference(base_path, "2024", sessions=["09"])
# Out:
# 📘 지문: 2024-09-국어 18~21
# ============================================================
# 📂 이미지 로딩 중...
# 🔀 이미지 4등분 중...
# 🔍 [1/4] 분할 이미지 OCR 중...
# 🔍 [2/4] 분할 이미지 OCR 중...
# 🔍 [3/4] 분할 이미지 OCR 중...
# 🔍 [4/4] 분할 이미지 OCR 중...
# 🔧 GPT 정교화 단계 진행 중...
# 🧠 특수기호 위치 검토 및 보정 중...
# 🗂️ GPT 지문 범위 표시([A], [B] 등) 삽입 중...
#
# --- ❓ 문제 18 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ① 이도련은 춘향이 자신에게 호감을 느꼈다는 사실을 알지 못했다.
#
# [해설]
# - ① 선택지는 이도련이 춘향의 호감을 인지하지 못했다는 내용을 담고 있습니다. 지문에서 이도련은 춘향의 아름다움에 감탄하며 그녀를 부르려 하지만, 춘향이 이도련에게 호감을 느꼈다는 직접적인 언급은 없습니다. 따라서 이도련이 춘향의 호감을 알지 못했다는 해석이 적절합니다.
#
# - ② 선택지는 춘향이 그네를 타기 위해 나들이에 나섰지만 기대했던 바를 달성하지 못했다고 설명합니다. 그러나 지문에서는 춘향이 그네를 타고 즐기는 모습이 묘사되어 있으며, 기대했던 바를 달성하지 못했다는 내용은 없습니다.
#
# - ③ 선택지는 이도련이 김한의 말을 믿었다고 설명하지만, 지문에서는 이도련이 김한의 말을 믿었다는 명확한 근거가 없습니다. 오히려 김한이 춘향을 불러오라는 이도련의 명령을 따르지 않고 춘향이 오지 않을 것이라고 말하는 장면이 있습니다.
#
# - ④ 선택지는 이도련이 월매가 춘향의 어머니라는 사실을 알고 있었다고 설명하지만, 지문에서는 이도련이 김한의 설명을 듣고 월매의 딸이 춘향이라는 사실을 알게 되는 장면이 있습니다. 따라서 이도련이 이를 모르는 척했다는 설명은 부적절합니다.
#
# - ⑤ 선택지는 옆집 여자 아이가 이도련을 만나기 위해 춘향과 함께 왔다고 설명하지만, 지문에서는 옆집 여자 아이가 풍경을 즐기기 위해 나섰다고 설명하고 있습니다. 이도련을 만나기 위해 왔다는 내용은 지문에 없습니다.
# 📌 예측 결과: None
# ✅ 정답: 1
#
# --- ❓ 문제 19 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③ 춘향이 몸을 감추고 이도린을 바라보는 장소
#
# [해설]
# - 지문에서 춘향은 "광한루 위에서 사람의 말소리가 들리자 ㉡(이게 누구지?) 춘향은 몸을 돌려 꽃그늘 속으로 들어가 숨고서는 주변을 둘러보았다."라는 문장이 있습니다. 이 문장은 춘향이 자신의 모습을 감추기 위해 꽃그늘로 들어갔음을 명확히 보여줍니다. 따라서 춘향이 몸을 감추고 이도린을 바라보는 장소라는 설명이 가장 적절합니다.
# - ① 춘향이 그네를 타기 위해 기다리는 장소: 지문에 따르면 춘향은 이미 그네를 타고 있었고, 그네를 멈추고 옷매무새를 바로잡으려 했습니다. 따라서 그네를 타기 위해 기다리는 장소가 아닙니다.
# - ② 춘향이 김한을 기다리며 머물고 있는 장소: 춘향은 김한을 기다리고 있지 않았습니다. 김한이 춘향을 찾아와 대화를 시도하는 상황입니다.
# - ④ 김한이 이도린을 만나서 대화를 나누는 장소: 김한은 이도린과 대화를 나누기 위해 꽃그늘에 있지 않았습니다. 김한은 춘향을 찾기 위해 꽃그늘로 갔습니다.
# - ⑤ 이도린이 춘향과 만나기 위해 미리 약속한 장소: 이도린과 춘향은 미리 약속한 적이 없으며, 이도린은 춘향을 우연히 보게 된 상황입니다.
# 📌 예측 결과: None
# ✅ 정답: 3
#
# --- ❓ 문제 20 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤ 춘향에게 이도련과의 만남은 거듭된 우연으로 이루어진 인연임을 알려 주어, 두 사람을 만나게 하는 매개자 역할을 한다.
#
# [해설]
# - 김한은 이도령과 춘향의 만남을 주선하는 역할을 하고 있습니다. 지문에서 김한은 춘향에게 "도련님께서 낭자를 보시고는 ‘귀신이냐? 선녀냐?’라고 물으시기에, ‘귀신도 아니고 선녀도 아닙니다.’라고 말했고, ‘그럼 누구냐?’라고 하시기에, ‘행수 기생의 딸입니다.’라고 말했소."라고 설명하며, 이도령이 춘향에게 관심을 가지게 된 계기를 설명합니다. 또한, 김한은 "도련님께서 낭자를 보시고는 ‘귀신이냐? 선녀냐?’라고 물으시기에, ‘귀신도 아니고 선녀도 아닙니다.’라고 말했고, ‘그럼 누구냐?’라고 하시기에, ‘행수 기생의 딸입니다.’라고 말했소."라고 하여, 이도령이 춘향을 만나게 하는 데 중요한 역할을 합니다. 이로 인해 김한은 두 사람의 만남을 매개하는 역할을 하게 됩니다.
#
# - ①은 김한이 이도령의 무지를 일깨우는 비판자 역할을 한다고 했지만, 김한은 이도령에게 춘향의 존재를 알리고 그 만남을 주선하는 역할을 합니다. 따라서 비판자 역할과는 거리가 있습니다.
# - ②는 김한이 이도령에게 춘향의 고귀한 신분을 알게 하는 조력자 역할을 한다고 했지만, 김한은 춘향의 신분보다는 그녀의 존재와 매력을 이도령에게 알리는 역할을 합니다.
# - ③은 김한이 이도령에게 춘향을 부르게 하는 중개자 역할을 한다고 했지만, 이는 부분적으로 맞지만, 김한의 역할은 단순히 중개자 역할을 넘어 두 사람의 만남이 우연임을 강조하며 매개자 역할을 합니다.
# - ④는 김한이 춘향이 이도령을 만나지 못하도록 방해자 역할을 한다고 했지만, 김한은 오히려 두 사람의 만남을 주선하는 역할을 합니다.
# 📌 예측 결과: None
# ✅ 정답: 5
#
# --- ❓ 문제 21 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 [A]와 ⑦을 통해 독자에게 작품의 감상법을 다양하게 설명하여, 『광한루기』를 8회로 구성한 이유를 부각하고 있다고 했지만, 이는 적절하지 않습니다. [A]는 광한루의 역할을 통해 서사 전개의 필연성을 설명하고 있으며, ⑦은 이도령의 반응에 대한 당연성을 강조하는 부분으로, 작품의 감상법을 다양하게 설명하거나 8회 구성의 이유를 부각하는 내용은 아닙니다.
#
# - ①번 선택지는 [A]에서 시구를 활용하여 ‘봄바람’과 ‘버드나무 언덕’이 어우러진 봄날의 분위기를 보여주면서 해당 회의 배경을 드러내고 있다는 점에서 적절합니다. 이는 지문에서 봄날의 분위기를 묘사하는 부분이 있기 때문입니다.
#
# - ②번 선택지는 [A]를 통해 해당 회의 주요 공간인 ‘광한루’를 소개하여 그 공간의 역할을 드러내고 있다는 점에서 적절합니다. 지문에서 광한루가 이도령과 춘향의 만남에 중요한 역할을 한다고 설명하고 있습니다.
#
# - ③번 선택지는 [A]에서 두 인물이 만나게 되는 계기를 서술하여 서사 전개의 개연성을 보여주고 있다는 점에서 적절합니다. 이는 광한루가 이도령과 춘향의 만남에 필수적인 요소로 작용하는 것을 설명하고 있습니다.
#
# - ④번 선택지는 ⑦이 인물의 말에 대한 평을 통하여 독자에게 이도령의 반응이 당연하다는 점을 강조하여 보여주고 있다는 점에서 적절합니다. 이는 이도령이 춘향의 아름다움에 반응하는 것이 자연스럽다는 것을 강조하는 부분입니다.
# 📌 예측 결과: None
# ✅ 정답: 5
#
# 📘 지문: 2024-09-국어 22~27
# ============================================================
# 📂 이미지 로딩 중...
# 🔀 이미지 4등분 중...
# 🔍 [1/4] 분할 이미지 OCR 중...
# 🔍 [2/4] 분할 이미지 OCR 중...
# 🔍 [3/4] 분할 이미지 OCR 중...
# 🔍 [4/4] 분할 이미지 OCR 중...
# 🔧 GPT 정교화 단계 진행 중...
# 🧠 특수기호 위치 검토 및 보정 중...
# 🗂️ GPT 지문 범위 표시([A], [B] 등) 삽입 중...
#
# --- ❓ 문제 22 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③ 빗대어 표현하는 방식으로 ‘나’의 인식을 드러내고 있다.
#
# [해설]
# - (가), (나), (다) 모두 빗대어 표현하는 방식을 사용하여 '나'의 인식을 드러내고 있습니다.
#
#   - (가)에서는 과거의 떠남과 돌아옴을 통해 자신의 정체성과 상실감을 빗대어 표현하고 있습니다. '부엌을', '자작나무와 이깔나무의 슬퍼하던 것', '오로촌이 멧돌을 잡아 나를 잡치해 보낸 것' 등은 모두 화자의 내적 상태와 경험을 빗대어 나타낸 것입니다.
#
#   - (나)에서는 '살얼음의 창'과 '생가'를 통해 자신의 내면과 기억을 빗대어 표현하고 있습니다. '물고기네 방이 한눈에 훤했다', '생각의 식구들이 나를 못 알아보고' 등은 화자의 내적 상태와 기억을 빗대어 나타낸 것입니다.
#
#   - (다)에서는 '늙은 나무'와 '암소의 뿔'을 통해 인간과 자연의 관계를 빗대어 표현하고 있습니다. '기둥으로 나무를 받쳐 놓았는데', '사람의 손을 빌려 온전하도록 한 것' 등은 자연과 인간의 상호 의존성을 빗대어 나타낸 것입니다.
#
# - 나머지 선택지들은 각 지문에서 공통적으로 드러나지 않는 요소들입니다.
#   - ① 비판적 태도로 현실의 부정적 측면을 부각하고 있는 것은 (가)에서 일부 드러나지만, (나)와 (다)에서는 명확히 드러나지 않습니다.
#   - ② 역사적 상황을 묘사하여 비극적 현실을 부각하는 것은 (가)에서 일부 드러나지만, (나)와 (다)에서는 드러나지 않습니다.
#   - ④ 영탄적 어조로 대상에 대한 경외감을 드러내는 것은 세 지문 모두에서 명확히 드러나지 않습니다.
#   - ⑤ 향토적 소재를 활용하여 과거에 대한 그리움을 드러내는 것은 (가)와 (나)에서 일부 드러나지만, (다)에서는 명확히 드러나지 않습니다.
# 📌 예측 결과: None
# ✅ 정답: 3
#
# --- ❓ 문제 23 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ① (가)의 화자는 태반에서 상실감을 느끼고 있고, (나)의 화자는 생가에서 서글픔을 느끼고 있다.
#
# [해설]
# - (가)에서 '태반'은 화자가 자신의 고향, 즉 본래의 땅으로 돌아온 것을 의미합니다. 그러나 돌아온 후에도 "나의 조상은 형제는 일가친척은 정다운 이웃은 그리운 것은 사랑하는 것은 우리르는 것은 나의 자랑은 나의 힘은 없다"라고 표현하며 상실감을 드러내고 있습니다. 이는 과거의 모든 것들이 사라져버린 상태를 나타내며, 상실감을 느끼고 있음을 보여줍니다.
# - (나)에서 '생가'는 화자가 자신의 과거를 회상하며 느끼는 감정을 나타냅니다. "생각의 식구들이 나를 못 알아보고 사방 쪽방으로 흩어졌다"라는 표현은 화자가 과거의 기억 속에서 소외감을 느끼고 있음을 나타내며, 이는 서글픔으로 해석될 수 있습니다. 또한, "어미들은 물속 쌓인 돌과 돌 그 틈새로 그걸 깊은 데라고 그걸 가장 깊은 속이라고 떼로 들어가 나를 못 알아보고"라는 구절은 화자가 과거의 기억 속에서 자신이 소외된 존재임을 느끼고 있음을 보여줍니다.
# - ②의 경우, (가)에서 화자는 소외감보다는 상실감을 느끼고 있으며, (나)에서 화자는 수치심보다는 서글픔을 느끼고 있습니다.
# - ③의 경우, (가)에서 태반은 이별을 수용하는 공간이 아니라 상실감을 느끼는 공간이며, (나)에서 생가는 만남을 기약하는 공간이 아니라 서글픔을 느끼는 공간입니다.
# - ④의 경우, (가)에서 태반은 희망이 드러나는 공간이 아니라 상실감이 드러나는 공간이며, (나)에서 생가는 절망이 드러나는 공간이 아니라 서글픔이 드러나는 공간입니다.
# - ⑤의 경우, (가)에서 태반은 생명의 섭리를 지향하는 공간이 아니라 상실감을 느끼는 공간이며, (나)에서 생가는 생명의 섭리를 거부하는 공간이 아니라 서글픔을 느끼는 공간입니다.
# 📌 예측 결과: None
# ✅ 정답: 1
#
# --- ❓ 문제 24 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 ㉢이 아니라 ㉥에 대한 설명입니다. ㉥에서는 "아, 나의 조상은 형제는 일가친척은 정다운 이웃은 그리운 것은 사랑하는 것은 우리르는 것은 나의 자랑은 나의 힘은 없다"라는 구절을 통해, 화자가 가깝게 느끼고 가치를 부여했던 것들이 부재함을 표현하고 있습니다. 따라서 ⑤번 선택지는 지문에서 제시된 ㉢과 관련이 없으므로 적절하지 않습니다.
#
# - ①번 선택지는 ㉠에서 여러 민족과 나라, 지명을 열거하여 화자가 떠나온 공간을 북방으로 포괄되는 동질적 공간으로 표현하고 있는 점을 잘 설명하고 있습니다.
# - ②번 선택지는 ㉡에서 자작나무와 이깔나무를 의인화하여 화자가 북방을 떠나면서 느낀 슬픔을 드러내고 있는 점을 잘 설명하고 있습니다.
# - ③번 선택지는 ㉢에서 "멧돌을 잡아 나를 잡치해 보낸 것도 쏠로이 십릿길을 따라 나와 울던 것도 잊지 않았다"라는 구절을 통해, 유사한 통사 구조로 화자가 북방에서의 기억을 여전히 간직하고 있음을 보여주고 있는 점을 잘 설명하고 있습니다.
# - ④번 선택지는 ㉣의 "아무 이기지 못할 슬픔도 시름도 없이"라는 시구가 ㉤의 "이제는 참으로 이기지 못할 슬픔과 시름에 쫓겨"로 반복, 변주되면서 상반된 상황이 시간의 추이에 따라 일치되는 과정을 드러내고 있는 점을 잘 설명하고 있습니다.
# 📌 예측 결과: None
# ✅ 정답: 4
#
# --- ❓ 문제 25 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④
#
# [해설]
# - 이 문제는 <보기>를 참고하여 (나)에서 화자가 물고기를 보며 유년 시절의 생가를 회상하는 방식을 묻고 있습니다. <보기>에서는 화자가 물고기의 움직임과 공간을 자신의 생가와 연결하여 회상하고 있음을 설명하고 있습니다.
#
# ① '투명한 창'을 통해 본 물고기의 생활 공간을 '물고기네 방'이라고 표현한 것은 화자가 물고기의 공간을 자신의 생가와 연결하여 보고 있음을 나타냅니다. 이는 <보기>의 설명과 일치합니다.
#
# ② '창으로 나를 보고' '사방 쪽방으로 흩어'지는 물고기들의 움직임을 '생가의 식구들'이 자신을 못 알아본 것으로 표현한 것은 화자가 물고기의 움직임을 생가의 기억과 연결하고 있음을 보여줍니다. 이는 <보기>의 설명과 일치합니다.
#
# ③ '젖을 갓 뗀 어린것들'이 '그네끼리 놀고'라고 표현한 것은 화자가 물고기의 모습을 통해 유년 시절 생가에서의 아이들의 모습을 떠올리고 있음을 나타냅니다. 이는 <보기>의 설명과 일치합니다.
#
# ④ 화자가 '비좁은 구석방에서' '금한 궁리를 하는' 물고기의 모습에 유년 시절 생가에서 외따로 지내야 했던 자신의 모습을 투영하고 있다는 내용은 지문에서 직접적으로 확인할 수 없습니다. <보기>에서도 이러한 해석은 제시되지 않았습니다. 따라서 이 선택지는 적절하지 않습니다.
#
# ⑤ '마음아, 너도 아직' 생가에서 '살고 있는가'라고 하여, 성년인 자신의 마음속에 유년의 기억이 자리 잡고 있음을 드러내고 있다는 내용은 <보기>의 설명과 일치합니다. 이는 화자가 여전히 유년 시절의 기억을 간직하고 있음을 나타냅니다.
# 📌 예측 결과: None
# ✅ 정답: 4
#
# --- ❓ 문제 26 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤ ⓐ와 ⓑ는 모두 대상을 새롭게 주목하게 하는 계기를 마련하고 있다.
#
# [해설]
# - 문제에서 요구하는 것은 ⓐ와 ⓑ에 대한 이해입니다. ⓐ와 ⓑ는 지문에서 특정 대상을 바라보는 시각이나 태도를 나타내는 요소로 작용합니다. ⓐ와 ⓑ는 모두 대상을 새롭게 바라보게 하는 계기를 마련하고 있습니다. 이는 지문에서 화자나 글쓴이가 특정 대상을 통해 새로운 인식을 하거나 주목하게 되는 상황을 나타냅니다.
#
# - ① ⓐ는 화자의 불안을 심화하는 역할을 한다고 볼 수 없으며, ⓑ는 글쓴이의 의지를 북돋아 주는 역할로 명시되어 있지 않습니다.
# - ② ⓐ는 화자의 이상향을 형상화하는 역할이 아니며, ⓑ가 글쓴이의 태도를 전환하는 역할로 명시되어 있지 않습니다.
# - ③ ⓐ와 ⓑ는 책임감을 떠올리게 하는 계기로 작용하지 않습니다.
# - ④ ⓑ는 ⓐ와 달리 글쓴이가 처한 상황을 극복하게 하는 역할로 명시되어 있지 않습니다.
#
# 따라서 ⑤번 선택지가 ⓐ와 ⓑ의 역할을 가장 적절하게 설명하고 있습니다.
# 📌 예측 결과: None
# ✅ 정답: 5
#
# --- ❓ 문제 27 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - 문제의 <보기>는 "서로 다른 생명체가 각각 이익을 주거나 받는 현상"에 대한 설명을 요구하고 있습니다. 따라서 학생의 말은 이문원의 늙은 나무가 인간의 도움을 받아 성장한 사례를 중심으로, 상호 이익 관계를 설명해야 합니다.
#
# - ① "이문원 동쪽 늙은 나무가 백여 년을 살 수 있었던 것은, 인간이 나무를 보살펴 주었기 때문입니다."는 나무가 인간의 도움을 받아 오래 살았다는 점에서 상호 이익 관계를 설명하고 있습니다.
#
# - ② "글쓴이가 '널찍이 드리운 서늘한 그늘'로 인해 '홀쩍 벗어나 있는 기분'이 든 것은, '이문원 동쪽 늙은 나무'에게서 인간이 이익을 얻은 경우에 해당합니다."는 인간이 나무로부터 그늘을 제공받아 이익을 얻는 상황을 설명하고 있습니다.
#
# - ③ "'풀과 나무'가 '몸을 보전하는 계획'이 있는 것은, '조물주'가 서로 다른 생명체가 이익을 주고받도록 해 준 경우에 해당합니다."는 자연의 조화 속에서 생명체들이 서로 이익을 주고받는 상황을 설명하고 있습니다.
#
# - ④ "'암소'의 '뿔이 구부러져 안쪽으로 향하는 위험을 인간이 '톱으로 잘라서' 해결해 주는 것은, '가축'이 인간에게 의지하며 살아가는 경우에 해당합니다."는 가축이 인간의 도움을 받아 생존하는 상황을 설명하고 있습니다.
#
# - ⑤ "글쓴이가 '이문원 동쪽 늙은 나무'가 '저 깊은 산중 인적 끊긴 골짜기'에서 자란 나무보다 번성하게 자랐다고 한 것은, 인간의 도움이 필요하다는 것을 말하기 위함입니다."는 인간의 도움을 받지 못한 나무와 비교하여 인간의 도움이 필요하다는 점을 강조하고 있지만, 상호 이익 관계를 설명하는 것은 아닙니다. 따라서 <보기>의 설명과 부합하지 않습니다.
# 📌 예측 결과: None
# ✅ 정답: 3
#
# 📘 지문: 2024-09-국어 28~31
# ============================================================
# 📂 이미지 로딩 중...
# 🔀 이미지 4등분 중...
# 🔍 [1/4] 분할 이미지 OCR 중...
# 🔍 [2/4] 분할 이미지 OCR 중...
# 🔍 [3/4] 분할 이미지 OCR 중...
# 🔍 [4/4] 분할 이미지 OCR 중...
# 🔧 GPT 정교화 단계 진행 중...
# 🧠 특수기호 위치 검토 및 보정 중...
# 🗂️ GPT 지문 범위 표시([A], [B] 등) 삽입 중...
#
# --- ❓ 문제 28 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④ 서술자가 특정 인물의 시선을 통해 인물의 특징을 관찰하여 알려 주고 있다.
#
# [해설]
# - [A] 부분에서는 서술자가 장상태의 시선을 통해 권 씨의 외양과 태도를 관찰하고 있습니다. 장상태는 권 씨를 만만한 상대로 보고 화풀이 대상으로 삼으려 하지만, 권 씨는 비굴하지 않고 자신감 있는 태도를 보입니다. 이러한 권 씨의 특징은 장상태의 시선을 통해 드러나며, 이는 서술자가 특정 인물의 시선을 통해 다른 인물의 특징을 관찰하여 알려 주고 있는 것입니다.
#
# - ① 인물의 행위를 사실적으로 그려 내어 내적 갈등을 표면화하고 있다는 설명은 [A] 부분에 적절하지 않습니다. [A] 부분에서는 인물의 외양과 태도에 대한 관찰이 중심입니다.
#
# - ② 과거와 현재를 교차하여 인물이 겪는 인식의 변화를 드러내고 있다는 설명은 [A] 부분에 해당하지 않습니다. [A] 부분은 인물의 외양과 태도에 대한 현재 시점의 관찰입니다.
#
# - ③ 공간적 배경을 구체적으로 묘사하여 인물이 처한 상황을 드러내고 있다는 설명은 [A] 부분에 적절하지 않습니다. [A] 부분은 인물의 외양과 태도에 대한 관찰입니다.
#
# - ⑤ 서술자가 인물의 경험을 삽화 형식으로 나열하여 사건을 입체적으로 보여 주고 있다는 설명은 [A] 부분에 적절하지 않습니다. [A] 부분은 인물의 외양과 태도에 대한 관찰입니다.
# 📌 예측 결과: None
# ✅ 정답: 4
#
# --- ❓ 문제 29 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③번 선택지는 권 씨가 ㉠을 마저 입을지를 선택하는 일이 중요하다고 생각한다고 해석하고 있지만, 지문에서는 권 씨가 제복 착용 문제를 중요하게 생각하는 것이 아니라, 사무직 사원들이 제복 문제로 논쟁하는 것을 비판적으로 바라보고 있음을 보여줍니다. 권 씨는 "한쪽에선 작업 중에 팔이 뭉텅 잘려져 나간 사람이 있고 그 팔 값을 찾아 주려고 투쟁하는 사람들이 있는 반면에 다른 한쪽에선 몸에 걸치는 옷 때문에 자기 인생을 거리는 분들도 계시구나 하는 생각이 들어서 그냥 지나칠 수가 없었습니다."라고 말하며, 제복 문제보다 더 중요한 문제들이 있음을 암시하고 있습니다.
#
# - ①번 선택지는 "이미 끝난 일이야"라는 말로, 일부 남자 사원들이 제복 착용 여부를 결정해야 하는 상황에 직면했음을 나타내고 있습니다. 이는 지문에서 민도식이 "이제 길은 두 가지뿐이야. 나머지 절반을 찾아서 마저 몸에 꿰든가, 아니면 기왕 우리 몸에 입혀진 절반을 아예 벗어 버리든가"라고 말한 부분과 일치합니다.
#
# - ②번 선택지는 "험악해진 분위기"로 인해 제복 착용 문제로 남자 사원들 사이에 소란이 있었음을 나타내고 있습니다. 이는 지문에서 "민도식이 나서서 험악해진 분위기를 간신히 가라앉혔다."라는 부분과 일치합니다.
#
# - ④번 선택지는 아내가 총각 사원이 제복 문제로 회사를 그만두었다는 소문을 믿지 않고 있다는 것을 나타내고 있습니다. 이는 지문에서 "제복 때문에 총각 사원 하나가 사표를 던졌다는 소문을 아내는 믿지 않았다."라는 부분과 일치합니다.
#
# - ⑤번 선택지는 "검정 곤색 일색"으로 체육 대회에 참석한 전체 사원이 제복을 마저 입게 되었음을 나타내고 있습니다. 이는 지문에서 "검정 군색 일색의 운동장을 내려다보는 순간"이라는 부분과 일치합니다.
# 📌 예측 결과: None
# ✅ 정답: 3
#
# --- ❓ 문제 30 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤ 선택지는 "e는 사원들이 사복을 입은 민도식에 대한 불만을 드러내는 반응이다."라고 설명하고 있습니다. 그러나 지문에서는 민도식이 사복 차림으로 체육 대회에 참석했을 때, "검정 곤색의 제복들이 일치단결해 가지고 사복 차림으로 꽁무니에 따라붙으려는 유일한 사람을 완강히 거부하는 듯한 기분에 사로잡혔다."고 서술하고 있습니다. 이는 사원들이 민도식에 대해 직접적인 불만을 드러낸 것이 아니라, 민도식이 그렇게 느꼈다는 것을 나타내는 것이므로, 선택지의 설명은 부적절합니다.
#
# - ① 선택지는 권 씨가 사무직 사원들의 대화에 관심을 가지고 있었다는 것을 나타내며, 이는 권 씨가 "말씀 내용이 동림산업에 계신 분들 같아서 저도 모르게 관심이 갔나 봅니다."라고 말한 부분과 일치합니다.
#
# - ② 선택지는 미스 윤이 장상태의 큰 소리 명령에 반응한 것을 설명하고 있으며, 이는 "눈이 휘둥그레진 미스 윤이 종종걸음으로 그에게 다가가기 전에 그쪽에서 자진해서 먼저 일어섰다."는 부분과 일치합니다.
#
# - ③ 선택지는 아내가 남편 민도식이 집을 나서지 않자 걱정하는 반응을 설명하고 있으며, 이는 "아내는 시종 근심스런 눈초리를 거두지 않았다."는 부분과 일치합니다.
#
# - ④ 선택지는 민도식이 제복을 입은 사원들이 도열한 모습을 보고 숨이 막히는 반응을 설명하고 있으며, 이는 "민도식은 갑자기 숨이 턱 막혀 옴을 느꼈다."는 부분과 일치합니다.
# 📌 예측 결과: None
# ✅ 정답: 5
#
# --- ❓ 문제 31 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - ② 선택지는 민도식이 '작업 중' 사고를 둘러싼 '투쟁'과 '몸에 걸치는 옷'을 둘러싼 논쟁에 적극적으로 참여하고 있지 않다고 설명하고 있습니다. 그러나 지문에서는 민도식이 동료들에게 경영자의 숨은 의도를 파악하여 발언하는 장면이 나옵니다. 이는 민도식이 회사의 논리에 대해 비판적으로 인식하고 있다는 것을 보여주며, 이는 <보기>에서 설명하는 '중도적 주인공'의 인식 측면에 부합합니다. 따라서 ②는 적절하지 않은 설명입니다.
#
# - ① 선택지는 민도식이 '준비 위원회'의 '회의'에 담긴 '경영자'의 숨은 의도를 파악하여 발언하는 것을 통해 '동림산업'의 논리에 대해 비판적으로 인식하고 있음을 보여줍니다. 이는 <보기>에서 설명하는 '중도적 주인공'의 인식 측면에 부합하므로 적절합니다.
#
# - ③ 선택지는 민도식이 아내에게 큰소리로 자신의 생각을 말하면서도 결국 집을 나서는 모습을 통해, 회사의 문제를 인식하고 있으면서도 회사를 떠나지 못하는 상황에 놓여 있음을 보여줍니다. 이는 <보기>에서 설명하는 '중도적 주인공'의 행동 측면에 부합하므로 적절합니다.
#
# - ④ 선택지는 민도식이 사복 차림으로 체육 대회에 가지만 자신을 집단에 소속되고 싶은 마음도 지니고 있다고 설명합니다. 이는 <보기>에서 설명하는 '중도적 주인공'의 행동 측면에 부합하므로 적절합니다.
#
# - ⑤ 선택지는 민도식이 '제1 공장' 정문 앞에서 '발버둥 버린 듯' 움직이지 않는 모습을 통해, 정책에 대한 비판을 적극적인 행동으로 옮길지 여부를 결정하지 못하고 있음을 보여줍니다. 이는 <보기>에서 설명하는 '중도적 주인공'의 행동 측면에 부합하므로 적절합니다.
# 📌 예측 결과: None
# ✅ 정답: 2
#
# 📘 지문: 2024-09-국어 32~34
# ============================================================
# 📂 이미지 로딩 중...
# 🔀 이미지 4등분 중...
# 🔍 [1/4] 분할 이미지 OCR 중...
# 🔍 [2/4] 분할 이미지 OCR 중...
# 🔍 [3/4] 분할 이미지 OCR 중...
# 🔍 [4/4] 분할 이미지 OCR 중...
# 🔧 GPT 정교화 단계 진행 중...
# 🧠 특수기호 위치 검토 및 보정 중...
# 🗂️ GPT 지문 범위 표시([A], [B] 등) 삽입 중...
#
# --- ❓ 문제 32 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ① 말을 건네는 방식을 통해 화자의 요구를 전달하고 있다.
#
# [해설]
# - (가), (나), (다) 모두에서 화자는 특정 대상에게 말을 건네는 방식을 사용하여 자신의 요구나 바람을 전달하고 있습니다.
#   - (가)에서는 "허술한 배 두신 분네는 모두 조심하소서"라는 표현을 통해 배를 소유한 사람들에게 주의를 당부하고 있습니다.
#   - (나)에서는 "온 놈이 온 말을 하여도 임이 짐작하소서"라는 표현을 통해 임에게 자신의 마음을 알아주기를 요청하고 있습니다.
#   - (다)에서는 각 수마다 "아이야"라는 호칭으로 시작하여 아이에게 특정 행동을 요구하고 있습니다. 예를 들어, "아이야 구럭 망태 찾아라"와 같은 표현이 있습니다.
#
# - ② 의인화는 지문에서 뚜렷하게 나타나지 않으며, 자연과의 유대감을 드러내는 방식으로 사용되지 않았습니다.
# - ③ 과거와 현재의 대비를 통해 미래에 대한 전망을 드러내는 내용은 지문에서 확인되지 않습니다.
# - ④ 물음의 방식은 (가)와 (나)에서 사용되었으나, (다)에서는 명령형 문장이 주로 사용되어 물음의 방식이 일관되게 나타나지 않습니다.
# - ⑤ 풍경의 사실적 묘사를 통한 계절의 변화상은 지문에서 명확하게 드러나지 않습니다.
# 📌 예측 결과: None
# ✅ 정답: 1
#
# --- ❓ 문제 33 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③번 선택지는 <제1수> 종장과 <제3수> 종장에서 화자의 걱정이 강화된다고 했지만, 이는 사실과 다릅니다. <제1수>의 종장에서는 "이 몸이 이 나물 아니면 조석 어이 지내리"라고 하여 고사리가 없으면 끼니를 해결할 수 없다는 소박한 생활을 드러내고 있으며, 이는 걱정보다는 현실적인 생활의 모습을 보여주는 것입니다. <제3수>의 종장에서는 "성세궁경도 역군은이시니라"라고 하여 태평한 세월에 농사를 짓는 것이 임금의 은혜라는 긍정적인 인식을 드러내고 있습니다. 따라서 두 종장 모두 화자의 걱정을 강화하는 것이 아니라, 소박한 생활과 긍정적인 인식을 드러내고 있습니다.
#
# - ①번 선택지는 각 수의 첫 음보가 "아이야"로 시작하여 시상 전개에 안정감을 부여하고 있다는 점에서 적절합니다.
# - ②번 선택지는 <제1수>와 <제2수>에서 각각 "구럭 망태"와 "도롱이 삿갓" 같은 생활 도구를 언급하여 화자의 생활 모습을 보여주고 있다는 점에서 적절합니다.
# - ④번 선택지는 <제1수> 종장과 <제3수> 초장에서 각각 "이 몸이 이 나물 아니면 조석 어이 지내리"와 "죽조반 다오"라는 표현을 통해 간단한 먹을거리를 언급하여 소박한 생활을 드러내고 있다는 점에서 적절합니다.
# - ⑤번 선택지는 <제4수> 종장에서 "어즈버"라는 감탄 표현을 활용하여 시상을 집약하고 있다는 점에서 적절합니다.
# 📌 예측 결과: None
# ✅ 정답: 3
#
# --- ❓ 문제 34 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③번 선택지는 '심의산'과 '오뉴월'의 '자취눈'을 화자의 심회와 복잡한 심정으로 비유하고 있으며, 이를 통해 당쟁의 상황에서 굳은 마음을 견지하려는 화자의 의지를 드러낸다고 해석하고 있습니다. 그러나 (나)의 초장과 종장은 화자의 복잡한 심정과 임에 대한 간절한 마음을 드러내고 있으며, 당쟁의 상황에서 굳은 마음을 견지하려는 의지를 명확히 드러내고 있지 않습니다. 따라서 이 선택지는 부적절합니다.
#
# - ①번 선택지는 '풍파'를 험난한 정치 현실로, '일렁이던 배'를 시련을 겪은 관료로 해석하여, (가)의 초장이 당쟁에 휘말린 사람이 정치적 소외 상태에 놓인 것을 의미한다고 했습니다. 이는 지문과 <보기>의 설명에 부합합니다.
#
# - ②번 선택지는 '구름이 험하거늘'을 정치적 위기의 조짐으로, '허술한 배 두신 분네'를 신진 관료로 해석하여, (가)의 종장이 정치 경험이 부족한 이들에게 정치의 험난함을 알려주는 것이라고 했습니다. 이는 지문과 <보기>의 설명에 부합합니다.
#
# - ④번 선택지는 '온 놈이 온 말을 하는 상황'을 비방과 모략이 난무하는 현실로, '임'을 임금으로 해석하여, (나)의 종장이 온갖 참소를 임금이 잘 판단해 달라는 것이라고 했습니다. 이는 지문과 <보기>의 설명에 부합합니다.
#
# - ⑤번 선택지는 '미늘 없는 낚시'를 욕심 없이 사는 삶으로 해석하여, (다)의 <제2수> 종장이 자연과 더불어 지내는 화자의 흥을 드러내는 것이라고 했습니다. 이는 지문과 <보기>의 설명에 부합합니다.
# 📌 예측 결과: None
# ✅ 정답: 3

# %%
run_tutor_inference(base_path, "2024", sessions=["수능"])
# Out:
# 📘 지문: 2024-수능-국어 18~21
# ============================================================
# 📂 이미지 로딩 중...
# 🔀 이미지 4등분 중...
# 🔍 [1/4] 분할 이미지 OCR 중...
# 🔍 [2/4] 분할 이미지 OCR 중...
# 🔍 [3/4] 분할 이미지 OCR 중...
# 🔍 [4/4] 분할 이미지 OCR 중...
# 🔧 GPT 정교화 단계 진행 중...
# 🧠 특수기호 위치 검토 및 보정 중...
# 🗂️ GPT 지문 범위 표시([A], [B] 등) 삽입 중...
#
# --- ❓ 문제 18 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 복록의 상황에 대해 언급하고 있습니다. 그러나 지문에서는 복록이 자신이 지은 '죄'에 대해 심리적 중압감을 느꼈다는 구체적인 내용이 드러나지 않습니다. 따라서 이 선택지는 지문과 일치하지 않는 내용입니다.
#
# - ①번 선택지는 ㉠에서 호첩에게 묻는 '연고'의 내용이 왕비가 말한 '사연'과 관련이 있다는 점을 지적하고 있습니다. 이는 지문에서 승상이 호첩에게 집안의 변고를 물었고, 왕비가 정렬부인의 모략에 대해 말한 것과 관련이 있습니다.
#
# - ②번 선택지는 승상이 황상에게 올린 '상소'의 내용이 '이미 아는 바'와 같다는 점을 언급하고 있습니다. 지문에서 승상은 왕비에게 "이 일은 소자가 이미 아는 바이오니 염려 마옵소서"라고 말하며, 상소를 통해 사건의 전말을 아뢰고 있습니다.
#
# - ③번 선택지는 ㉡에서 승상이 '사연'의 진상을 밝히는 데 왕비가 '그놈'의 행위를 알게 된 경위가 중요하다고 생각했다는 점을 지적하고 있습니다. 이는 지문에서 승상이 왕비에게 "처음에 그놈이 충렬부인 방에 간 줄 어찌 알으셨나이까?"라고 물은 부분과 일치합니다.
#
# - ④번 선택지는 ㉡에 대한 왕비의 대답에서 왕비에게 '그놈'의 행위에 대해 제보한 사람이 있었다는 점을 언급하고 있습니다. 이는 왕비가 "사촌 오라비가 이르기로 알았노라"고 답한 부분과 일치합니다.
# 📌 예측 결과: None
# ✅ 정답: 2
#
# --- ❓ 문제 19 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 지문에서 충렬부인이 누명을 벗게 되는 계기를 정확히 설명하고 있습니다. 지문에서 승상이 왕비가 자결하려 하자 "모친이 너무 과도히 하시면 소자가 먼저 죽으려 하나이다."라고 하며 만류하는 장면이 있습니다. 이로 인해 왕비가 자결을 멈추고, 충렬부인의 누명이 벗겨지게 됩니다.
#
# - ①번 선택지는 누명을 썼던 인물인 충렬부인이 자신의 어리석음을 탓하는 장면이 지문에 나타나지 않으므로 틀렸습니다.
# - ②번 선택지는 누명을 쓴 인물의 요청으로 남주인공이 처벌을 유보하는 내용이 지문에 없으므로 틀렸습니다.
# - ③번 선택지는 누명의 내용이 충렬부인이 구덩이에 있다는 사실과 관련이 없으므로 틀렸습니다. 누명은 정렬부인의 모략으로 인해 충렬부인이 옥에 갇힌 사건과 관련이 있습니다.
# - ④번 선택지는 누명을 씌우기 위한 계략에 특정 장소로 가게 하는 것이 포함되었다는 설명이 지문에 명시되어 있지 않으므로 틀렸습니다.
# 📌 예측 결과: None
# ✅ 정답: 4
#
# --- ❓ 문제 20 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④ 옥졸 - 승상: A가 B에게, 금연이 옥중 시신에 대하여 발설했을 것이라는 의혹을 제기함.
#
# [해설]
# - 문제는 인물 간의 소통 내용을 정리하는 것이므로, 지문에서 인물들이 서로 어떤 정보를 주고받았는지를 확인해야 합니다.
# - ① 원수 - 중군장: 지문에서 "나는 집에 변이 있어 먼저 가니 중군장은 차후에 인솔하여 오라."라는 부분에서 원수가 중군장에게 명령을 내리는 장면이 있습니다. 따라서 적절합니다.
# - ② 승상 - 월매: 지문에서 승상이 월매에게 "충렬부인은 어디 계시냐?"라고 물어보는 장면이 있습니다. 따라서 적절합니다.
# - ③ 옥졸 - 금연: 지문에는 옥졸과 금연 간의 대화가 직접적으로 나타나지 않지만, 금연이 옥중 시신의 정체와 관련된 정보를 알고 있다는 점에서 간접적으로 적절하다고 볼 수 있습니다.
# - ④ 옥졸 - 승상: 지문에는 옥졸이 승상에게 금연이 옥중 시신에 대해 발설했을 것이라는 의혹을 제기하는 장면이 없습니다. 따라서 부적절합니다.
# - ⑤ 금연 - 승상: 지문에서 승상이 금연에게 "처음에 그놈이 충렬부인 방에 간 줄 어찌 알으셨나이까?"라고 물어보는 장면이 있습니다. 따라서 적절합니다.
# 📌 예측 결과: None
# ✅ 정답: 1
#
# --- ❓ 문제 21 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③ 선택지는 왕비가 ‘앙천통곡’하는 장면에서 충렬부인의 수난이 ‘악녀’의 탓이라는 인식이 드러나면서 일부다처제의 문제가 개인의 인성 문제로 축소되고 있음을 설명하고 있습니다. 그러나 지문에서는 왕비가 자신의 잘못을 인정하고 자결하려는 장면이 나오며, 이는 왕비가 자신의 판단 실수를 인정하는 것이지, 단순히 '악녀'의 탓으로 돌리는 것이 아닙니다. 따라서 이 선택지는 지문과 일치하지 않습니다.
#
# - ① 선택지는 정을선이 황상에게 올린 상소에서 대원수와 가장으로서의 모습이 드러나는 것을 설명하고 있습니다. 이는 지문에서 정을선이 군사적 문제와 가정 문제 모두에 관여하고 있음을 보여주므로 적절합니다.
#
# - ② 선택지는 승상이 충렬부인을 구출하는 장면에서 인물의 고난과 감정이 극대화된 형상임을 설명하고 있습니다. 지문에서 충렬부인이 야위어 뼈가 드러난 모습과 승상의 통곡하는 모습은 이러한 극대화를 잘 보여줍니다.
#
# - ④ 선택지는 월매가 매를 맞는 장면에서 월매가 능동적인 행위자로 지향하고 있음을 설명하고 있습니다. 지문에서 월매는 죽음을 각오하고 진실을 밝히려는 모습을 보이므로 적절합니다.
#
# - ⑤ 선택지는 정렬부인이 승상의 호통 소리에 반응하는 장면에서 상층 인물이 희화화되고 있음을 설명하고 있습니다. 이는 정렬부인이 승상의 호통 소리에 놀라 자빠지는 장면을 통해 상층 인물의 위엄이 실추되는 모습을 보여주므로 적절합니다.
# 📌 예측 결과: None
# ✅ 정답: 4
#
# 📘 지문: 2024-수능-국어 22~27
# ============================================================
# 📂 이미지 로딩 중...
# 🔀 이미지 4등분 중...
# 🔍 [1/4] 분할 이미지 OCR 중...
# 🔍 [2/4] 분할 이미지 OCR 중...
# 🔍 [3/4] 분할 이미지 OCR 중...
# 🔍 [4/4] 분할 이미지 OCR 중...
# 🔧 GPT 정교화 단계 진행 중...
# 🧠 특수기호 위치 검토 및 보정 중...
# 🗂️ GPT 지문 범위 표시([A], [B] 등) 삽입 중...
#
# --- ❓ 문제 22 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④ 특정한 행위를 중심으로 행위 주체와 대상의 관계를 드러낸다.
#
# [해설]
# - (가), (나), (다) 세 지문 모두 특정한 행위를 중심으로 행위 주체와 대상의 관계를 드러내고 있습니다.
#   - (가)에서는 '배를 밀다'라는 행위를 통해 배와 바다, 그리고 그 배를 미는 주체의 관계를 드러내고 있습니다. 배를 밀어내는 행위는 사랑과 슬픔을 밀어내는 행위로 비유되며, 이러한 행위를 통해 주체의 감정과 대상(배, 바다)과의 관계가 표현됩니다.
#   - (나)에서는 '당신'이라는 말을 부르는 행위를 통해 화자와 '당신'의 관계를 드러내고 있습니다. 화자가 '당신'을 부르는 행위는 그리움과 기대, 상처와 위로의 감정을 담고 있으며, 이러한 행위를 통해 화자와 '당신'의 관계가 부각됩니다.
#   - (다)에서는 '편지를 쓰다'라는 행위를 통해 화자와 편지의 수신자, 그리고 편지 속의 '자신'과의 관계를 드러내고 있습니다. 편지를 쓰는 행위는 고백과 자기 성찰의 과정을 담고 있으며, 이러한 행위를 통해 화자와 수신자, 그리고 화자 자신의 관계가 표현됩니다.
#
# - 나머지 선택지들은 다음과 같은 이유로 적절하지 않습니다:
#   - ① 하강적 이미지를 활용하여 시간의 흐름을 보여 준다는 설명은 지문에서 명확히 드러나지 않습니다.
#   - ② 자연물에 빗대어 부정적 현실의 극복 가능성을 암시한다는 설명은 지문에서 명확히 드러나지 않습니다.
#   - ③ 동일한 구절의 반복과 변주를 통해 상황의 반전을 표현한다는 설명은 지문에서 명확히 드러나지 않습니다.
#   - ⑤ 공간의 이동에 따라 내용을 전개하여 역동적 분위기를 강화한다는 설명은 지문에서 명확히 드러나지 않습니다.
# 📌 예측 결과: None
# ✅ 정답: 4
#
# --- ❓ 문제 23 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 지문 (가)에서 '밀려들어 온 배'가 '아무 소리 없이' 돌아오는 것을 '대상과의 재회가 예상대로 이루어짐'으로 해석하고 있습니다. 그러나 지문에서는 '내 안으로 들어오는 배여'라는 표현을 통해 배가 돌아오는 상황을 묘사하고 있지만, 이는 실제 재회가 이루어졌다는 확정적인 의미보다는, 화자의 내면으로 들어오는 감정의 흐름을 상징적으로 표현한 것으로 볼 수 있습니다. 따라서 '대상과의 재회가 예상대로 이루어짐'이라는 해석은 지문과 일치하지 않습니다.
#
# - ①번 선택지는 '아주 추락하지 않을 순간'에 '배를 밀던 손'이 '아슬아슬히 배에서 떨어진다'는 표현을 통해 이별의 정서적 긴장감을 드러내고 있습니다. 이는 지문에서 배를 밀어내는 순간의 긴장감과 불안함을 잘 표현하고 있습니다.
#
# - ②번 선택지는 '뵈지도 않는 길'을 '사랑이 떠나는 길'로 해석하여 이별의 막막한 상황을 공간적으로 형상화한 것으로, 지문에서 '벼지도 않는 길'이라는 표현과 일치합니다.
#
# - ③번 선택지는 '슬픔을 밀어내는 것'을 '배를 밀듯 한껏 세게 밀어낸다'고 표현하여 이별의 아픔을 떨쳐 내려는 화자의 태도를 드러내고 있습니다. 이는 지문에서 슬픔을 밀어내는 행위를 배를 밀어내는 행위에 비유한 것과 일치합니다.
#
# - ④번 선택지는 '배가 나가며 생긴 흉터가 잠시 머물다 가라앉는다'는 표현을 통해 이별의 슬픔이 잦아드는 상태를 드러내고 있습니다. 이는 지문에서 배가 나간 후 남은 물 위의 흉터가 가라앉는다는 표현과 일치합니다.
# 📌 예측 결과: None
# ✅ 정답: 5
#
# --- ❓ 문제 24 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - ②번 선택지는 '당신'이 화자의 내면에 살고 있는 '병자'로서 연민의 대상이라고 설명하고 있습니다. 그러나 지문 (나)에서 '당신'은 화자가 '킥킥'거리며 부르는 대상으로, 화자의 내면에 있는 병자와 동일시되거나 연민의 대상으로 표현되지 않습니다. '당신'은 화자가 부름으로써 환기되는 대상이며, 화자가 버릴 수 없고 무를 수도 없는 숙명적 존재로 나타납니다. 따라서 ②번 선택지는 지문과 일치하지 않습니다.
#
# - ①번 선택지는 '당신'이 화자와 '한때'의 기억을 잇는 매개적 존재라고 설명하고 있습니다. 지문에서 화자는 '당신'을 부르며 한때의 적요로움과 슬픔을 떠올리고 있어, 이는 적절한 설명입니다.
#
# - ③번 선택지는 '당신'이 화자의 눈앞에 없지만 '부름'으로써 환기되는 대상이라고 설명하고 있습니다. 지문에서 화자는 '당신'을 부르며 그 존재를 환기하고 있으므로, 이는 적절한 설명입니다.
#
# - ④번 선택지는 '당신'이 화자가 '버릴 수 없고' '무를 수도 없는' 숙명적 존재라고 설명하고 있습니다. 지문에서 화자는 '당신'을 '끝내 버릴 수 없는, 무를 수도 없는' 존재로 표현하고 있어, 이는 적절한 설명입니다.
#
# - ⑤번 선택지는 '당신'이 화자에게 '사랑'과 '슬픔'을 경험하게 하는 이중적 존재라고 설명하고 있습니다. 지문에서 화자는 '당신'을 부르며 사랑과 슬픔의 복합적인 감정을 드러내고 있어, 이는 적절한 설명입니다.
# 📌 예측 결과: None
# ✅ 정답: 2
#
# --- ❓ 문제 25 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - ②번 선택지는 "상처에 기대, 나 킥킥……, 당신을 부릅니다"라는 구절을 상실의 고통으로 인해 사랑의 기억이 희미해지는 화자의 심적 상태를 보여주는 표현으로 해석하고 있습니다. 그러나 이 구절에서 화자는 상처에 기대어 '당신'을 부르는 행위를 통해 사랑의 기억을 떠올리고 있으며, 이는 오히려 상실의 고통 속에서도 사랑의 기억이 희미해지지 않고 지속되고 있음을 나타냅니다. 따라서 이 선택지는 적절하지 않습니다.
#
# - ①번 선택지는 '킥킥'이라는 의성어가 반복적으로 사용되어 화자의 복합적인 정서를 드러내는 표현임을 설명하고 있으며, 이는 지문의 내용과 일치합니다.
#
# - ③번 선택지는 "킥킥거리며 세월에 대해 혹은 사랑과 상처,"라는 구절이 맥락이 없어 보이는 표현들이 이어진 서술로, 화자의 복합적인 내면을 드러내는 표현임을 설명하고 있으며, 이는 지문의 설명과 일치합니다.
#
# - ④번 선택지는 '마음의 무덤'이라는 표현이 화자의 심적 상태를 형상화하여 상실의 고통을 안고 살아가는 내면을 비유한 것임을 설명하고 있으며, 이는 지문의 내용과 일치합니다.
#
# - ⑤번 선택지는 "이쁜 당신……, 당신이라는 말 참 좋지요,"라는 구절이 끊어질 듯 이어지는 서술로, 대상에 대한 사랑의 감정을 품고 있는 화자의 내면을 드러내는 표현임을 설명하고 있으며, 이는 지문의 내용과 일치합니다.
# 📌 예측 결과: None
# ✅ 정답: 2
#
# --- ❓ 문제 26 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ㉠과 ㉡에 대한 이해를 묻는 문제입니다. ㉠은 "치병과 환후는 각각 따로인 것을"이라는 구절로, 치병(병을 다스림)과 환후(병을 정중하게 이르는 말)가 서로 다른 것임을 인식하고 있음을 나타냅니다. 이는 아픔의 실체를 자각하지 못하고 있다는 것을 의미합니다. ㉡은 "누군가가 듣기를 바라는 모든 고백이란, 위선이 아니면 위악이다"라는 구절로, 고백의 실체가 위선이나 위악임을 자각하지 못하고 있다는 것을 나타냅니다. 따라서 ㉠과 ㉡ 모두 아픔이나 고백의 실체를 자각하지 못하고 있다는 점에서 ⑤번이 가장 적절합니다.
#
# - ①은 ㉠의 내용과 관련이 없습니다. ㉠은 치병과 환후가 각각 따로인 것을 인식하고 있다는 내용이지, 치병의 노력으로 환후가 사라지지 않는다는 내용이 아닙니다.
# - ②는 ㉠의 내용과 맞지 않습니다. ㉠은 화자가 대상의 아름다움을 발견하여 환후를 의식하지 않게 되었다는 내용이 아닙니다.
# - ③은 ㉡의 내용과 맞지 않습니다. ㉡은 사랑의 편지가 위선과 위악에서 벗어날 수 있다는 내용이 아니라, 고백이 위선이나 위악임을 자각하지 못한다는 내용입니다.
# - ④는 ㉡의 내용과 관련이 없습니다. ㉡은 더 나은 자신을 드러내려는 욕망이 상대를 매혹하는 요인이라는 내용이 아닙니다.
# 📌 예측 결과: None
# ✅ 정답: 1
#
# --- ❓ 문제 27 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ①
#
# [해설]
# - ① 선택지는 '익명의 욕구'를 '통제할 수 없다'는 것을 '사랑이 운명적이어서 멈출 수 없다'고 해석하고 있습니다. 그러나 지문에서는 '익명의 욕구'가 '편지의 현실적인 목표를 잊어버리게 만든다'고 설명하고 있습니다. 즉, '익명의 욕구'는 사랑의 운명성을 의미하는 것이 아니라, 편지가 본래 의도와 달리 자기 고백으로 변질되는 과정을 설명하는 것입니다. 따라서 ①은 적절하지 않은 선택지입니다.
#
# - ② 선택지는 '아무 전언도 들어 있지 않다'는 것이 '처음에 품었던 소소한 의도'를 잊음으로써 상대를 향한 글쓰기의 '현실적인 목표'가 실패로 돌아갔음을 의미한다고 설명하고 있습니다. 이는 지문에서 '모든 사랑의 편지는 마지막 순간, 도구적이지 못하다'는 부분과 일치합니다. 따라서 적절한 선택지입니다.
#
# - ③ 선택지는 '2인칭을 경유하여 1인칭으로 돌아온다'는 것이 편지가 상대를 향한 '도구적' 기능을 하지 못하고 자기 고백에 그치게 됨을 의미한다고 설명하고 있습니다. 이는 지문에서 '고백이란 결국 2인칭을 경유하여 1인칭으로 돌아온다'는 부분과 일치합니다. 따라서 적절한 선택지입니다.
#
# - ④ 선택지는 '편지 속의 그를 그녀는 사랑했다'는 것이 편지를 받은 그녀가 사랑한 상대는 편지 속의 '또 다른 영혼'임을 의미한다고 설명하고 있습니다. 이는 지문에서 '정확하게 말하면 '편지 속의 그'를 그녀는 사랑했다'는 부분과 일치합니다. 따라서 적절한 선택지입니다.
#
# - ⑤ 선택지는 '자신의 비루함을 뼈속 깊이 실감했다'는 것이 실제 자신과 이상화된 자신 사이의 간극을 자각한 '그'가 부끄러움에 빠져 있음을 의미한다고 설명하고 있습니다. 이는 지문에서 '그는 '편지 속의 그'를 연기하는 것이 부끄러웠고, 자신의 비루함을 뼛속 깊이 실감했다'는 부분과 일치합니다. 따라서 적절한 선택지입니다.
# 📌 예측 결과: None
# ✅ 정답: 1
#
# 📘 지문: 2024-수능-국어 28~31
# ============================================================
# 📂 이미지 로딩 중...
# 🔀 이미지 4등분 중...
# 🔍 [1/4] 분할 이미지 OCR 중...
# 🔍 [2/4] 분할 이미지 OCR 중...
# 🔍 [3/4] 분할 이미지 OCR 중...
# 🔍 [4/4] 분할 이미지 OCR 중...
# 🔧 GPT 정교화 단계 진행 중...
# 🧠 특수기호 위치 검토 및 보정 중...
# 🗂️ GPT 지문 범위 표시([A], [B] 등) 삽입 중...
#
# --- ❓ 문제 28 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④ ㉣: 인물의 상황에 관련된 정보를 부가하여 서술하고 있다.
#
# [해설]
# - ㉣ 부분에서는 "어느 해 여름이었다. 하니까 그것은 허원이 자신의 배꼽을 잃어버리고 나서 불편하기 그지없는 세 번째의 여름을 맞고 있을 때였다."라는 문장을 통해, 허원이 배꼽을 잃어버린 후 세 번째 여름을 맞이하고 있다는 상황적 정보를 부가하여 서술하고 있습니다. 이로 인해 허원의 심리적 상태와 그가 처한 상황에 대한 이해를 돕고 있습니다.
#
# - ① ㉠: "불편스런 일이 한두 가지가 아니었다."라는 문장은 허원의 생각을 서술하고 있지만, 누가 말하는지를 명시한 표현은 아닙니다. 따라서 적절하지 않습니다.
#
# - ② ㉡: "그깟 놈의 배꼽, 안 가지고 있음 어때."라는 문장은 허원의 생각을 직접적으로 드러내고 있으며, 서술자가 이를 평가하거나 심화된 의미를 함축하여 서술하지는 않습니다.
#
# - ③ ㉢: "자신으로부터 배꼽이 사라져 버린 사실을..." 부분은 인물의 의식을 서술자가 전달하는 방식이지, 인물 자신의 생생한 목소리를 통해 서술하는 것은 아닙니다.
#
# - ⑤ ㉤: "배꼽에 관한 논의가 그릇듯 갑자기 시중 일반에게까지 성행하기 시작한 것이다."라는 문장은 인물 행동의 진행 과정을 순차적으로 서술하는 것이 아니라, 배꼽 논의의 확산에 대한 결과를 설명하고 있습니다.
# 📌 예측 결과: None
# ✅ 정답: 4
#
# --- ❓ 문제 29 ---
# 📘 [문학 개념 설명]
# 비밀의 서사적 기능에 대해 설명하자면, 비밀은 주로 인물의 내면적 갈등이나 심리적 변화를 드러내는 중요한 요소입니다. 이와 관련하여 가장 적절한 선택지는 ③번입니다.
#
# ③ 일상적이지 않은 경험을 인물이 의식한다는 표지로, 인물의 심리적 동요를 부른다.
#
# 이 선택지는 비밀이 인물의 심리적 상태에 미치는 영향을 강조하며, 비밀이 드러나면서 인물의 내면적 갈등이나 동요가 발생하는 과정을 잘 설명하고 있습니다.
# 📌 예측 결과: None
# ✅ 정답: 3
#
# --- ❓ 문제 30 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 '허원'이 '실물'에 대한 인식을 '세상 사람들'과 공유하게 되면서, 그간 이어 온 '사념'을 더 이상 지속하지 않게 된다고 설명하고 있습니다. 그러나 지문에서는 허원이 배꼽에 대한 사념을 지속하고 있으며, 오히려 세상 사람들의 관심이 배꼽에 쏠리면서 그의 사념은 더욱 확고해지고 있습니다. 따라서 ⑤번 선택지는 지문과 일치하지 않는 내용입니다.
#
# - ①번 선택지는 허원이 자신의 배꼽이 사라진 후, 사념을 통해 존재의 의미를 발견해 가는 과정을 설명하고 있습니다. 이는 지문에서 허원이 배꼽에 대한 사념을 통해 존재의 비밀을 탐구하는 과정과 일치합니다.
#
# - ②번 선택지는 허원이 배꼽이 큰 기능을 하지 않는다는 것을 알고 안도감을 느끼는 부분을 설명하고 있습니다. 이는 지문에서 허원이 배꼽이 사라졌지만 외모나 바깥 생활에 큰 지장이 없다는 점에서 안도감을 느끼는 부분과 일치합니다.
#
# - ③번 선택지는 허원이 사념을 통해 자신의 현재 상태를 다른 방향에서 접근하고자 한다는 내용을 담고 있습니다. 이는 허원이 배꼽에 대한 사념을 통해 자신의 존재와 세계를 이해하려는 시도와 일치합니다.
#
# - ④번 선택지는 허원이 세상 사람들의 배꼽에 대한 관심의 원인에 대해 궁금해하며 주의를 기울이는 부분을 설명하고 있습니다. 이는 지문에서 허원이 세상 사람들의 배꼽에 대한 관심을 인식하고 주의를 기울이는 부분과 일치합니다.
# 📌 예측 결과: None
# ✅ 정답: 5
#
# --- ❓ 문제 31 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④
#
# [해설]
# - ④번 선택지는 "그의 사념이 도달한 '배꼽론'의 '확고한 경지'는 사소한 것의 심층적 의미를 탐색할 때 이를 수 있으므로, 그 사소한 것에 얽매이지 않는 자유로운 상태에서 실현이 가능해지겠군."이라고 설명하고 있습니다. 그러나 지문에서는 허원이 배꼽에 대한 사념을 통해 심오한 배꼽론을 발전시키면서도 여전히 허전함과 허망감을 느끼고 있다고 서술하고 있습니다. 즉, 허원은 사소한 것에 얽매이지 않는 자유로운 상태에 도달하지 못하고, 오히려 배꼽에 대한 집착이 심화된 상태입니다. 따라서 이 선택지는 지문과 일치하지 않습니다.
#
# - ①번 선택지는 "의식의 끈이 건드려짐으로써 주인공이 비정상적 문제 상황에 지속적으로 주목하게 된 것이겠군."이라고 설명하고 있습니다. 이는 지문에서 허원이 잃어버린 배꼽에 대한 상념에 사로잡혀 있는 상황을 설명하는 것으로, 지문과 일치합니다.
#
# - ②번 선택지는 "회사 출근을 포기하게 되고 늦잠 버릇이 사라진 상황은, 주인공의 일상이 변화된 모습을 보여 준다고 할 수 있겠군."이라고 설명하고 있습니다. 이는 허원이 배꼽에 대한 집착으로 인해 일상생활에 변화가 생긴 것을 나타내며, 지문과 일치합니다.
#
# - ③번 선택지는 "배꼽을 태줄에 연관하여 이해하는 것은, 개인에 관련된 생각을 우주와 만남는 심오하고 추상적인 생각으로 확장하는 실마리가 된다고 할 수 있겠군."이라고 설명하고 있습니다. 이는 허원이 배꼽을 통해 존재의 의미를 탐색하는 과정을 설명하며, 지문과 일치합니다.
#
# - ⑤번 선택지는 "기묘한 현상은, 배꼽 이야기가 일반화되는 상황이 뜻밖이지만 사실로 나타나는 현상을 두고 일컫는 말이라고 할 수 있겠군."이라고 설명하고 있습니다. 이는 지문에서 배꼽에 대한 논의가 일반화되는 상황을 설명하며, 지문과 일치합니다.
# 📌 예측 결과: None
# ✅ 정답: 4
#
# 📘 지문: 2024-수능-국어 32~34
# ============================================================
# 📂 이미지 로딩 중...
# 🔀 이미지 4등분 중...
# 🔍 [1/4] 분할 이미지 OCR 중...
# 🔍 [2/4] 분할 이미지 OCR 중...
# 🔍 [3/4] 분할 이미지 OCR 중...
# 🔍 [4/4] 분할 이미지 OCR 중...
# 🔧 GPT 정교화 단계 진행 중...
# 🧠 특수기호 위치 검토 및 보정 중...
# 🗂️ GPT 지문 범위 표시([A], [B] 등) 삽입 중...
#
# --- ❓ 문제 32 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④ 과거와 현재를 대비하여 악화된 처지를 보여 준다.
#
# [해설]
# - ① 대구 표현으로 외양을 묘사하여 대상의 처지를 드러낸다: (가) 지문에서 "허리 위로 불작시면 베적삼이 깃만 남고 허리 아래 굽어보니 헌 잠방이 노닥노닥"이라는 표현은 대구법을 사용하여 외양을 묘사하고 있으며, 이를 통해 대상의 처지를 드러내고 있다.
# - ② 행위의 실행을 가정하여 부정적 전망을 제시한다: "십 리 길을 하루 가니 멀 리 가서 엎어지리"라는 부분은 행위의 실행을 가정하여 부정적인 전망을 제시하고 있다.
# - ③ 의문의 표현을 사용하여 상대의 행적에 대해 의심한다: "네 행색을 보아 하니 군자 도망 네로구나"라는 부분은 의문의 표현을 사용하여 상대의 행적에 대해 의심하고 있다.
# - ④ 과거와 현재를 대비하여 악화된 처지를 보여 준다: (가) 지문에서는 과거와 현재를 대비하여 처지가 악화된 것을 보여주는 부분이 명확하지 않다. 따라서 이 선택지는 적절하지 않다.
# - ⑤ 구체적 수치를 제시하여 감당하기 힘든 현실을 드러낸다: "한 몸 신역 삼 냥 오 전 돈피 두 장 의법이라 열두 사람 없는 구실 합쳐 보면 사십육 냥"이라는 부분은 구체적인 수치를 제시하여 감당하기 힘든 현실을 드러내고 있다.
# 📌 예측 결과: None
# ✅ 정답: 3
#
# --- ❓ 문제 33 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤ ①과 ②은 모두, 각각을 언급하는 화자가 보기에 상대가 했으면 하는 행위의 대상이다.
#
# [해설]
# - ①과 ②는 각각 (가)와 (나)에서 언급된 내용으로, 화자가 상대방에게 권유하거나 기대하는 행위와 관련이 있습니다. (가)에서는 "칠팔월에 인삼 캐고 구시월에 돈피 잡아"라는 부분에서, 화자는 상대방이 특정 시기에 특정한 일을 하기를 기대하고 있습니다. (나)에서는 "이내 말씀 들어 보소 이 내 또한 갑민이라"는 부분에서, 화자는 상대방에게 자신의 말을 들어주기를 기대하고 있습니다. 따라서 두 선택지 모두 화자가 상대방에게 기대하는 행위와 관련이 있습니다.
#
# - ①은 (가)에서 "칠팔월에 인삼 캐고 구시월에 돈피 잡아"라는 부분으로, 화자가 상대방에게 특정 시기에 특정한 일을 하도록 권유하는 내용입니다.
#
# - ②는 (나)에서 "이내 말씀 들어 보소 이 내 또한 갑민이라"는 부분으로, 화자가 상대방에게 자신의 말을 들어주기를 기대하는 내용입니다.
#
# - 오답 설명:
#   - ① ①은 ①을 언급하는 화자가 이주해 가려는 땅에서 재배할 약재이다: (가)에서 인삼은 특정 시기에 캐는 것으로, 이주와 직접적인 관련이 없습니다.
#   - ② ②은 ②을 언급하는 화자가 말을 건네는 상대에게 노동의 대가로 주는 보상이다: (나)에서 노동의 대가로 주는 보상이라는 내용은 없습니다.
#   - ③ ①과 ②은 모두, 각각을 언급하는 화자가 유흥을 목적으로 구하려는 물품이다: (가)와 (나) 모두 유흥과 관련된 내용이 아닙니다.
#   - ④ ①과 ②은 모두, 각각을 언급하는 화자가 획득하려면 상대의 도움이 필요한 대상이다: 인삼과 돈피는 화자가 상대방에게 기대하는 행위이지, 상대의 도움이 필요한 대상이 아닙니다.
# 📌 예측 결과: None
# ✅ 정답: 5
#
# --- ❓ 문제 34 ---
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - ②번 선택지는 (가)의 '이내' 말쌈이 집안의 내력과 사회적 지위를 언급하며 사회의 부조리를 해결하자는 입장이라고 설명하고 있습니다. 그러나 지문을 보면 '이내' 말쌈은 자신의 집안 내력과 현재의 고통스러운 상황을 설명하면서 자신의 어려움을 토로하고 있는 것으로 보입니다. '이내' 말쌈은 사회의 부조리를 해결하자는 입장이라기보다는 자신의 처지를 호소하는 내용입니다. 따라서 이 선택지는 적절하지 않습니다.
#
# - ①번 선택지는 (가)에서 '그대'가 '자네'에게 다른 권유를 하고 있으며, '자네'의 사연이 당시 갑산 백성의 고통을 사실적으로 보여준다고 설명하고 있습니다. 이는 지문에서 '자네'가 자신의 어려운 상황을 설명하고 '그대'가 다른 조언을 하는 대화 구조와 일치합니다.
#
# - ③번 선택지는 (나)에서 선행하는 화자의 요청에 대해 '우리'가 기대에 어긋난 대답을 하면서 대화가 의외의 상황으로 전개된다고 설명하고 있습니다. 이는 (나)의 대화가 의외의 상황으로 전개되는 특징을 잘 설명하고 있습니다.
#
# - ④번 선택지는 (나)에서 '고기'를 누구에게 주라고 명시하지 않아 불완전한 표현이 되었다고 설명하고 있습니다. 이는 대화의 전개 양상에 주목하는 작품의 특징을 설명하는 것으로 적절합니다.
#
# - ⑤번 선택지는 (가)의 '그대'와 (나)의 선행하는 화자가 각각 다른 인물에게 말을 건네고 있어 작품의 상황이 극 중 장면처럼 보인다고 설명하고 있습니다. 이는 두 작품 모두 대화체를 사용하여 극적 장면을 연출하고 있음을 잘 설명하고 있습니다.
# 📌 예측 결과: None
# ✅ 정답: 2

# %% [markdown]
# # **<테스트 결과>**

# %% [markdown]
# ❌ 오답 문항 수
#
# - 2025년 6월: 18, 20, 21, 26, 27, 29, 32 → 7문항
#
# - 2025년 9월: 24, 27 → 2문항
#
# - 2025년 수능: 18, 19, 20, 21, 26, 32 → 6문항
#
# - 총 오답: 15문항

# %% [markdown]
# 🧾 요약
# - 총 문항 수: 51
#
# - 정답 수: 36
#
# - 오답 수: 15
#
# ### **정답률: 약 70.59%**
# - 깔끔한 텍스트에서 실험했을때 틀렸던 문항들이 이번에도 틀리는 모습을 확인
# - 지문 이미지의 텍스트를 잘못 추출했을때 그 지문의 문항들이 틀리는 것 때문에 정답률이 낮아짐
