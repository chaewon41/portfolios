# %% [markdown]
# # **0. 패키지 설치**

# %%
# !pip install openai
# !pip install langchain
# !pip install -U langchain-community
# !pip install pypdf
# !pip install faiss-cpu
# !pip install tiktoken
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.11/dist-packages (1.96.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from openai) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from openai) (0.10.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from openai) (2.11.7)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.11/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.11/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.11/dist-packages (from openai) (4.14.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.11/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (2025.7.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Requirement already satisfied: langchain in /usr/local/lib/python3.11/dist-packages (0.3.26)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.69)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.3.8)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.11/dist-packages (from langchain) (0.4.6)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.11.7)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Collecting langchain-community
#   Downloading langchain_community-0.3.27-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.69)
# Requirement already satisfied: langchain<1.0.0,>=0.3.26 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.3.26)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.41)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (3.11.15)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (8.5.0)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.10.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith>=0.1.125 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (0.4.6)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.1-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.11/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (0.3.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.11/dist-packages (from langchain<1.0.0,>=0.3.26->langchain-community) (2.11.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (1.33)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (4.14.1)
# Requirement already satisfied: packaging>=23.2 in /usr/local/lib/python3.11/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-community) (25.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (3.11.0)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from langsmith>=0.1.125->langchain-community) (0.23.0)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.4.0->langchain-community)
#   Downloading python_dotenv-1.1.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2->langchain-community) (2025.7.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.2.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.66->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<1.0.0,>=0.3.26->langchain-community) (2.33.2)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.3.27-py3-none-any.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 8.0 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.1-py3-none-any.whl (8.1 kB)
# Downloading pydantic_settings-2.10.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 3.0 MB/s eta 0:00:00
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.1 MB/s eta 0:00:00
# Downloading python_dotenv-1.1.1-py3-none-any.whl (20 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: python-dotenv, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pydantic-settings, dataclasses-json, langchain-community
# Successfully installed dataclasses-json-0.6.7 httpx-sse-0.4.1 langchain-community-0.3.27 marshmallow-3.26.1 mypy-extensions-1.1.0 pydantic-settings-2.10.1 python-dotenv-1.1.1 typing-inspect-0.9.0
# Collecting pypdf
#   Downloading pypdf-5.8.0-py3-none-any.whl.metadata (7.1 kB)
# Downloading pypdf-5.8.0-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.7/309.7 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: pypdf
# Successfully installed pypdf-5.8.0
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from faiss-cpu) (25.0)
# Downloading faiss_cpu-1.11.0.post1-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (31.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/31.3 MB 30.9 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0.post1
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (0.9.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2025.7.14)

# %%
from langchain.chat_models import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from langchain.schema.output_parser import StrOutputParser
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings

# %% [markdown]
# # **0. 구글 드라이브 마운트 & api key**

# %%
from google.colab import drive
drive.mount('/content/drive')

import glob
import os
# Out:
# Mounted at /content/drive

# %%
import os
import openai
from langchain.chat_models import ChatOpenAI

#  API 키 설정
OPENAI_API_KEY = ""  # 여기에만 입력하면 아래에서 자동 사용됨
os.environ["OPENAI_API_KEY"] = OPENAI_API_KEY
client = openai.OpenAI(api_key=OPENAI_API_KEY)

# %% [markdown]
# # **1. 문서 업로드 & Retriever**

# %%
import os
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders import UnstructuredPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings
from langchain.retrievers import ContextualCompressionRetriever, EnsembleRetriever
from langchain.retrievers.document_compressors import LLMChainExtractor

# 1. 📥 PDF 로딩 (하위 폴더 포함) + 출처 추적
def load_all_pdfs(root_dir):
    all_docs = []
    for dirpath, _, filenames in os.walk(root_dir):
        for filename in filenames:
            if filename.endswith(".pdf"):
                full_path = os.path.join(dirpath, filename)
                loader = UnstructuredPDFLoader(full_path)
                docs = loader.load()

                for doc in docs:
                    # 📎 source: 상대 경로 기준으로 저장 (예: RAG/작품A.pdf)
                    relative_path = os.path.relpath(full_path, root_dir)
                    doc.metadata["source"] = relative_path
                    doc.page_content = doc.page_content.strip().replace("\n", " ").replace("  ", " ")

                all_docs.extend(docs)
    return all_docs

# 2. 텍스트 분할기
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=100,
    separators=["\n\n", "\n", ".", " ", ""]
)

# 3. 임베딩
embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

# 4. 배치 임베딩
def embed_in_batches(docs, batch_size=100):
    vectorstore = None
    for i in range(0, len(docs), batch_size):
        batch = docs[i:i + batch_size]
        print(f"🔄 Embedding batch {i} ~ {i + len(batch)} / {len(docs)}")
        if vectorstore is None:
            vectorstore = FAISS.from_documents(batch, embedding=embeddings)
        else:
            vectorstore.add_documents(batch)
    return vectorstore

# 5. 저장 경로
VECTORSTORE_PATH = "/content/drive/MyDrive/Colab Notebooks/TAVE 프로젝트_STUBO/문학/faiss_index_답변해설"

# 6. 벡터스토어 생성 또는 로딩
def build_vectorstore():
    root_dir = "/content/drive/MyDrive/Colab Notebooks/TAVE 프로젝트_STUBO/문학/data/RAG"
    all_docs = load_all_pdfs(root_dir)
    split_docs = text_splitter.split_documents(all_docs)
    vectorstore = embed_in_batches(split_docs)
    vectorstore.save_local(VECTORSTORE_PATH)
    return vectorstore

# 7. 리트리버 생성
def get_retriever():
    if os.path.exists(VECTORSTORE_PATH):
        print("📁 기존 벡터스토어 불러오는 중...")
        vectorstore = FAISS.load_local(VECTORSTORE_PATH, embeddings, allow_dangerous_deserialization=True)
    else:
        print("🧠 새 벡터스토어 생성 중...")
        vectorstore = build_vectorstore()

    retriever = vectorstore.as_retriever(
        search_type="mmr",
        search_kwargs={
            "k": 5,
            "score_threshold": 0.5
        }
    )
    return retriever

# 🔄 최종 retriever
retriever = get_retriever()
# Out:
# /tmp/ipython-input-5-2237303118.py:37: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings(model="text-embedding-3-small")
# 📁 기존 벡터스토어 불러오는 중...

# %% [markdown]
# # **2. 개념 답변 QA chain**

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.3)

# 개념 설명 체인
concept_prompt = ChatPromptTemplate.from_template("""
너는 수능 문학 개념을 설명해주는 튜터야. 아래 질문에 대해 간단명료하게 설명해줘.

질문:
{question}
""")

concept_chain = concept_prompt | llm | StrOutputParser()
# Out:
# /tmp/ipython-input-6-3416333025.py:1: LangChainDeprecationWarning: The class `ChatOpenAI` was deprecated in LangChain 0.0.10 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import ChatOpenAI``.
#   llm = ChatOpenAI(model="gpt-4o-mini", temperature=0.3)

# %% [markdown]
# # **3. 문제 답변&해설 QA 체인**

# %%
# 문제 기반 QA RAG 체인
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain.chat_models import ChatOpenAI
from langchain_core.runnables import RunnableLambda

# LLM 설정
llm = ChatOpenAI(model="gpt-4o", temperature=0.3)

# 문제 기반 QA 체인용 프롬프트
qa_prompt = ChatPromptTemplate.from_template("""
당신은 한국 수능 국어 문학 전문 튜터입니다.

다음은 수능 국어 문학 객관식 문제입니다. ①, ②, ③, ④, ⑤ 중 하나를 고르는 객관식 문제이며,
정답은 반드시 지문 및 <보기>의 정확한 분석에 근거해 판단해야 합니다.

🟨 반드시 지켜야 할 분석 기준:

1. 지문 분석을 중심으로 판단하며, **선택지의 내용이 지문과 일치하는지** 엄밀히 검토하세요.
2. 문제에 <보기>가 있다면, <보기> 속 설명(구조, 시점, 표현, 인물 해석 등)을 **지문에 어떻게 적용했는지** 구체적으로 분석하세요.
3. **서술 방식, 인물 심리 표현, 문체, 시점 변화, 지시 표현, 병렬 구조** 등은 서술상·표현상 특징 문제에서 핵심 근거입니다.
4. 참고 자료는 반드시 보조적 용도로만 활용합니다. 절대 지문을 덮어쓰거나 대체해서는 안 됩니다.

📌 답변 형식:

[정답]
- (①, ②, ③, ④, ⑤ 중 하나)

[해설]
- 문제에서 요구한 핵심 요소(예: 표현 방식, 구조, 시점 등)에 따라 왜 정답인지 논리적으로 설명합니다.
- 지문 및 <보기>의 문장을 **직접 인용**하여 명확한 판단 근거를 제시하세요.
- 나머지 오답 선택지들은 각각 왜 틀렸는지를 간단히 설명하세요.

📖 [지문]
{context}

📚 [참고 자료] — 필요 시만 사용 (retriever 제공):
{reference}

🙋‍♂️ [문제 및 <보기>]
{question}
""")

def format_with_retrieved_docs(inputs):
    question = inputs["question"]
    context = inputs["context"]

    # 🔍 관련 문서 검색 (context와 question 모두 기준으로 검색)
    retrieved_docs = retriever.get_relevant_documents(f"{context}\n\n{question}")
    retrieved_context = "\n\n".join(doc.page_content for doc in retrieved_docs)

    return {
        "context": context,           # 지문 및 <보기>
        "reference": retrieved_context,  # 보조 자료
        "question": question
    }

# RAG QA 체인: 문항 지문 중심 + retriever 참고
rag_qa_chain = (
    RunnableLambda(format_with_retrieved_docs)
    | qa_prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# # **4. 문제 vs 개념 분류 함수**

# %%
def is_problem_question(question: str) -> bool:
    classification_prompt = ChatPromptTemplate.from_template("""
다음 질문이 문학 개념 질문인지, 지문 기반 문제인지 판별해줘. '개념' 또는 '문제' 중 하나로만 답해.

질문:
{question}
""")
    chain = classification_prompt | llm | StrOutputParser()
    result = chain.invoke({"question": question})
    return "문제" in result.strip()

# %% [markdown]
# # **5. 최종 질문 처리 함수**

# %%
def tutor_response(question: str, passage: str = None):
    """
    문학 질문 또는 문항에 대한 응답을 처리합니다.

    Parameters:
    - question: 수험생 질문 또는 문학 개념 질문
    - passage: 선택적 입력. 문항 지문이 있는 경우 함께 제공
    """
    if is_problem_question(question):
        if not passage:
            print("❗ 오류: 문학 문제 풀이에는 지문(passage)이 필요합니다.")
            return

        print("📘 [문제에 대한 정답 및 해설]")

        # rag_qa_chain에 지문과 문제를 분리해서 입력
        response = rag_qa_chain.invoke({
            "context": passage,
            "question": question
        })
        print(response)

    else:
        print("📘 [문학 개념 설명]")
        response = concept_chain.invoke({"question": question})
        print(response)

# %% [markdown]
# # **<직접 수정한 깨끗한 텍스트로 테스트>**
# - 2025학년도(2024년 시행) 6월, 9월 수능 테스트

# %%
import re

# 🔸 문제/지문 파싱 함수
def extract_passage_question_pairs(path):
    with open(path, "r", encoding="utf-8") as f:
        content = f.read()

    # 🔹 블록 단위로 split
    raw_blocks = re.split(r"---\s+(\d{4}-(?:\d{2}|수능)-국어_[^\s(]+)", content)
    blocks = list(zip(raw_blocks[1::2], raw_blocks[2::2]))  # [(header, content), ...]

    passage = None
    pairs = []

    for header, body in blocks:
        body = body.strip()

        # 지문 블록이면 지문 갱신
        if "_p" in header:
            passage = body

        # 문제 블록이면 현재 지문과 연결
        elif re.match(r"\d{4}-(\d{2}|수능)-국어_\d{2}", header):
            question = body
            if passage:  # 지문이 있어야 유효
                pairs.append({
                    "id": header,  # e.g., "2025-06-국어_18"
                    "context": passage,
                    "question": question
                })

    return pairs

# 🔹 정답표 딕셔너리 (연도-월별 구성)
answer_key = {
    "2024-06": {
        18: "4", 19: "3", 20: "3", 21: "4", 22: "1", 23: "2",
        24: "5", 25: "2", 26: "5", 27: "2", 28: "3", 29: "4",
        30: "3", 31: "5", 32: "4", 33: "3", 34: "3"
    },
    "2024-09": {
        18: "1", 19: "3", 20: "5", 21: "5", 22: "3", 23: "1",
        24: "4", 25: "4", 26: "5", 27: "3", 28: "4", 29: "3",
        30: "5", 31: "2", 32: "1", 33: "3", 34: "3"
    },
    "2024-수능": {
        18: "2", 19: "4", 20: "1", 21: "4", 22: "4", 23: "5",
        24: "2", 25: "2", 26: "1", 27: "1", 28: "4", 29: "3",
        30: "5", 31: "4", 32: "3", 33: "5", 34: "2"
    }
}

# 🔸 회차 및 문항 번호 파싱 함수
def get_correct_answer_from_id(qid):
    # e.g., qid = "2025-06-국어_18"
    match = re.match(r"(\d{4}-\d{2}|2024-수능)-국어_(\d+)", qid)
    if not match:
        return "❓"
    key, num = match.groups()
    num = int(num)
    return answer_key.get(key, {}).get(num, "❓")

# 🔹 문항별 tutor_response 실행
def run_tutor_response_on_question_pairs(pairs):
    for pair in pairs:
        qid = pair["id"]
        correct_answer = get_correct_answer_from_id(qid)
        print(f"\n\n=============================== ✅ 문항 {qid} (정답: {correct_answer}) ===============================\n")
        try:
            tutor_response(
                question=pair["question"],
                passage=pair["context"]
            )
        except Exception as e:
            print(f"❌ 문항 {qid} 처리 중 오류 발생: {e}")

# %%
# 🔸 txt 파일 경로
txt_path = "/content/drive/MyDrive/Colab Notebooks/TAVE 프로젝트_STUBO/문학/data/문제해설모델 테스트_직접수정.txt"

# 🔹 전체 문항 불러오기 (지문과 매핑된)
qa_inputs = extract_passage_question_pairs(txt_path)

# ✅ 실행
run_tutor_response_on_question_pairs(qa_inputs)
# Out:
# =============================== ✅ 문항 2024-06-국어_18 (정답: 4) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# /tmp/ipython-input-7-3533957196.py:50: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   retrieved_docs = retriever.get_relevant_documents(f"{context}\n\n{question}")
# [정답]
# - ④
#
# [해설]
# - ④번 선택지는 "㉣은 이대봉이 중원으로 향하기 전에 머물던 공간이다."라고 설명하고 있습니다. 지문에서 "서해 용왕의 구함을 입어 살아나 서역 천축국 ㉣(백운암)에 가 팔 년을 의탁하였나이다."라는 부분이 있습니다. 이 부분에서 이대봉이 서역 천축국 백운암에 머물렀다는 사실을 알 수 있으며, 이후 중원으로 향하기 전에 머물렀던 공간임을 알 수 있습니다. 따라서 ④번 선택지가 가장 적절합니다.
#
# - ①번 선택지는 "㉠은 이대봉이 이릉의 영혼을 만나 갑옷과 칼을 얻은 공간이다."라고 설명하고 있습니다. 그러나 지문에서 ㉠은 용궁으로, 이대봉이 부친과 함께 떠난 장소로 설명되어 있으며, 이릉의 영혼을 만난 장소는 농서입니다. 따라서 ①번은 틀렸습니다.
#
# - ②번 선택지는 "㉡은 흉노가 침범한 곳이자 이대봉이 흉노를 처단한 공간이다."라고 설명하고 있습니다. 그러나 지문에서 ㉡은 황성으로, 이대봉이 부친과 함께 머물 곳을 정한 후 성상께 상소를 올린 장소로 설명되어 있습니다. 따라서 ②번은 틀렸습니다.
#
# - ③번 선택지는 "㉢은 장 한림 부부가 간신의 모해로 유배 간 공간이다."라고 설명하고 있습니다. 그러나 지문에서 ㉢은 해도로, 이대봉 부자가 유배 간 곳으로 설명되어 있습니다. 따라서 ③번은 틀렸습니다.
#
# - ⑤번 선택지는 "㉤은 동돌수가 이대봉을 피해 달아난 공간이다."라고 설명하고 있습니다. 그러나 지문에서 ㉤은 금릉으로, 황성이 함몰된 후 어가가 이동한 장소로 설명되어 있습니다. 따라서 ⑤번은 틀렸습니다.
#
#
# =============================== ✅ 문항 2024-06-국어_19 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③ 선택지는 부친이 세상을 버린 이유를 "혼약이 어그러진 것과 이 시랑의 죽음에 대한 분노 때문"이라고 설명하고 있습니다. 그러나 지문에서는 부친이 세상을 버린 이유를 "대인의 억울함과 소첩의 앞길이 그릇됨을 원통히 여겨 걱정과 분노가 병이 되어 중도에 세상을 버리시니"라고 명시하고 있습니다. 즉, 이 시랑의 죽음 때문이 아니라, 이 시랑의 억울함과 소첩의 앞길이 그릇된 것에 대한 원통함이 주된 이유로 제시되어 있습니다. 따라서 ③은 지문과 일치하지 않습니다.
#
# - ① 선택지는 "부친과 이 시랑이 ‘진진지연’을 맺은 데에는 신기한 꿈이 영향을 미쳤을 것이라고 알고 있다"는 내용으로, 지문에서 "부친이 신기한 꿈을 꾸고는 대인과 진진지연을 깊이 맺었더니"라는 부분과 일치합니다.
#
# - ② 선택지는 "이 시랑이 ‘간신의 모해’를 입은 것은 시운이 좋지 않았기 때문이라고 생각했다"는 내용으로, 지문에서 "슬프다, 양가 시운이 불리하여 대인은 간신의 모해를 입어 외딴섬에 유배 가시고"라는 부분과 일치합니다.
#
# - ④ 선택지는 "왕희가 ‘혼인을 강제하’는 것으로 판단하여 변복 도주했다"는 내용으로, 지문에서 "간적 왕희가 첩의 고독함을 업신여겨 혼인을 강제하옵기로 변복 도주하였다가"라는 부분과 일치합니다.
#
# - ⑤ 선택지는 "‘성혼 행례’는 하지 않았으나, 승려가 된 양씨를 시어머니로 대했다"는 내용으로, 지문에서 "비록 성혼 행례는 아니 하였사오나 어찌 시어머니와 며느리 사이가 아니리잇가"라는 부분과 일치합니다.
#
#
# =============================== ✅ 문항 2024-06-국어_20 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④
#
# [해설]
# - ④번 선택지는 부적절합니다. ⓐ와 ⓑ에서 글을 바치는 사람이 오해했던 사건의 실상이 ⓑ에서 드러난다는 내용은 지문에서 확인할 수 없습니다. ⓐ는 장 한림의 딸이 시랑 이 공의 영위 앞에 바치는 제문이고, ⓑ는 이대봉이 성상에게 바치는 표문입니다. 두 글 모두 각자의 상황을 설명하고 요청을 하는 내용이지만, ⓑ에서 ⓐ의 오해가 풀린다는 내용은 없습니다.
#
# - ①번 선택지는 적절합니다. ⓐ는 망자에게 바치는 제문이고, ⓑ는 성상에게 바치는 표문입니다. 지문에서 ⓐ는 '시랑의 영위 먼저 차린 후 제문을 읽으니'라는 부분에서 제문임을 알 수 있고, ⓑ는 '죄신 이대봉은 황공함과 두려운 마음으로 머리를 조아려 절을 올리며 한 장 표문을 황상 용탑 하에 바치옵나이다'라는 부분에서 표문임을 알 수 있습니다.
#
# - ②번 선택지도 적절합니다. ⓐ는 상대의 원통함을 위로하기 위한 제문이고, ⓑ는 성상에게 사건 경과를 알려 특별한 조치를 요청하기 위한 표문입니다. ⓐ에서는 '어찌 참통치 않으리잇고'라는 부분에서 원통함을 위로하는 내용을 확인할 수 있고, ⓑ에서는 '왕희는 국가의 난신적자요 신의 원수라... 엄형 국문하옵신 후 왕적을 내어 주시고 신의 죄를 다스리옵소서'라는 부분에서 특별한 조치를 요청하고 있음을 알 수 있습니다.
#
# - ③번 선택지도 적절합니다. ⓑ에는 '죄신 이대봉은 황공함과 두려운 마음으로 머리를 조아려 절을 올리며'라는 표현이 있어 글을 바치는 사람이 스스로를 낮추는 표현이 사용되었습니다.
#
# - ⑤번 선택지도 적절합니다. ⓐ와 ⓑ 모두 글을 바치는 사람과 상대를 서두에서 밝히고 있습니다. ⓐ에서는 '기주 장 한림의 딸 애황은 감히 이부 시랑 이 공 영위 앞에 아뢰나이다'라는 부분에서, ⓑ에서는 '죄신 이대봉은 황공함과 두려운 마음으로 머리를 조아려 절을 올리며 한 장 표문을 황상 용탑 하에 바치옵나이다'라는 부분에서 확인할 수 있습니다.
#
#
# =============================== ✅ 문항 2024-06-국어_21 (정답: 4) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ①
#
# [해설]
# - ① 선택지는 장애황이 혼약을 이루기 위해 대공을 세웠다고 한 데에서 혼약이 국가 차원의 사건에 참여하는 동력이 되었음을 알 수 있다고 설명합니다. 그러나 지문에서 장애황이 대공을 세운 이유는 "적자 왕희를 없이하여 원통함을 풀고 대인과 공자를 찾아 혼약을 이루기 위함"이라고 되어 있습니다. 이는 혼약이 국가 차원의 사건에 참여하는 동력이 되었다기보다는 사적 목표를 위한 행동임을 나타냅니다. 따라서 이 선택지는 부적절합니다.
#
# - ② 선택지는 장애황이 난신 왕희를 국법으로 다스린 후 자신에게 내어 달라고 한 데에서 공적 권위를 존중하되 사적 목표도 실현하고자 하는 마음을 알 수 있다고 설명합니다. 이는 지문에서 장애황이 왕희를 처벌하고자 하는 이유가 개인적 원한을 풀기 위한 것이지만, 이를 국법에 따라 처리하려는 점에서 공적 권위를 존중하는 모습을 보여주므로 적절합니다.
#
# - ③ 선택지는 흉노의 침입으로 성상이 피신했다는 소식에 분노하여 이대봉이 출전한 데에서 국가 차원의 문제 해결에 참여하는 당위성을 확인할 수 있다고 설명합니다. 이는 이대봉이 국가의 위기를 해결하기 위해 출전한 상황을 잘 설명하고 있으므로 적절합니다.
#
# - ④ 선택지는 표류하던 이대봉이 천우신조로 무인절도에서 이 시랑과 재회한 데에서 비현실계의 존재가 이대봉의 공적 활약에 조력한 것을 확인할 수 있다고 설명합니다. 이는 지문에서 이대봉이 비현실적인 도움을 받아 위기를 극복하고 이 시랑과 재회한 상황을 설명하므로 적절합니다.
#
# - ⑤ 선택지는 이대봉이 흉노 제압을 공으로 드러낸 후 성상에게 왕희의 처벌을 요구한 데에서 충의 이념을 훼손하지 않으면서도 사적 목표의 정당성을 확보하려는 인물의 의중을 확인할 수 있다고 설명합니다. 이는 이대봉이 국가적 공적을 세운 후 개인적 원한을 해결하려는 모습을 잘 설명하고 있으므로 적절합니다.
#
#
# =============================== ✅ 문항 2024-06-국어_22 (정답: 1) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ①
#
# [해설]
# - ① (가)는 '공것', '뜬재물', '혼인 중매', '산진매 수진매' 등 다양한 사례를 열거하여 꽁생원의 비윤리적이고 요행을 바라는 삶을 비판적으로 묘사하고 있습니다. (나)는 부지런한 농부와 게으른 농부를 대조하여 노력의 중요성을 강조하고 있습니다. 따라서 (가)는 열거의 방식을, (나)는 대조의 방식을 활용하여 주제를 부각하고 있다는 설명이 적절합니다.
#
# - ② (가)에서 대구적 표현을 활용한 부분은 명확하지 않으며, 인물에 대한 태도의 변화를 드러내는 부분도 없습니다. (나)에서도 대구적 표현을 통한 인물에 대한 태도의 변화는 나타나지 않습니다.
#
# - ③ (나)에서는 반어적 표현보다는 농부들의 행동을 직접적으로 서술하여 그 결과를 보여주고 있습니다. 반어적 표현을 통해 인물에 대한 기대감을 높이는 부분은 없습니다.
#
# - ④ (가)와 (나) 모두 계절적 배경이 등장하지만, 향토적 분위기를 조성하기 위한 주된 장치로 사용되지는 않습니다. (가)는 꽁생원의 비윤리적 행위를 비판하고, (나)는 농부들의 노력을 강조하는 데 중점을 두고 있습니다.
#
# - ⑤ (가)와 (나) 모두 해학적 표현을 활용하여 인물 간의 우호적 관계를 드러내고 있지 않습니다. (가)는 꽁생원의 부정적 행위를 비판하며, (나)는 농부들의 상반된 태도를 통해 교훈을 전달하고 있습니다.
#
#
# =============================== ✅ 문항 2024-06-국어_23 (정답: 2) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - ① ㉠은 '음양술수'에 현혹되어 이장과 이사를 자주 하는 꽁생원이 집터나 묏자리를 통해 길운을 바라는 대상임을 나타냅니다. 이는 지문에서 "주제넘게 아는 체로 음양술수 현혹되어 이장도 자주 하며 이사도 힘을 쓰고"라는 구절에서 확인할 수 있습니다.
#
# - ② ㉡은 꽁생원이 재물을 모으는 과정에서 가족을 희생시키는 모습을 보여주는 대상입니다. 지문에서 "올 적 갈 적 행로상에 처자식을 흩어 놓고"라는 구절은 꽁생원이 가족을 돌보지 않고 자신의 이익을 추구하는 모습을 나타내므로, 함께 풍요로운 삶을 누리고 싶은 대상이라는 해석은 적절하지 않습니다.
#
# - ③ ㉢은 꽁생원이 재물을 경영하여 부를 증식하려는 과정에서 권력가의 권세를 이용하려는 방법을 나타냅니다. 이는 지문에서 "재상가에 청질하다 봉변당해 물러서며"라는 구절에서 확인할 수 있습니다.
#
# - ④ ㉣은 꽁생원이 집이나 땅을 중개하여 이문을 취하려는 과정에서 부정적인 반응을 겪는 모습을 나타냅니다. 이는 "가대 흥정 구문 먹기 핀잔 듣고 자빠지고"라는 구절에서 확인할 수 있습니다.
#
# - ⑤ ㉤은 꽁생원이 부자의 재산으로 이익을 얻으려는 수단으로 부자를 꾀는 모습을 나타냅니다. 이는 "부자나 후려 볼까 감언이설 꾀어 보자"라는 구절에서 확인할 수 있습니다.
#
#
# =============================== ✅ 문항 2024-06-국어_24 (정답: 5) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 ⓑ와 ⓒ에 대한 설명이 지문과 일치합니다. ⓑ의 게으른 농부는 "김을 매도 죽을 것이고 김을 매지 않아도 죽을 것이다."라고 하며, 김매기를 하여도 작물이 죽을 것이라고 생각합니다. ⓒ의 선비들은 "공명에는 분수가 있어서 학문으로 이룰 수 있는 것이 아니며, 부귀는 운명에 달려 있으니 역시 학문으로 이룰 수 있는 것이 아니다."라고 하며, 학문에 힘을 쏟아도 부귀를 이루지 못할 수 있다고 생각합니다.
#
# - ①번 선택지는 ⓐ와 ⓑ에 대한 설명이 틀렸습니다. ⓐ의 꽁생원은 도박과 음주에 빠져 있다는 내용이 지문에 없으며, ⓑ의 게으른 농부는 술에 취해 잠들어 있다는 내용이 지문에 없습니다.
#
# - ②번 선택지는 ⓐ와 ⓒ에 대한 설명이 틀렸습니다. ⓐ의 꽁생원은 부모의 혜택을 받지 못하여 팔자를 원망하는 것이 아니라, 부모 덕분에 돈을 얻었으나 그 돈을 잘못 사용하여 팔자를 원망하는 것입니다. ⓒ의 선비들은 자신의 배움에 한계가 있다고 생각하는 것이 아니라, 학문으로 부귀를 이룰 수 없다고 생각합니다.
#
# - ③번 선택지는 ⓐ와 ⓒ에 대한 설명이 틀렸습니다. ⓐ의 꽁생원은 혼인을 중매하는 일에 성공하지 못하여 창피를 당하는 것이 아니라, 돈에 창피당해 뺨을 맞습니다. ⓒ의 선비들은 과거 시험에서 뜻을 이루지 못하여 수치를 당하는 것이 아니라, 학문으로 부귀를 이룰 수 없다고 생각합니다.
#
# - ④번 선택지는 ⓑ와 ⓒ에 대한 설명이 틀렸습니다. ⓑ의 게으른 농부는 다른 농부들의 조롱을 받는 것이 아니라, 오히려 다른 농부들을 비웃습니다. ⓒ의 선비들은 한때의 괴로움을 참지 못하여 공명을 이루지 못하는 것이 아니라, 학문으로 부귀를 이룰 수 없다고 생각합니다.
#
#
# =============================== ✅ 문항 2024-06-국어_25 (정답: 2) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - ②번 선택지는 글쓴이의 주장과 그에 대한 반박을 제시하여 화제에 대한 상반된 입장을 나타내고 있다고 설명하고 있습니다. 그러나 (나) 지문에서는 글쓴이의 주장을 반박하는 내용이 나타나지 않습니다. (나) 지문은 부지런한 농부와 게으른 농부의 대조를 통해 부지런함의 중요성을 강조하고 있으며, 글쓴이의 주장을 반박하는 내용은 없습니다.
#
# - ①번 선택지는 인물들의 말을 인용하여 특정 상황에 대한 서로 다른 태도를 드러내고 있다고 설명하고 있습니다. (나) 지문에서는 부지런한 농부와 게으른 농부의 대조적인 태도를 인용을 통해 드러내고 있습니다.
#
# - ③번 선택지는 물음에 답하는 인물을 통해 글쓴이가 관찰한 상황이 발생하게 된 이유를 제시하고 있다고 설명하고 있습니다. (나) 지문에서는 마을 노인의 말을 통해 부지런한 농부와 게으른 농부의 결과를 설명하고 있습니다.
#
# - ④번 선택지는 다른 사람에게 교훈을 전달하고자 하는 글쓴이의 의도를 드러내며 글을 마무리하고 있다고 설명하고 있습니다. (나) 지문은 부지런함의 중요성을 강조하며 교훈을 전달하고 있습니다.
#
# - ⑤번 선택지는 글쓴이의 경험을 통해 얻은 깨달음을 바탕으로 논의의 대상을 다른 상황으로 확장하고 있다고 설명하고 있습니다. (나) 지문은 농부의 부지런함과 게으름을 학문을 하는 선비들의 태도와 비교하여 논의를 확장하고 있습니다.
#
#
# =============================== ✅ 문항 2024-06-국어_26 (정답: 5) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - ② 선택지는 (나)에서 '비가 내리지 않'아 '김을 맬 수가 없'는 것을 농경에 부적합한 환경이라는 문제 상황에 당면한 것으로 해석하고 있습니다. 하지만 이는 지문에서 '비가 내리지 않'아도 부지런히 김을 매는 농부와 그렇지 않은 농부의 대조를 통해 성실함의 중요성을 강조하는 맥락에서 벗어난 해석입니다. 따라서 이 선택지는 적절하지 않습니다.
#
# - ① 선택지는 (가)의 '공것'과 '뜬재물'이 정당한 노력을 기울이지 않고 요행을 바라는 태도를 나타내는 소재로 적절히 해석하고 있습니다.
#
# - ③ 선택지는 (가)의 '공납'을 유용하려는 태도에서 규범을 무시하는 태도를, (나)의 '그냥 쉬는 것이 나을 것'에서 불행한 결과를 예단하는 운명론적 태도를 확인할 수 있다고 적절히 해석하고 있습니다.
#
# - ④ 선택지는 (가)의 '돈천이나 가졌더니', '친구 대접 하였던가'에서 인색한 물욕을, (나)의 '풀 뽑기를 쉬지 아니하여'에서 한계 상황을 극복하고자 하는 의지를 확인할 수 있다고 적절히 해석하고 있습니다.
#
# - ⑤ 선택지는 (가)의 '일가'와 '친구'에게서 소외당한 꽁생원의 말로에서 무책임한 삶에 대한 경계를, (나)의 '큰 일을 하면서 부지런하'기를 촉구하는 데에서 게으른 농부에 대한 권면이 나타난다고 적절히 해석하고 있습니다.
#
#
# =============================== ✅ 문항 2024-06-국어_27 (정답: 2) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - ② ㉡은 "나는 담배를 피워 물었다."라는 문장에서 서술의 주체가 '나'임을 명확히 알 수 있습니다. 그러나 서술자와 지각의 주체가 뚜렷이 구분된다고 보기 어렵습니다. 이 문장은 '나'의 행동을 서술하는 것으로, 서술자와 지각의 주체가 동일하게 '나'로 겹쳐져 있습니다. 따라서 서술자와 지각의 주체가 뚜렷이 구분된다는 설명은 적절하지 않습니다.
#
# - ① ㉠에서는 "바로 그 순간부터 나는 아버지의 그 죄라는 것을 내 스스로 함께 나누어 지니고 만 느낌이었다."라는 문장에서 '나'의 지각 내용을 '나'가 서술하고 있어 인물과 서술자가 겹쳐 있음을 알 수 있습니다.
#
# - ③ ㉢에서는 "언젠가 어머니의 낡은 반닫이 깊숙한 옷가지 밑에 숨겨져 있던 액자 속에서 학생복 차림으로 서 있던 그대로 그건 영락없는 그 사내였다."라는 문장에서 '나'가 지각하는 대상을 주어로 서술하여 대상을 부각하고 있습니다.
#
# - ④ ㉣에서는 "저것 봐라이."라는 발화가 인용 부호 없이 서술되어 있지만, 이는 어머니의 목소리가 드러나는 부분입니다.
#
# - ⑤ ㉤에서는 "불현듯 시야가 부옇게 흐려 왔다."라는 문장에서 지각의 주체를 알리는 표지가 나타나지 않아 누가 지각한 것인지 모호한 상황이 빚어지고 있습니다.
#
#
# =============================== ✅ 문항 2024-06-국어_28 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ⓐ는 "어머니의 변명은 끝끝내 내 마음을 어루만져 주지 못했다"라는 부분으로, 아버지의 죄를 시인하는 어머니의 한마디가 주인공에게 엄청난 충격을 주며, 이야기의 긴장감을 형성하는 요인으로 작용합니다. 이로 인해 주인공은 아버지의 죄를 함께 나누어 지니고 있다는 느낌을 받게 되고, 이는 이야기의 긴장감을 고조시킵니다.
# - ⓑ는 "소대장이 병을 기울였고 다른 녀석들도 낄낄대며 한마디씩 보태었다"라는 부분으로, 유해를 매장한 후 작은 술판이 벌어지며 긴장감이 완화됨을 드러냅니다. 이는 이야기의 긴장감이 완화되는 표지로 작용합니다.
# - 따라서 ⓐ는 이야기의 긴장감이 형성되는 요인이고, ⓑ는 이야기의 긴장감이 완화됨을 드러내는 표지로 설명한 ③번이 가장 적절합니다.
#
# - ① ⓐ와 ⓑ는 이야기의 주제와 관련된 제재나 단서로 작용하지 않습니다.
# - ② ⓐ는 이야기의 절정으로 치닫게 하는 추진력이 아니며, ⓑ는 결말에 이르게 하는 원동력이 아닙니다.
# - ④ ⓐ는 위기감이 해소된 종착점이 아니며, ⓑ는 위기감이 고조된 정점이 아닙니다.
# - ⑤ ⓐ는 이야기를 일으키는 시발점이 아니며, ⓑ는 이야기의 전모가 드러나게 되는 귀결점이 아닙니다.
#
#
# =============================== ✅ 문항 2024-06-국어_29 (정답: 4) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④
#
# [해설]
# - ㉮와 ㉯는 각각 지문에서 인물의 내면적 상태와 관련된 요소로 등장합니다. ㉮는 "날짐승도 때가 되면 돌아올 줄 아는 법이다"라는 어머니의 말로, 인물이 아버지의 귀환을 염원하는 마음을 드러냅니다. 반면 ㉯는 "쑥부쟁이와 엉겅퀴꽃"으로, 아버지가 무덤도 없이 홀로 잠들어 있을 것이라는 현실을 상징합니다. 따라서 ④번 선택지는 ㉯에서 연상되는 상황(아버지가 무덤도 없이 홀로 잠들어 있음)이 현실이 될 경우, ㉮에 투영된 염원(아버지의 귀환)은 실현 가능성이 사라진다는 점에서 적절합니다.
#
# - ① ㉮는 어머니의 말로, ㉯는 자연물로 표현되며, 둘 다 인물의 내면적 상태를 드러내지만, 능동성과 영향력의 차이를 언급하기에는 적절하지 않습니다.
# - ② ㉮와 ㉯ 모두 시간과 공간에 직접적으로 관여하지 않으며, 이야기의 배경에 실감을 더한다고 보기 어렵습니다.
# - ③ ㉯는 희망적인 성격보다는 현실의 비극성을 상징하므로, 인물이 원하는 바를 집약한 결과로 보기 어렵습니다.
# - ⑤ ㉮와 ㉯ 모두 관념적 의미가 부여되지만, 인물이 이념에 편향되어 있음을 드러내는 것과는 관련이 없습니다.
#
#
# =============================== ✅ 문항 2024-06-국어_30 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③번 선택지는 '줄 묶음'을 '내던지'는 '노인'의 행위와 '물 사발'을 올리는 '어머니'의 행위가 '나'의 기억을 재응고화하기 위한 노력으로 해석하고 있습니다. 그러나 지문에서 '노인'의 행위는 유해를 매장하는 과정에서의 행동이며, '어머니'의 '물 사발'은 단순히 '나'의 기억 속에 떠오르는 장면일 뿐, 이들이 '나'의 기억을 재응고화하기 위한 의도적인 노력으로 해석하기는 어렵습니다. 따라서 이 선택지는 적절하지 않습니다.
#
# - ①번 선택지는 '낙인'과도 같은 유년의 기억을 성인이 되어서도 떨쳐 버리지 못했다는 고백을 통해, 응고된 기억의 영향력에서 벗어나는 일이 쉽지 않음을 설명하고 있습니다. 이는 지문에서 '나'가 아버지의 죄책감을 계속해서 느끼고 있다는 내용과 일치합니다.
#
# - ②번 선택지는 '죄악감과 불길한 예감'을 유발한 동인을 '아버지'에 관한 기억으로 보고 있으며, 이는 지문에서 '나'의 심리적 불안정이 아버지의 기억으로부터 비롯된다는 내용과 부합합니다.
#
# - ④번 선택지는 '모래밭'에서의 '어머니' 형상과 '사내의 환영'이 어우러지는 장면에서 '아버지'에 대한 기억이 재편될 가능성을 시사하고 있다고 설명하고 있습니다. 이는 지문에서 '나'가 어머니와 아버지의 환영을 보며 과거의 기억을 떠올리는 장면과 관련이 있습니다.
#
# - ⑤번 선택지는 '아버지'에 대한 이미지가 '유해'에 대응되면서 '나'의 정서적 반응에 변화가 생기는 것을 설명하고 있습니다. 이는 지문에서 '나'가 유해를 매장하는 과정에서 아버지를 떠올리며 정서적 변화를 겪는 부분과 일치합니다.
#
#
# =============================== ✅ 문항 2024-06-국어_31 (정답: 5) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 "(가)와 (나)는 모두, 자연물에 화자의 정서를 투영함으로써 대상에 대한 친밀감을 드러내고 있다."라고 설명하고 있습니다. 그러나 (가)와 (나)는 자연물에 화자의 정서를 투영하여 친밀감을 드러내는 방식이 다릅니다. (가)에서는 자연 속에서의 고독과 관습을 벗어난 자유로움을 추구하는 모습이 나타나며, 자연물에 대한 직접적인 친밀감이 드러나지 않습니다. 반면 (나)에서는 차를 마시는 행위를 통해 관습과 사실을 강조하며, 자연물에 대한 친밀감보다는 개인의 내면적 고독과 관습을 중시하는 태도가 드러납니다. 따라서 ⑤번 선택지는 적절하지 않습니다.
#
# - ①번 선택지는 "(가)는 인격화한 대상을 통해 화자의 심리를 내포하고 있다."라고 설명하고 있습니다. (가)에서는 "때까치들이 몰려와 모든 야성을 버리고 들 가운데 순결해진다"와 같은 표현을 통해 자연물에 인격을 부여하여 화자의 심리를 내포하고 있습니다. 따라서 ①번 선택지는 적절합니다.
#
# - ②번 선택지는 "(나)는 대상을 한정하는 어휘들을 사용하여 주제 의식을 강조하고 있다."라고 설명하고 있습니다. (나)에서는 "차를 마시는 것은 이와 같이 스스로 달갑고 가장 즐거울 뿐, 이것은 다만 사실이며 또 관습이다."와 같은 표현을 통해 대상을 한정하는 어휘를 사용하여 주제 의식을 강조하고 있습니다. 따라서 ②번 선택지는 적절합니다.
#
# - ③번 선택지는 "(가)는 (나)와 달리, 공간의 이동에 따라 포착된 사물을 통해 화자의 태도를 드러내고 있다."라고 설명하고 있습니다. (가)에서는 "며칠째 청산에 와 발을 푸니"와 같은 표현을 통해 공간의 이동을 나타내며, 이를 통해 화자의 태도를 드러내고 있습니다. 따라서 ③번 선택지는 적절합니다.
#
# - ④번 선택지는 "(나)는 (가)와 달리, 화자를 거듭 명시하면서 시상을 전개하고 있다."라고 설명하고 있습니다. (나)에서는 "나의 고즈넉한 관습이다."와 같은 표현을 통해 화자를 명시하며 시상을 전개하고 있습니다. 따라서 ④번 선택지는 적절합니다.
#
#
# =============================== ✅ 문항 2024-06-국어_32 (정답: 4) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④
#
# [해설]
# - ④번 선택지는 ⓐ와 ⓑ의 특성을 정확하게 파악하고 있습니다. ⓐ는 '서른 번 다져 두고 서른 번 포기한 관습들'이라는 표현에서 내면의 갈등을 드러내고 있으며, 이는 반복적인 시도와 포기의 과정을 통해 화자의 내적 갈등을 나타냅니다. 반면, ⓑ는 '고즈넉한 관습'과 '담담한 사실'이라는 표현에서 내면의 평정함을 내포하고 있습니다. 이는 차를 마시는 행위가 화자에게 안정감을 주고 있음을 보여줍니다.
#
# - ①번 선택지는 ⓐ의 '길을 가다가 자주 뒤를 돌아보게 하는'이라는 표현을 그리움의 대상으로 해석했으나, 이는 내면의 갈등과 관련된 표현으로 보는 것이 더 적절합니다.
# - ②번 선택지는 ⓑ의 '호을로'라는 표현을 사회적 고립으로 해석했으나, 이는 차를 마시는 행위의 개인적 즐거움을 나타내는 것으로, 고립과는 관련이 없습니다.
# - ③번 선택지는 ⓐ를 '서쪽 마을'과 관련지어 피안에 대한 지향으로 해석했으나, 이는 지문에서 명확히 드러나지 않으며, ⓑ의 '저녁'과 '안식'의 연결도 지문에서 직접적으로 드러나지 않습니다.
# - ⑤번 선택지는 ⓐ를 '내려다보'는 것과 연결하여 자기 연민으로 해석했으나, 이는 지문에서 명확히 드러나지 않으며, ⓑ의 '달갑고', '좋아하는'이 자기 위안적 성격을 띤다는 해석은 가능하지만, ⓐ와의 비교에서 적절하지 않습니다.
#
#
# =============================== ✅ 문항 2024-06-국어_33 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③ 선택지는 "㉢은 ‘맨살’을 드러낸 ‘돌들’이 부대끼는 형상으로 세파에 시달리는 모습을 나타내는 표현이다."라고 설명하고 있습니다. 그러나 지문에서 "맨살 비비는 돌들과 함께 누워 실로 이 세상을 앓아 보지 않은 것들과 함께 잠들고 싶다."라는 구절은 돌들이 부대끼는 형상으로 세파에 시달리는 모습을 나타내는 것이 아니라, 자연과 함께 조용히 잠들고자 하는 화자의 소망을 표현한 것입니다. 따라서 ③은 적절하지 않은 설명입니다.
#
# - ① 선택지는 "㉠은 대상이 이전에는 제대로 파악되지 않았음을 드러내는 표현이다."라고 설명하고 있습니다. 지문에서 "흐리던 산길이 잘 보인다."라는 구절은 이전에는 산길이 흐려서 잘 보이지 않았음을 의미하므로 적절한 설명입니다.
#
# - ② 선택지는 "㉡은 ‘저녁 연기’의 형상으로 ‘한 가정’의 상황과 처지를 시각화한 표현이다."라고 설명하고 있습니다. 지문에서 "가늘게 흩어지는 저녁 연기가 한 가정의 고민의 양식으로 피어오르고"라는 구절은 저녁 연기를 통해 한 가정의 고민을 시각적으로 표현한 것이므로 적절한 설명입니다.
#
# - ④ 선택지는 "㉣은 ‘차를 마시는 것’이 화자의 선호에 따른 주체적 행위임을 드러내는 표현이다."라고 설명하고 있습니다. 지문에서 "스스로 달갑고 가장 즐거울 뿐"이라는 구절은 차를 마시는 것이 화자의 주체적 선택임을 나타내므로 적절한 설명입니다.
#
# - ⑤ 선택지는 "㉤은 ‘나’에 대한 현재의 인식이 이전과는 달라졌음을 드러내는 표현이다."라고 설명하고 있습니다. 지문에서 "이제는 차를 마시는 나일 뿐"이라는 구절은 현재의 인식이 이전과 달라졌음을 나타내므로 적절한 설명입니다.
#
#
# =============================== ✅ 문항 2024-06-국어_34 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤ 선택지는 (가)의 '이 세상을 앓아 보지 않은 것들과 함께'와 (나)의 '물은 물일 뿐'을 비교하고 있습니다. (가)에서 '이 세상을 앓아 보지 않은 것들과 함께'는 자연과의 동화나 순수한 상태를 지향하는 태도를 드러내고 있습니다. 그러나 (나)에서 '물은 물일 뿐'은 경험적 사실을 있는 그대로 받아들이겠다는 태도를 나타내며, 이는 절대자와의 관계를 회의하고 경험적 사실에 기초하여 존재를 인식하겠다는 태도와 연결됩니다. 따라서 ⑤의 설명은 (가)와 (나)의 태도를 잘못 연결하고 있습니다.
#
# - ① (가)의 '쓰다 둔 편지 구절과 버린 칫솔을 생각한다'는 부분은 화자가 자연에 완전히 동화되지 못하고 세속적 미련을 가지고 있음을 나타내고 있습니다. 이는 자연에 대한 온전한 동화의 어려움을 보여줍니다.
#
# - ② (나)의 '차를 마시는' 행위가 '내가 아는 내게 대한 모든 것', '모든 것에 대한 모든 것'으로 확장되는 것은, 경험적 사실을 '나'와 모든 존재들에 대한 인식의 유일한 근거로 삼겠다는 의식이 반영된 것입니다. 이는 절대자와의 관계를 회의하고 경험적 사실에 기초한 인식을 강조합니다.
#
# - ③ (가)의 '발을 푸니'와 '잘 보인다'는 자연에 친숙해지는 화자의 심리 상태를 나타내고 있으며, (나)의 '앞으로 남은 십년을 더 살든지 죽든지'는 절대자에 대한 회의와 현실에 얽매이지 않겠다는 태도를 드러내고 있습니다.
#
# - ④ (가)의 '여울물'과 '때까치들'에는 자연에 들어와서 느끼는 화자의 심리가 투사되어 있으며, (나)의 '참새'의 떨어짐이 '누구'에 의한 것이 '아니'라는 데에서 절대자와의 관계에 대한 회의가 드러나 있습니다. 이는 절대자와의 관계를 부정하고 경험적 사실을 중시하는 태도를 보여줍니다.
#
#
# =============================== ✅ 문항 2024-09-국어_18 (정답: 1) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - ② 선택지는 춘향이 그네를 타기 위해 나들이에 나섰지만 기대했던 바를 달성하지 못했다는 내용을 담고 있습니다. 지문에서 "원래 춘향은 풍경을 즐기려는 옆집 여자 아이를 따라 나온 것이었다. 채색 줄로 만든 그네를 탔는데, 봄바람에 옷자락이 흐트러져 버드나무 가지를 꽉 잡은 채 그네를 멈추고 옷매무새를 바로잡으려 했다."라는 부분에서 춘향이 그네를 타러 나왔으나, 그네를 멈추고 옷매무새를 바로잡으려 했다는 점에서 기대했던 바를 달성하지 못했음을 알 수 있습니다.
#
# - ① 선택지는 이도린이 춘향이 자신에게 호감을 느꼈다는 사실을 알지 못했다는 내용인데, 지문에서는 이도린이 춘향을 보고 "고운 얼굴 한번 보려고 그런다."라고 말하며 춘향에게 호감을 느끼고 있음을 보여주고 있습니다. 따라서 이도린이 춘향의 호감을 알지 못했다는 내용은 지문과 일치하지 않습니다.
#
# - ③ 선택지는 이도린이 춘향을 부르면 춘향이 자신을 만나러 올 것이라는 김한의 말을 믿었다는 내용인데, 지문에서 이도린은 김한에게 "오고 안 오고는 저 아이한테 달렸지 너한테 달리지 않았으니, 너는 그 새 주둥이 같은 입을 그만 닥치거라."라고 말하며 김한의 말을 믿지 않고 있음을 보여줍니다.
#
# - ④ 선택지는 이도린이 월매가 춘향의 어머니라는 사실을 알고 있었지만 이를 모르는 척했다는 내용인데, 지문에서는 이도린이 김한에게 "도련님께서는 교방 행수 기생 월매를 기억하시는지요?"라고 물었을 때 "저렇게 젊고 아리따운 여인을 어떻게 반쯤은 쭈글쭈글해진 노파에다 비교할 수 있느냐?"라고 반문하며 월매와 춘향의 관계를 처음 알게 된 듯한 반응을 보입니다.
#
# - ⑤ 선택지는 옆집 여자 아이가 이도린을 만나기 위해 춘향과 함께 왔지만 풍경을 즐기는 것에 만족했다는 내용인데, 지문에서는 옆집 여자 아이가 풍경을 즐기기 위해 나섰다는 언급은 있지만, 이도린을 만나기 위해 왔다는 내용은 없습니다. 따라서 이 선택지는 지문과 일치하지 않습니다.
#
#
# =============================== ✅ 문항 2024-09-국어_19 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③ 춘향이 몸을 감추고 이도린을 바라보는 장소
#
# [해설]
# - 지문에서 "춘향은 몸을 돌려 (꽃그늘) 속으로 들어가 숨고서는 주변을 둘러보았다."라는 구절이 있습니다. 이 문장은 춘향이 꽃그늘 속에서 몸을 감추고 있다는 것을 명확히 보여줍니다. 따라서 '꽃그늘'은 춘향이 몸을 감추고 있는 장소로 이해할 수 있습니다.
# - ① 춘향이 그네를 타기 위해 기다리는 장소: 지문에 따르면 춘향은 이미 그네를 타고 있었으며, 그네를 타기 위해 기다리는 장소가 아닙니다.
# - ② 춘향이 김한을 기다리며 머물고 있는 장소: 춘향은 김한을 기다리고 있지 않았으며, 김한이 춘향을 찾으러 온 상황입니다.
# - ④ 김한이 이도린을 만나서 대화를 나누는 장소: 김한과 이도린의 대화는 광한루에서 이루어졌으며, 꽃그늘은 그 장소가 아닙니다.
# - ⑤ 이도린이 춘향과 만나기 위해 미리 약속한 장소: 이도린과 춘향은 미리 약속한 적이 없으며, 춘향이 꽃그늘에 숨은 것은 우연한 상황입니다.
#
#
# =============================== ✅ 문항 2024-09-국어_20 (정답: 5) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - 김한의 역할은 이도린과 춘향의 만남을 성사시키는 데 중요한 역할을 합니다. 지문에서 김한은 이도린에게 춘향을 소개하고, 춘향에게는 이도린과의 만남이 우연이 아님을 설명하며 만남을 설득합니다. "도련님께서 춘향이 발한 것이 우연히 오늘이며, 낭자가 그네 뛰며 논 것도 마침 이때이니, 이는 참으로 그렇게 하지 않았는데도 그렇게 된 것이오."라는 대목에서 김한은 이도린과 춘향의 만남을 운명적인 것으로 설명하며 두 사람을 만나게 하는 매개자 역할을 합니다. 따라서 ⑤번 선택지가 가장 적절합니다.
#
# - ① 이도린에게 금과 옥이 아니라고 알려주는 것은 맞지만, 이는 이도린의 무지를 일깨우는 비판자 역할이라기보다는 춘향의 아름다움을 강조하기 위한 대화입니다.
# - ② 김한은 춘향을 선녀 같은 아가씨라고 말하지만, 이는 춘향의 고귀한 신분을 알게 하는 것이 아니라 춘향의 아름다움을 강조하는 표현입니다.
# - ③ 김한이 이도린에게 춘향을 부르게 하는 중개자 역할을 하는 것은 맞지만, 이는 ⑤번 선택지의 설명과 비교했을 때 덜 적절합니다.
# - ④ 김한은 춘향에게 지혜로운 사람임을 일깨워 주지만, 이는 이도린을 만나지 못하도록 방해하는 것이 아니라 오히려 만남을 설득하는 과정입니다.
#
#
# =============================== ✅ 문항 2024-09-국어_21 (정답: 5) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 [A]와 ㉠을 통해 독자에게 작품의 감상법을 다양하게 설명하여, ｢광한루기｣를 8회로 구성한 이유를 부각하고 있다고 했으나, 이는 적절하지 않습니다. [A]에서는 두 인물이 만나게 되는 계기를 서술하며 서사 전개의 개연성을 보여주고 있으며, ㉠에서는 이도린의 반응이 당연하다는 점을 강조하고 있습니다. 따라서 이 선택지는 작품의 감상법을 설명하거나 8회로 구성한 이유를 부각하지 않습니다.
#
# - ①번 선택지는 [A]에서 시구를 활용하여 '봄바람'과 '버드나무 언덕'이 어우러진 봄날의 분위기를 보여주며 해당 회의 배경을 드러내고 있다는 점에서 적절합니다.
#
# - ②번 선택지는 [A]를 통해 '광한루'라는 주요 공간을 소개하고 그 공간의 역할을 드러내고 있다는 점에서 적절합니다.
#
# - ③번 선택지는 [A]에서 두 인물이 만나게 되는 계기를 서술하여 서사 전개의 개연성을 보여주고 있다는 점에서 적절합니다.
#
# - ④번 선택지는 ㉠이 인물의 말에 대한 평을 통해 독자에게 이도린의 반응이 당연하다는 점을 강조하고 있다는 점에서 적절합니다.
#
#
# =============================== ✅ 문항 2024-09-국어_22 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③ 빗대어 표현하는 방식으로 ‘나’의 인식을 드러내고 있다.
#
# [해설]
# - (가), (나), (다) 세 지문 모두에서 빗대어 표현하는 방식이 사용되어 '나'의 인식을 드러내고 있습니다.
#   - (가)에서는 "범과 사슴과 너구리를 배반하고"와 같은 표현을 통해 떠나온 과거와의 단절을 비유적으로 표현하고 있습니다.
#   - (나)에서는 "살얼음의 창"을 통해 물고기와의 거리감을 비유적으로 표현하며, 생가와의 관계를 회상하고 있습니다.
#   - (다)에서는 "암소의 뿔"과 "늙은 나무"를 통해 자연물에 대한 의존성을 비유적으로 설명하고 있습니다.
# - 따라서, 세 지문 모두에서 비유적 표현을 통해 '나'의 인식과 감정을 드러내고 있다는 점에서 ③번이 정답입니다.
#
# - ① 비판적 태도로 현실의 부정적 측면을 부각하고 있다는 표현은 (가)에서 일부 확인할 수 있으나, (나)와 (다)에서는 명확히 드러나지 않습니다.
# - ② 역사적 상황을 묘사하여 비극적 현실을 부각하는 것은 (가)에서 일부 나타나지만, (나)와 (다)에서는 역사적 상황을 직접적으로 묘사하지 않습니다.
# - ④ 영탄적 어조로 대상에 대한 '나'의 경외감을 드러내는 부분은 (다)에서 일부 확인할 수 있으나, (가)와 (나)에서는 명확히 드러나지 않습니다.
# - ⑤ 향토적 소재를 활용하여 '나'의 과거에 대한 그리움을 드러내는 것은 (가)와 (나)에서 일부 나타날 수 있으나, (다)에서는 명확히 드러나지 않습니다.
#
#
# =============================== ✅ 문항 2024-09-국어_23 (정답: 1) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ①
#
# [해설]
# - (가)에서 '태반'은 화자가 돌아온 고향이나 본래의 장소를 의미하며, 화자는 이곳에서 "이기지 못할 슬픔과 시름에 쫓겨" 돌아왔다고 표현하고 있습니다. 이는 화자가 태반에서 상실감을 느끼고 있음을 나타냅니다. "나의 조상은 형제는 일가친척은 정다운 이웃은 그리운 것은 사랑하는 것은 우러르는 것은 나의 자랑은 나의 힘은 없다"라는 부분에서 화자가 느끼는 상실감이 드러납니다.
# - (나)에서 '생가'는 화자가 자신의 본래 집을 떠올리며 느끼는 감정의 공간으로, "나의 생가 같았다"라는 표현과 "나를 못 알아보고"라는 부분에서 화자가 생가에서 느끼는 서글픔이 드러납니다. 이는 화자가 생가에서 서글픔을 느끼고 있음을 나타냅니다.
#
# - ②는 (가)에서 화자가 태반에서 소외감을 느끼고 있다는 설명이 지문과 일치하지 않으며, (나)에서 화자가 생가에서 수치심을 떠올리고 있다는 설명도 지문에 근거가 없습니다.
# - ③은 (가)에서 태반이 이별을 수용하는 공간으로 설명되었으나, 이는 화자가 돌아온 공간으로 이별보다는 상실감과 관련이 있습니다. (나)에서 생가가 만남을 기약하는 공간이라는 설명도 지문에 근거가 없습니다.
# - ④는 (가)에서 태반이 화자의 희망이 드러나는 공간으로 설명되었으나, 이는 상실감과 관련이 있습니다. (나)에서 생가가 절망이 드러나는 공간이라는 설명도 지문에 근거가 없습니다.
# - ⑤는 (가)에서 태반이 생명의 섭리를 지향하는 공간으로 설명되었으나, 이는 상실감과 관련이 있습니다. (나)에서 생가가 생명의 섭리를 거부하는 공간이라는 설명도 지문에 근거가 없습니다.
#
#
# =============================== ✅ 문항 2024-09-국어_24 (정답: 4) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④
#
# [해설]
# - ④ 선택지는 ㉣의 시구가 ㉤에서 반복, 변주되는 것을 통해 상반된 상황이 시간의 추이에 따라 일치되는 과정을 드러낸다고 설명하고 있습니다. 하지만 지문을 보면 ㉣에서는 "아무 이기지 못할 슬픔도 시름도 없이"라는 구절이 나오고, ㉤에서는 "이제는 참으로 이기지 못할 슬픔과 시름에 쫓겨"라는 구절이 나옵니다. 이 두 구절은 상반된 상황을 나타내며, 시간의 추이에 따라 일치되는 것이 아니라 오히려 대조적인 상황을 강조하고 있습니다. 따라서 이 선택지는 적절하지 않습니다.
#
# - ① 선택지는 ㉠에서 여러 민족, 나라, 지명을 열거하여 화자가 떠나온 공간을 북방으로 포괄되는 동질적 공간으로 표현하고 있다고 설명합니다. 이는 지문에서 "부여를 숙신을 발해를 여진을 요를 금을 흥안령을 음산을 아무우르를 숭가리를" 등 다양한 지명을 나열함으로써 북방이라는 큰 틀 안에서의 동질성을 강조하고 있는 것과 일치합니다.
#
# - ② 선택지는 ㉡에서 의인화된 자연물을 제시하여 화자가 북방을 떠나면서 느낀 슬픔을 드러내고 있다고 설명합니다. 지문에서 "자작나무와 이깔나무의 슬퍼하던 것을 기억한다"와 같은 표현을 통해 자연물이 의인화되어 화자의 슬픔을 나타내고 있음을 알 수 있습니다.
#
# - ③ 선택지는 ㉢에서 이별하던 장면을 유사한 통사 구조로 제시하여 화자가 북방에서의 기억을 여전히 간직하고 있음을 보여주고 있다고 설명합니다. "오로촌이 멧돝을 잡아 나를 잔치해 보내던 것도 쏠론이 십릿길을 따라 나와 울던 것도 잊지 않았다"라는 유사한 통사 구조를 통해 화자가 이별의 기억을 간직하고 있음을 나타내고 있습니다.
#
# - ⑤ 선택지는 ㉥에서 '없다'와 그 앞에 열거된 시어들을 통해 화자가 가깝게 느끼고 가치를 부여했던 것들이 부재함을 표현하고 있다고 설명합니다. "아, 나의 조상은 형제는 일가친척은 정다운 이웃은 그리운 것은 사랑하는 것은 우러르는 것은 나의 자랑은 나의 힘은 없다"라는 구절을 통해 화자가 소중하게 여겼던 것들이 사라졌음을 강조하고 있습니다.
#
#
# =============================== ✅ 문항 2024-09-국어_25 (정답: 4) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④
#
# [해설]
# - ④번 선택지는 화자가 물고기의 모습을 통해 유년 시절 생가에서 외따로 지내야 했던 자신의 모습을 투영하고 있다고 설명하고 있습니다. 그러나 지문에서 화자는 물고기들이 '비좁은 구석방에' 서 '급한 궁리를 하'는 모습을 보고, 물고기들이 자신을 알아보지 못하고 흩어지는 상황을 통해 생가의 식구들이 자신을 알아보지 못하는 상황을 연상하고 있습니다. 이는 외따로 지내야 했던 자신의 모습보다는, 가족들이 자신을 알아보지 못하는 상황을 더 강조하고 있습니다. 따라서 ④번 선택지는 지문과 <보기>의 내용과 일치하지 않습니다.
#
# - ①번 선택지는 '투명한 창'을 통해 본 물고기의 생활 공간을 '물고기네 방'이라고 표현한 부분을 통해, 화자가 물고기의 공간과 자신의 생가를 겹쳐 보고 있음을 설명하고 있습니다. 이는 지문에서 화자가 물고기의 공간을 자신의 생가와 연결 짓고 있음을 잘 드러내고 있습니다.
#
# - ②번 선택지는 '창으로 나를 보'고 '사방 쪽방으로 흩어'지는 물고기들의 움직임을 통해, 화자가 '생가의 식구들'이 자신을 못 알아본 것으로 표현하고 있음을 설명하고 있습니다. 이는 지문에서 물고기들이 흩어지는 모습을 통해 가족들이 자신을 알아보지 못하는 상황을 연상하고 있음을 잘 드러내고 있습니다.
#
# - ③번 선택지는 '젖을 갓 뗀 어린것들'이 '그네끼리 놀고'라는 표현을 통해, 화자가 물고기들이 노는 모습을 보고 유년 시절 생가에서 지내던 아이들의 모습을 떠올리고 있음을 설명하고 있습니다. 이는 지문에서 물고기들의 행동을 통해 유년 시절의 기억을 떠올리고 있음을 잘 드러내고 있습니다.
#
# - ⑤번 선택지는 '마음아, 너도 아직' 생가에서 '살고 있는가'라는 표현을 통해, 성년인 자신의 마음속에 유년의 기억이 자리 잡고 있음을 설명하고 있습니다. 이는 지문에서 화자가 여전히 유년 시절의 기억을 간직하고 있음을 잘 드러내고 있습니다.
#
#
# =============================== ✅ 문항 2024-09-국어_26 (정답: 5) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⓐ와 ⓑ는 각각 (나)와 (다) 지문에서 등장하는 요소로, 이들은 모두 대상을 새롭게 주목하게 하는 계기를 마련하고 있습니다. (나) 지문에서 ⓐ(살얼음의 창)는 화자가 물고기와의 관계를 새롭게 인식하게 하며, 물고기네 방이 자신의 생가와 같다고 느끼게 합니다. 이는 화자가 자신의 과거와 현재를 새롭게 바라보게 하는 계기가 됩니다. (다) 지문에서 ⓑ(기둥)는 나무가 인간의 도움을 받아 살아가고 있음을 보여주며, 이는 자연과 인간의 관계를 새롭게 인식하게 합니다. 따라서 ⓐ와 ⓑ는 모두 대상을 새롭게 주목하게 하는 계기를 마련하고 있다고 할 수 있습니다.
#
# - ① ⓐ는 화자의 불안을 심화하는 역할을 한다고 보기 어렵습니다. ⓐ는 화자가 물고기와의 관계를 새롭게 인식하게 하는 계기를 마련합니다. 또한, ⓑ는 글쓴이의 의지를 북돋아 주는 역할보다는 자연과 인간의 관계를 새롭게 인식하게 합니다.
# - ② ⓐ는 화자의 이상향을 형상화하는 역할을 하지 않습니다. ⓐ는 화자가 자신의 과거와 현재를 새롭게 바라보게 하는 계기를 마련합니다. ⓑ 또한 글쓴이의 태도를 전환하는 역할보다는 자연과 인간의 관계를 새롭게 인식하게 합니다.
# - ③ ⓐ는 ⓑ와 달리 화자에게 책임감을 떠올리게 하는 계기가 된다고 보기 어렵습니다. ⓐ는 화자가 자신의 과거와 현재를 새롭게 바라보게 하는 계기를 마련합니다.
# - ④ ⓑ는 ⓐ와 달리 글쓴이가 처한 상황을 극복하게 하는 역할을 한다고 보기 어렵습니다. ⓑ는 자연과 인간의 관계를 새롭게 인식하게 하는 계기를 마련합니다.
#
#
# =============================== ✅ 문항 2024-09-국어_27 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 글쓴이가 '이문원 동쪽 늙은 나무'가 '저 깊은 산중 인적 끊긴 골짜기'에서 자란 나무보다 번성하게 자랐다고 한 이유를 인간의 도움이 필요하다는 것을 말하기 위함이라고 설명하고 있습니다. 그러나 지문에서는 '이문원 동쪽 늙은 나무'가 인간의 도움을 받아 번성하게 자랐다는 점을 강조하고 있으며, 이는 인간과 나무가 서로 이익을 주고받는 관계를 나타내기 위한 것입니다. 따라서 ⑤번은 적절하지 않은 설명입니다.
#
# - ①번 선택지는 '이문원 동쪽 늙은 나무'가 '백여 년'을 살 수 있었던 이유로 인간이 나무를 보살펴 주었기 때문이라고 설명하고 있습니다. 이는 지문에서 나무가 인간의 도움을 받아 오랫동안 무성하게 자랐다는 점과 일치합니다.
#
# - ②번 선택지는 글쓴이가 '널찍이 드리운 서늘한 그늘'로 인해 '훌쩍 벗어나 있는 기분'이 든 것을 인간이 나무에게서 이익을 얻은 경우로 설명하고 있습니다. 이는 지문에서 나무가 제공하는 그늘을 통해 인간이 이익을 얻는 상황을 나타내므로 적절합니다.
#
# - ③번 선택지는 '풀과 나무'가 '몸을 보전하는 계책'이 있는 것을 '조물주'가 서로 다른 생명체가 이익을 주고받도록 해 준 경우로 설명하고 있습니다. 이는 지문에서 자연의 섭리에 따라 생명체들이 서로 이익을 주고받는 관계를 설명하는 부분과 일치합니다.
#
# - ④번 선택지는 '암소'의 '뿔이 구부러져 안쪽으로 향'하는 위험을 인간이 '톱으로 잘라'서 해결해 주는 것을 '가축'이 인간에게 의지하며 살아가는 경우로 설명하고 있습니다. 이는 지문에서 가축이 인간의 도움을 받아 살아가는 상황을 설명하는 부분과 일치합니다.
#
#
# =============================== ✅ 문항 2024-09-국어_28 (정답: 4) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④ 서술자가 특정 인물의 시선을 통해 인물의 특징을 관찰하여 알려 주고 있다.
#
# [해설]
# - [A] 부분에서는 서술자가 민도식의 시선을 통해 권 씨라는 인물의 특징을 관찰하고 있습니다. "도식이 보기엔 첫눈에 결코 만만한 상대가 아니었다"라는 문장을 통해 민도식의 시각에서 권 씨의 자신감 있는 태도와 외모의 특징을 서술하고 있습니다. 이는 특정 인물의 시선을 통해 다른 인물의 특징을 관찰하여 독자에게 전달하는 방식입니다.
#
# - ① 인물의 행위를 사실적으로 그려 내어 내적 갈등을 표면화하고 있다는 설명은 [A] 부분에 적절하지 않습니다. [A]에서는 권 씨의 외모와 태도를 중심으로 서술하고 있을 뿐, 내적 갈등을 직접적으로 드러내고 있지 않습니다.
#
# - ② 과거와 현재를 교차하여 인물이 겪는 인식의 변화를 드러내고 있다는 설명은 [A] 부분에 적절하지 않습니다. [A]는 특정 시점에서 권 씨의 외모와 태도를 관찰하는 장면으로, 과거와 현재를 교차하는 서술이 아닙니다.
#
# - ③ 공간적 배경을 구체적으로 묘사하여 인물이 처한 상황을 드러내고 있다는 설명은 [A] 부분에 적절하지 않습니다. [A]는 인물의 외모와 태도에 대한 관찰에 집중하고 있으며, 공간적 배경에 대한 구체적인 묘사는 없습니다.
#
# - ⑤ 서술자가 인물의 경험을 삽화 형식으로 나열하여 사건을 입체적으로 보여 주고 있다는 설명은 [A] 부분에 적절하지 않습니다. [A]는 삽화 형식으로 사건을 나열하는 것이 아니라, 권 씨의 외모와 태도를 관찰하는 장면입니다.
#
#
# =============================== ✅ 문항 2024-09-국어_29 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③번 선택지는 권 씨가 ㉠을 마저 입을지를 선택하는 일이 중요한 문제라고 생각하고 있다고 해석하고 있습니다. 그러나 지문에서 권 씨는 "한쪽에선 작업 중에 팔이 뭉텅 잘려져 나간 사람이 있고 그 팔 값을 찾아 주려고 투쟁하는 사람들이 있는 반면에 다른 한쪽에선 몸에 걸치는 옷 때문에 자기 인생을 걸려는 분들도 계시구나 하는 생각이 들어서 그냥 지나칠 수가 없었습니다."라고 말하며, 제복 착용 문제를 상대적으로 덜 중요한 문제로 보고 있음을 드러내고 있습니다. 따라서 권 씨가 제복 착용 문제를 중요한 문제로 생각하고 있다는 해석은 부적절합니다.
#
# - ①번 선택지는 "이미 끝난 일이야"라는 말로 보아, 남자 사원들 중에 ㉠을 마저 입을지를 결정해야 하는 상황에 직면했다고 생각하는 사람이 있음을 알 수 있다고 했는데, 이는 지문에서 민도식이 "이제 길은 두 가지뿐야. 나머지 절반을 찾아서 마저 몸에 꿰든가, 아니면 기왕 우리 몸에 입혀진 절반을 아예 벗어 버리든가 각자가 알아서 결정할 일이야."라고 말한 부분과 일치합니다.
#
# - ②번 선택지는 "험악해진 분위기"로 보아, ㉠과 관련된 문제로 남자 사원들 사이에 소란스러운 일이 있었음을 알 수 있다고 했는데, 이는 지문에서 민도식이 "험악해진 분위기를 간신히 가라앉혔다."라고 한 부분과 일치합니다.
#
# - ④번 선택지는 "총각 사원 하나"에 대한 아내의 반응으로 보아, 아내는 총각 사원이 ㉠ 때문에 회사를 스스로 그만두었다는 소문을 믿지 않고 있음을 알 수 있다고 했는데, 이는 지문에서 아내가 "사표를 제출한 게 아니라 강제로 모가지가 잘린 거라고 굳게 믿고 있었다."라고 한 부분과 일치합니다.
#
# - ⑤번 선택지는 "검정 곤색 일색"으로 보아, 체육 대회에 참석한 전체 사원이 ㉠을 마저 입게 되었음을 알 수 있다고 했는데, 이는 지문에서 "검정 곤색 일색의 운동장을 넘어다보는 순간"이라는 표현과 일치합니다.
#
#
# =============================== ✅ 문항 2024-09-국어_30 (정답: 5) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤ 선택지는 부적절합니다. ⓔ는 사원들이 사복을 입은 민도식에 대한 불만을 드러내는 반응이 아니라, 민도식이 사복 차림으로 체육 대회에 참석한 자신을 사원들이 야유하는 듯한 기분이 들었다는 민도식의 주관적인 느낌을 나타낸 것입니다. 이는 지문에서 "노래 부르는 사원들 모두가 작당해서 ⓔ(지각한 사람을 야유하는) 듯한 기분이 들었다."라는 부분에서 알 수 있습니다. 따라서 이는 사원들의 실제 반응이 아니라 민도식의 심리적 반응입니다.
#
# - ① 선택지는 적절합니다. ⓐ는 권 씨가 사무직 사원들의 대화에 관심이 있었음을 나타내는 반응으로, "말씀 내용이 동림산업에 계신 분들 같아서 저도 모르게 관심이 갔나 봅니다."라는 권 씨의 대사에서 확인할 수 있습니다.
#
# - ② 선택지는 적절합니다. ⓑ는 장상태가 화를 내며 큰 소리로 명령하였기 때문에 미스 윤이 놀라서 눈이 휘둥그레진 반응을 보인 것으로, "장상태가 화를 벌컥 내면서 큰 소리로 미스 윤을 불렀다."라는 부분에서 알 수 있습니다.
#
# - ③ 선택지는 적절합니다. ⓒ는 아내가 집을 나서지 않고 있는 남편 때문에 걱정하여 보인 반응으로, "아내는 시종 근심스런 눈초리를 거두지 않았다."라는 부분에서 확인할 수 있습니다.
#
# - ④ 선택지는 적절합니다. ⓓ는 전체 사원들이 같은 옷을 입고 군대처럼 도열한 모습을 본 민도식이 숨이 턱 막혀 오는 반응을 보인 것으로, "철책 너머로 검정 곤색 일색의 운동장을 넘어다보는 순간 민도식은 갑자기 ⓓ(숨이 턱 막혀 옴)을 느꼈다."라는 부분에서 확인할 수 있습니다.
#
#
# =============================== ✅ 문항 2024-09-국어_31 (정답: 2) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - <보기>에서는 '중도적 주인공'이 집단의 논리를 비판적으로 인식하지만, 행동으로 옮기지 못하거나 집단에 동화되지 못한 채 머뭇거리는 모습을 보인다고 설명하고 있습니다. 민도식은 '동림산업'의 논리에 대해 비판적으로 인식하고 있으나, 행동으로 옮기지 못하는 모습을 보입니다.
#
# - ① 민도식이 '준비 위원회'의 '회의'에 담긴 '경영자'의 숨은 의도를 파악하여 발언하는 장면은 그가 비판적으로 인식하는 주체적인 관점을 지니고 있음을 보여줍니다. 이는 <보기>의 '중도적 주인공'의 인식 측면과 일치합니다.
#
# - ② 권 씨를 '노리갯감'으로 삼자는 장상태의 '눈짓'에 선뜻 동참하지 않은 것은 민도식이 논쟁에 적극적으로 참여하지 않음을 보여줍니다. 그러나 이는 단순히 논쟁에 참여하지 않는 것일 뿐, <보기>에서 설명하는 '중도적 주인공'의 모습과는 다릅니다. <보기>에서는 주인공이 집단의 논리를 인식하지만 행동으로 옮기지 못하는 상태를 강조하고 있습니다. 따라서 이 선택지는 적절하지 않습니다.
#
# - ③ 민도식이 아내에게 큰소리로 자신의 생각을 말하면서도 결국 집을 나서는 모습은, 그가 '동림산업'의 문제를 인식하고 있지만 회사를 떠나지 못하는 상황에 놓여 있음을 보여줍니다. 이는 <보기>의 설명과 일치합니다.
#
# - ④ 민도식이 '사복 차림'으로 체육 대회에 가면서 자신을 '꽁무니에 따라붙으려는' 사람이라고 생각하는 것은 집단의 논리를 거부하고 싶지만, 동시에 소속되고 싶은 마음도 지니고 있음을 보여줍니다. 이는 <보기>의 설명과 일치합니다.
#
# - ⑤ 민도식이 '제1 공장' 정문 앞에서 '붙박여 버린 듯' 움직이지 않는 모습은, 그가 '동림산업'의 정책에 대한 비판을 행동으로 옮길지 여부를 결정하지 못하고 있음을 보여줍니다. 이는 <보기>의 설명과 일치합니다.
#
#
# =============================== ✅ 문항 2024-09-국어_32 (정답: 1) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ① 말을 건네는 방식을 통해 화자의 요구를 전달하고 있다.
#
# [해설]
# - (가), (나), (다) 모두에서 화자는 특정 대상에게 말을 건네는 방식으로 자신의 요구나 바람을 전달하고 있습니다. (가)에서는 "허술한 배 두신 분네는 모두 조심하소서"라는 구절을 통해, (나)에서는 "온 놈이 온 말을 하여도 임이 짐작하소서"라는 구절을 통해, (다)에서는 "아이야 구럭 망태 찾아라", "아이야 도롱이 삿갓 차려라" 등에서 볼 수 있듯이, 화자가 특정 대상에게 직접적으로 말을 건네는 방식으로 자신의 요구를 전달하고 있습니다.
#
# - ② 대상을 의인화하여 화자와 자연의 유대감을 나타내고 있다는 설명은 지문에 명확히 드러나지 않습니다. 각 시조에서 자연물이나 대상을 의인화하여 유대감을 나타내는 부분은 없습니다.
#
# - ③ 과거와 현재를 대비하여 미래에 대한 전망을 드러내고 있다는 설명은 지문에 나타나지 않습니다. 각 시조는 주로 현재의 상황이나 감정에 초점을 맞추고 있습니다.
#
# - ④ 물음의 방식을 활용하여 대상에 대한 친밀감을 표현하고 있다는 설명은 (가)와 (나)에서는 일부 나타날 수 있으나, (다)에서는 물음의 방식보다는 명령형 문장을 통해 요구를 전달하고 있습니다.
#
# - ⑤ 풍경을 사실적으로 묘사하여 계절의 변화상을 그려 내고 있다는 설명은 (다)에서 일부 나타날 수 있으나, (가)와 (나)에서는 주로 감정이나 상황에 대한 묘사가 중심이 되어 계절의 변화상을 그려내는 데 중점을 두지 않습니다.
#
#
# =============================== ✅ 문항 2024-09-국어_33 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③번 선택지는 <제 1수> 중장과 <제 3수> 중장에서 나타나는 화자의 걱정이 각 수의 종장에서 강화된다고 했지만, 이는 지문과 일치하지 않습니다. <제 1수> 중장에서는 "이 몸이 이 나물 아니면 조석 어이 지내리"라는 표현을 통해 고사리 채취에 대한 걱정을 드러내고 있지만, 종장에서는 이러한 걱정이 강화되기보다는 일상적인 삶의 모습을 담담하게 받아들이는 태도를 보여줍니다. <제 3수> 중장에서는 "서투른 따비는 누구와 마주 잡을꼬"라는 농사일에 대한 걱정이 드러나지만, 종장에서는 "두어라 성세궁경도 역군은이시니라"라는 표현을 통해 오히려 태평한 세월에 대한 감사와 만족을 드러내고 있습니다. 따라서 걱정이 종장에서 강화된다고 보기 어렵습니다.
#
# - ①번 선택지는 각 수의 첫 음보가 "아이야"로 동일하게 시작되어 시상 전개에 안정감을 부여하고 있다는 점에서 적절합니다.
# - ②번 선택지는 <제 1수>의 "구럭 망태"와 <제 2수>의 "도롱이 삿갓" 등 생활 도구를 언급하여 화자의 일상적인 삶을 보여주고 있다는 점에서 적절합니다.
# - ④번 선택지는 <제 1수> 종장의 "이 몸이 이 나물 아니면 조석 어이 지내리"와 <제 3수> 초장의 "죽조반 다오"에서 간단한 먹을거리를 언급하여 소박한 생활을 드러내고 있다는 점에서 적절합니다.
# - ⑤번 선택지는 <제 4수> 종장의 "어즈버 희황상인을 오늘 다시 보는구나"에서 감탄 표현을 활용하여 시상을 집약하고 있다는 점에서 적절합니다.
#
#
# =============================== ✅ 문항 2024-09-국어_34 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③번 선택지는 '심의산'을 화자의 심회로, '오뉴월'의 '자취눈'을 화자의 복잡한 심정으로 비유하여, (나)의 초장과 중장에서 당쟁의 상황에서 굳은 마음을 견지하려는 화자의 의지를 드러낸다고 해석하고 있습니다. 그러나 (나)의 시조에서는 '심의산'과 '오뉴월'의 '자취눈'이 화자의 복잡한 심정을 비유한 표현으로 해석되기보다는 자연의 변화와 그 속에서의 화자의 감정 변화를 나타내는 데 중점을 두고 있습니다. 따라서 이 선택지는 지문과 <보기>의 설명에 부합하지 않습니다.
#
# - ①번 선택지는 '풍파'를 험난한 정치 현실로, '일렁이던 배'를 시련을 겪은 관료로 해석하여, (가)의 초장을 당쟁에 휘말린 사람이 정치적 소외 상태에 놓인 것으로 해석하고 있습니다. 이는 지문과 <보기>의 설명에 부합합니다.
#
# - ②번 선택지는 '구름이 험하거늘'을 정치적 위기의 조짐으로, '허술한 배 두신 분네'를 신진 관료로 해석하여, (가)의 종장에서 화자가 정치 경험이 충분치 않은 이들에게 정치의 험난함을 알려주는 것으로 해석하고 있습니다. 이는 지문과 <보기>의 설명에 부합합니다.
#
# - ④번 선택지는 '온 놈이 온 말을 하'는 상황을 비방과 모략이 난무하는 현실로, '임'을 임금으로 해석하여, (나)의 종장에서 온갖 참소를 임금이 잘 판단해 달라는 것으로 해석하고 있습니다. 이는 지문과 <보기>의 설명에 부합합니다.
#
# - ⑤번 선택지는 '미늘 없는 낚시'를 욕심 없이 사는 삶으로 해석하여, (다)의 <제 2수> 종장에서 자연과 더불어 지내는 화자의 흥을 드러내는 것으로 해석하고 있습니다. 이는 지문과 <보기>의 설명에 부합합니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_18 (정답: 2) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 복록의 상황에 대한 잘못된 해석을 포함하고 있습니다. 지문에서 복록은 자신의 죄를 알고 후원에 올라가 이미 죽었다고 언급되어 있습니다. 이는 복록이 심리적 중압감을 느끼기 전에 이미 자살한 상태임을 나타내므로, 심리적 중압감을 느꼈다는 표현은 맞지 않습니다.
#
# - ①번 선택지는 ㉠에서 호첩에게 물은 '연고'의 내용이 왕비가 말한 '사연'의 내용과 관련이 있다는 점에서 적절합니다. 지문에서 승상은 왕비에게 사연을 듣고 이미 아는 바라고 하며, 이는 호첩에게 물은 연고와 관련이 있음을 시사합니다.
#
# - ②번 선택지는 ㉠에서 승상이 황상에게 올린 '상소'의 내용이 '이미 아는 바'와 같다는 점에서 적절합니다. 승상은 왕비에게 사연을 이미 아는 바라고 했고, 이는 상소에 포함된 내용과 일치합니다.
#
# - ③번 선택지는 ㉡에서 승상이 사연의 진상을 밝히기 위해 왕비가 '그놈'의 행위를 알게 된 경위를 중요하게 여겼다는 점에서 적절합니다. 승상은 왕비에게 '그놈'이 충렬부인 방에 간 것을 어떻게 알았는지를 물어 경위를 확인하려 했습니다.
#
# - ④번 선택지는 ㉡에 대한 왕비의 대답에서 왕비에게 '그놈'의 행위에 대해 제보한 사람이 있었다는 점에서 적절합니다. 왕비는 사촌 오라비가 이르러 알게 되었다고 답변합니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_19 (정답: 4) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④
#
# [해설]
# - ④번 선택지는 지문에서 충렬부인이 누명을 쓰게 된 계략을 설명하는 부분과 일치합니다. 정렬부인이 충렬부인을 침소로 가도록 강권하여 누명을 씌우는 계략을 꾸몄다는 내용이 지문에 명확히 드러나 있습니다. "정렬부인이 앓는 체하고 누웠사오매 충렬부인이 약으로 구병하며 곁에 있으시매 침소로 가라 강권하여 침소로 마지못하여 가시매"라는 부분이 이를 뒷받침합니다.
#
# - ①번 선택지는 누명이 벗겨지면서 누명을 썼던 인물인 충렬부인이 자신의 어리석음을 탓하는 내용이 지문에 나타나지 않으므로 부적절합니다.
# - ②번 선택지는 남주인공인 승상이 누명을 씌운 인물인 정렬부인의 처벌을 유보하는 내용이 지문에 나타나지 않으므로 부적절합니다.
# - ③번 선택지는 누명의 내용이 충렬부인이 구덩이에 있다는 사실과 관련이 없으므로 부적절합니다.
# - ⑤번 선택지는 누명이 벗겨지는 계기가 남주인공이 자신의 어머니가 극단적 선택을 하겠다는 것을 만류한 것과 관련이 없으므로 부적절합니다. 누명이 벗겨지는 계기는 금연이 정렬부인의 계략을 고백하는 부분입니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_20 (정답: 1) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 금연이 승상으로부터 정렬부인이 거짓으로 앓아 누웠었다는 정보를 얻었다고 설명하고 있습니다. 그러나 지문에서 금연은 승상에게 정렬부인의 모략과 관련된 정보를 자백하는 입장에 있습니다. 즉, 금연은 정보를 제공하는 쪽이지 정보를 얻는 쪽이 아닙니다. 따라서 ⑤번 선택지는 지문과 일치하지 않습니다.
#
# - ①번 선택지는 원수(정을선)가 중군장에게 서융을 사로잡으라고 명령하는 내용으로, 이는 지문에서 "나는 집에 변이 있어 먼저 가니 중군장은 차후에 인솔하여 오라"는 부분과 일치합니다.
#
# - ②번 선택지는 승상이 월매에게 충렬부인이 어디 있는지 묻는 내용으로, 이는 지문에서 "충렬부인은 어디 계시냐?"라는 승상의 질문과 일치합니다.
#
# - ③번 선택지는 옥졸이 금연으로부터 옥중 시신의 정체와 관련된 정보를 얻는 내용으로, 이는 지문에서 옥졸이 금연에게서 정보를 듣고 발설한 것으로 설명되어 일치합니다.
#
# - ④번 선택지는 옥졸이 승상에게 금연이 옥중 시신에 대해 발설했을 것이라는 의혹을 제기받는 내용으로, 이는 지문에서 승상이 옥졸에게 금연이 발설했을 가능성을 묻는 부분과 일치합니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_21 (정답: 4) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤ 선택지는 정렬부인이 '승상의 호통 소리'에 반응하는 장면을 가정의 상층 인물이 희화화되는 것으로 해석하고 있습니다. 그러나 지문에서는 정렬부인이 승상의 호통 소리를 듣고 놀라서 똥을 싸고 자빠졌다는 표현이 있어, 이는 정렬부인의 위엄이 실추되는 행동으로 볼 수는 있지만, 희화화된다고 보기에는 무리가 있습니다. 희화화는 보통 인물의 행동이나 성격이 과장되거나 우스꽝스럽게 묘사되는 것을 의미하는데, 이 장면에서는 정렬부인의 두려움과 당황스러움이 드러날 뿐 희화화된다고 보기는 어렵습니다.
#
# - ① 선택지는 정을선이 황상에게 올린 상소에서 대원수와 가장으로서의 모습이 드러나며, 가정 안팎의 사건에 남주인공이 두루 관여하고 있음을 나타냅니다. 이는 지문에서 정을선이 집안의 문제를 해결하기 위해 적극적으로 나서는 모습과 일치합니다.
#
# - ② 선택지는 승상이 충렬부인을 구출하는 장면에서 인물의 고난과 감정이 극대화된 형상을 설명하고 있습니다. 지문에서 충렬부인이 매우 야위어 뼈가 드러난 모습과 승상이 통곡하는 모습이 이러한 극대화를 잘 보여주고 있습니다.
#
# - ③ 선택지는 왕비가 '앙천통곡'하는 장면에서 일부다처제의 문제가 개인의 인성 문제로 축소되고 있음을 설명합니다. 이는 지문에서 왕비가 자신의 잘못을 깨닫고 통곡하는 모습과 연결됩니다.
#
# - ④ 선택지는 월매가 매를 맞는 장면에서 월매가 능동적인 행위자로 등장하는 것을 설명합니다. 지문에서 월매는 죽음을 각오하고 진실을 밝히려는 의지를 보이며, 이는 하층의 시비가 능동적인 행위자로 등장하는 것을 보여줍니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_22 (정답: 4) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④
#
# [해설]
# - (가), (나), (다) 모두 특정한 행위를 중심으로 행위 주체와 대상의 관계를 드러내고 있습니다.
#   - (가)에서는 "배를 밀어내는" 행위를 통해 화자와 배(대상)의 관계를 드러내고 있으며, 이는 이별과 슬픔의 감정을 표현합니다.
#   - (나)에서는 "당신을 부르는" 행위를 통해 화자와 '당신'(대상)의 관계를 드러내며, 이는 그리움과 상처의 감정을 나타냅니다.
#   - (다)에서는 "편지를 쓰는" 행위를 통해 화자와 그녀(대상)의 관계를 드러내며, 이는 사랑과 자기 성찰의 과정을 보여줍니다.
#
# - 나머지 선택지들은 지문과 일치하지 않습니다.
#   - ① 하강적 이미지를 활용하여 시간의 흐름을 보여주는 것은 지문에서 명확히 드러나지 않습니다.
#   - ② 자연물에 빗대어 부정적 현실의 극복 가능성을 암시하는 내용은 지문에 나타나지 않습니다.
#   - ③ 동일한 구절의 반복과 변주를 통해 상황의 반전을 표현하는 것은 지문에서 확인되지 않습니다.
#   - ⑤ 공간의 이동에 따라 내용을 전개하여 역동적 분위기를 강화하는 것은 지문에서 드러나지 않습니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_23 (정답: 5) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 '밀려들어 온 배'가 '아무 소리 없이' 다시 돌아온 배라는 점에서 대상과의 재회가 예상대로 이루어짐을 드러낸다고 했지만, 지문에서는 '내 안으로 들어오는 배여, 아무 소리 없이 밀려들어오는 배여'라는 표현을 통해 배가 다시 돌아오는 것이 아니라, 새로운 배가 들어오는 것을 암시합니다. 이는 새로운 시작이나 다른 감정의 유입을 의미할 수 있으며, 대상과의 재회가 이루어졌다는 해석은 지문에 근거하지 않습니다.
#
# - ①번 선택지는 '아주 추락하지 않을 순간'에 '배'를 밀던 '손'이 '아슬아슬히 배에서 떨어진다'는 표현을 통해 이별의 정서적 긴장감을 드러내고 있습니다. 이는 지문에서 이별의 순간에 대한 긴장감과 불안함을 잘 나타내고 있습니다.
#
# - ②번 선택지는 '뵈지도 않는 길'이 '사랑'이 '떠나'는 길이라는 점에서 이별의 막막한 상황을 공간의 형상으로 드러낸다는 설명이 지문과 일치합니다. 이는 이별의 불확실성과 막막함을 공간적으로 표현한 것입니다.
#
# - ③번 선택지는 '슬픔'을 '밀어내는 것'을 '배'를 밀듯 '한껏 세게 밀어낸다'는 표현을 통해 이별의 아픔을 떨쳐 내려는 화자의 태도를 드러내고 있습니다. 이는 슬픔을 적극적으로 밀어내려는 의지를 보여줍니다.
#
# - ④번 선택지는 '배가 나가며 생긴 흉터'가 '잠시 머물다 가라앉는다'는 표현을 통해 이별의 슬픔이 잦아든 상태에 있음을 드러내고 있습니다. 이는 이별의 상처가 시간이 지나면서 점차 사라지는 과정을 나타냅니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_24 (정답: 2) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - (나) 지문에서 '당신'은 화자의 내면에 살고 있는 '병자'로서 연민의 대상이 아니라, 화자가 부르는 대상이며, 그 대상은 화자에게 다양한 감정을 불러일으키는 존재입니다. 지문에서 "킥킥……, 당신을 부릅니다"라는 부분을 통해 '당신'이 화자의 내면에 있는 병자가 아니라 외부의 존재임을 알 수 있습니다. 또한, "당신 이쁜 당신……, 당신이라는 말 참 좋지요, 내가 아니라서 끝내 버릴 수 없는, 무를 수도 없는 참혹……, 그러나 킥킥 당신"이라는 구절에서는 '당신'이 화자에게 숙명적 존재임을 드러내고 있습니다. 따라서 ②번 선택지는 적절하지 않습니다.
#
# - ①번 선택지는 "한때 적요로움의 울음이 있었던 때"라는 구절을 통해 '당신'이 화자와 '한때'의 기억을 잇는 매개적 존재임을 나타내므로 적절합니다.
# - ③번 선택지는 "당신……, 킥킥거리며"라는 구절에서 '당신'이 화자의 눈앞에 없지만 부름으로써 환기되는 대상임을 보여주므로 적절합니다.
# - ④번 선택지는 "내가 아니라서 끝내 버릴 수 없는, 무를 수도 없는 참혹……, 그러나 킥킥 당신"이라는 구절을 통해 '당신'이 화자에게 숙명적 존재임을 나타내므로 적절합니다.
# - ⑤번 선택지는 "세월에 대해 혹은 사랑과 상처, 상처의 몸이 나에게 기대와 저를 부빌 때 당신……"이라는 구절을 통해 '당신'이 화자에게 '사랑'과 '슬픔'을 경험하게 하는 이중적 존재임을 나타내므로 적절합니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_25 (정답: 2) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - ②번 선택지는 "상처에 기대, 나 킥킥……, 당신을 부릅니다"라는 구절을 말줄임표와 쉼표를 사용한 서술로 해석하고 있습니다. 그러나 이 구절은 상실의 고통으로 인해 사랑의 기억이 희미해지는 화자의 심적 상태를 드러낸다고 보기 어렵습니다. 오히려 이 구절은 상처와 슬픔 속에서도 화자가 '당신'을 부르며 그 존재에 기대고 있는 모습을 보여주고 있습니다. 따라서 상실의 고통으로 사랑의 기억이 희미해지는 것이 아니라, 상처 속에서도 여전히 '당신'을 부르는 화자의 심리를 드러내는 표현입니다.
#
# - ①번 선택지는 '킥킥'이라는 웃음의 의성어가 반복적으로 등장하여 화자의 복합적인 정서를 드러내는 표현으로 적절합니다.
#
# - ③번 선택지는 맥락이 없어 보이는 표현들이 이어진 서술로서, 감정들이 뒤섞인 화자의 내면을 보여주는 표현으로 적절합니다.
#
# - ④번 선택지는 '마음의 무덤'이라는 표현이 화자의 심적 상태를 형상화하여 상실의 고통을 드러내는 비유로 적절합니다.
#
# - ⑤번 선택지는 '이쁜 당신……, 당신이라는 말 참 좋지요,'라는 구절이 끊어질 듯 이어지는 서술로, 대상에 대한 사랑의 감정을 드러내는 표현으로 적절합니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_26 (정답: 1) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⓐ와 ⓑ에 대한 이해를 위해서는 각각의 문맥을 살펴보아야 합니다. ⓐ는 "치병과 환후는 각각 따로인 것"이라는 구절로, 이는 병을 다스리는 것과 병 자체가 별개라는 인식을 나타냅니다. 즉, 화자가 병을 다스리려는 노력과 병 자체가 사라지는 것과는 별개라는 점을 인식하고 있음을 의미합니다. ⓑ는 "누군가가 듣기를 바라는 모든 고백이란, 위선이 아니면 위악이다."라는 구절로, 이는 고백이 진정한 의미를 갖기 어렵고, 결국 위선적이거나 악의적일 수 있음을 나타냅니다. 따라서 ⓐ와 ⓑ는 모두 아픔을 겪는 이나 고백을 하는 이가 그 아픔이나 고백의 실체를 지각하지 못하고 있음을 말한다고 볼 수 있습니다.
#
# - ①은 ⓐ에 대한 설명으로, 치병의 노력과 환후의 사라짐을 별개로 보는 인식은 맞지만, 이는 화자의 인식보다는 병과 치병의 관계에 대한 일반적인 설명에 가깝습니다.
#
# - ②는 ⓐ에 대한 설명으로, 화자가 대상의 아름다움을 발견함으로써 환후를 의식하지 않게 되었다는 내용은 지문에서 찾아볼 수 없습니다.
#
# - ③은 ⓑ에 대한 설명으로, 사랑의 편지가 위선과 위악에서 벗어날 수 있다는 내용은 지문과 일치하지 않습니다. 오히려 고백이 위선적이거나 악의적일 수 있음을 나타냅니다.
#
# - ④는 ⓑ에 대한 설명으로, 더 나은 자신을 드러내려는 욕망이 상대를 매혹하는 진정한 요인이라는 내용은 지문에서 찾아볼 수 없습니다. ⓑ는 고백이 위선적이거나 악의적일 수 있음을 나타냅니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_27 (정답: 1) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ①
#
# [해설]
# - ① 선택지는 '익명의 욕구'를 '통제할 수 없'다는 것을 상대를 향한 '그'의 사랑이 운명적이어서 사랑을 멈출 수 없음을 의미한다고 설명하고 있습니다. 그러나 지문에서는 "그 통제할 수 없는 익명의 욕구가 그 편지의 현실적인 목표를 잊어버리게 만들기 때문이다."라고 하여, '익명의 욕구'는 사랑의 운명적 성격보다는 편지의 본래 의도를 잊게 만드는 통제 불가능한 감정임을 나타냅니다. 따라서 ①은 부적절한 설명입니다.
#
# - ② 선택지는 '아무 전언도 들어 있지 않다'는 것이 '처음에 품었던 소소한 의도'를 잊음으로써 상대를 향한 글쓰기의 '현실적인 목표'가 실패로 돌아갔음을 의미한다고 설명하고 있습니다. 이는 지문에서 "모든 사랑의 편지는 마지막 순간, 도구적이지 못하다. 세상의 모든 글쓰기가 최후의 순간에는 처음에 품었던 소소한 의도를 배반하는 것처럼"이라는 부분과 일치합니다.
#
# - ③ 선택지는 '2인칭을 경유하여 1인칭으로 돌아온다'는 것이 편지가 상대를 향한 '도구적' 기능을 하지 못하고 자기 고백에 그치게 됨을 의미한다고 설명하고 있습니다. 이는 지문에서 "고백이란 결국 2인칭을 경유하여 1인칭으로 돌아온다"라는 부분과 일치합니다.
#
# - ④ 선택지는 '편지 속의 그'를 그녀는 사랑했다는 것이 편지를 받은 그녀가 사랑한 상대는 편지 속의 '또 다른 영혼'임을 의미한다고 설명하고 있습니다. 이는 지문에서 "정확하게 말하면 ‘편지 속의 그’를 그녀는 사랑했다. 편지 속에는 그가 찾아낸 자신의 또 다른 영혼이 있었다."라는 부분과 일치합니다.
#
# - ⑤ 선택지는 '자신의 비루함을 뼛속 깊이 실감했다'는 것이 실제 자신과 이상화된 자신 사이의 간극을 자각한 '그'가 부끄러움에 빠져 있음을 의미한다고 설명하고 있습니다. 이는 지문에서 "그는 ‘편지 속의 그’를 연기하는 것이 부끄러웠고, 자신의 비루함을 뼛속 깊이 실감했다."라는 부분과 일치합니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_28 (정답: 4) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④
#
# [해설]
# - ④ 선택지는 ㉣ 부분의 서술 방식을 적절히 설명하고 있습니다. ㉣에서는 "어느 해 여름이었다. 하니까 그것은 허원이 자신의 배꼽을 잃어버리고 나서 불편하기 그지없는 세 번째의 여름을 맞고 있을 때였다."라는 문장이 있습니다. 이 문장은 허원의 상황에 대한 정보를 부가하여 서술하고 있으며, 그가 배꼽을 잃어버린 후 시간이 얼마나 흘렀는지를 독자에게 알려줍니다.
#
# - ① 선택지는 ㉠ 부분의 서술 방식을 잘못 설명하고 있습니다. ㉠에서는 허원의 내적 독백이 서술자의 설명을 통해 전달되고 있으며, 특정 인물의 생각을 누가 말하는지 명시하지 않고 있습니다.
#
# - ② 선택지는 ㉡ 부분의 서술 방식을 잘못 설명하고 있습니다. ㉡에서는 허원이 배꼽에 대해 체념하려는 시도를 서술하고 있으며, 서술자가 인물의 생각을 평가하거나 그 심화된 의미를 함축하여 서술하지 않습니다.
#
# - ③ 선택지는 ㉢ 부분의 서술 방식을 잘못 설명하고 있습니다. ㉢에서는 허원이 배꼽이 없는 생활에 익숙해지려는 시도를 서술자가 설명하는 방식으로 나타내고 있으며, 인물 자신의 생생한 목소리를 통해 서술하고 있지 않습니다.
#
# - ⑤ 선택지는 ㉤ 부분의 서술 방식을 잘못 설명하고 있습니다. ㉤에서는 배꼽에 관한 논의가 시중에 성행하기 시작한 현상을 설명하고 있으며, 인물 행동의 진행 과정을 순차적으로 서술하지 않습니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_29 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - 지문에서 허원은 배꼽이 사라진 후 그 사실을 잊고자 하지만, 배꼽이 없는 자신에 익숙해지지 못하고 심리적 동요를 겪습니다. 이는 "자꾸만 허전해서 견딜 수가 없어지곤 했다"는 표현에서 드러납니다. 이러한 심리적 동요는 허원이 일상적이지 않은 경험을 의식하게 된 결과로, 비밀의 서사적 기능이 인물의 심리적 동요를 부르는 것으로 작용합니다. 따라서 ③번 선택지가 가장 적절합니다.
#
# - ①은 허원의 신념이나 새로운 세계관을 형성하는 주제를 형성하는 내용이 지문에 명확히 드러나지 않습니다.
# - ②는 인간관계를 성찰하는 전환점으로 작용하는 내용이 지문에 나타나지 않습니다.
# - ④는 사회적 갈등을 해소하는 내용이 지문에 없습니다.
# - ⑤는 기성의 질서에 저항하는 신호로 작용하는 내용이 지문에 나타나지 않습니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_30 (정답: 5) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ⑤
#
# [해설]
# - ⑤번 선택지는 '허원'이 '실물'에 대한 인식을 '세상 사람들'과 공유하게 되면서 그간 이어 온 '사념'을 더 이상 지속하지 않게 된다고 서술하고 있습니다. 그러나 지문에서는 허원이 배꼽에 대한 자신의 사념을 계속해서 발전시키고 있으며, 세상 사람들의 관심이 높아짐에 따라 자신의 배꼽론을 더욱 확고히 하고 있다는 내용이 나옵니다. 따라서 허원이 사념을 지속하지 않게 된다는 내용은 지문과 일치하지 않습니다.
#
# - ①번 선택지는 허원이 배꼽이라는 '실물'과 관련하여 시작된 사념을 통해 존재의 의미를 발견해 간다는 내용으로, 지문에서 허원이 배꼽론을 발전시키며 자신의 존재와 우주에 대한 형이상학적 의미를 탐구하는 과정을 설명하고 있어 적절합니다.
#
# - ②번 선택지는 허원이 배꼽이 몸에서 큰 기능을 하지 않는다는 것을 알고 안도감을 느낀다는 내용으로, 지문에서 허원이 배꼽이 없더라도 외모나 바깥 생활에 큰 지장이 없다는 점에서 안도의 한숨을 내쉬는 부분과 일치합니다.
#
# - ③번 선택지는 허원이 사념을 통해 자신의 현재 상태에 대해 다른 방향에서 접근하고자 한다는 내용으로, 지문에서 허원이 배꼽에 대한 사념을 통해 자신의 존재와 세상과의 관계를 새롭게 이해하려는 시도를 하고 있다는 점에서 적절합니다.
#
# - ④번 선택지는 허원이 세상 사람들의 심상찮은 관심의 원인에 대해 궁금해하면서 주의를 기울이게 된다는 내용으로, 지문에서 허원이 세상 사람들이 배꼽에 관심을 가지게 된 이유를 알 수 없지만 그 현상에 주의를 기울이는 부분과 일치합니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_31 (정답: 4) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④
#
# [해설]
# - ④번 선택지는 "그의 사념이 도달한 '배꼽론'의 '확고한 경지'는 사소한 것의 심층적 의미를 탐색할 때 이를 수 있으므로, 그 사소한 것에 얽매이지 않는 자유로운 상태에서 실현이 가능해지겠군."이라고 설명하고 있습니다. 그러나 지문에서는 허원이 배꼽에 대한 사념에 얽매여 있으며, 그로 인해 오히려 자유롭지 못한 상태에 놓여 있음을 보여줍니다. 허원은 배꼽에 대한 사념이 심화될수록 "더욱더 허전해지고, 아무 곳에도 발이 닿아 있는 것 같지 않고, 혼자서 외롭게 허공을 둥둥 떠다니고 있는 것처럼 느껴졌다"고 서술되어 있습니다. 이는 사소한 것에 얽매이지 않는 자유로운 상태가 아니라, 오히려 그 사념에 얽매여 있는 상태를 나타냅니다.
#
# - ①번 선택지는 "의식의 끈이 건드려짐으로써 주인공이 비정상적 문제 상황에 지속적으로 주목하게 된 것이겠군."이라고 설명하고 있습니다. 이는 지문에서 허원이 배꼽이 없다는 사실을 의식하게 되면서 그에 대한 사념에 사로잡히게 되는 과정을 잘 설명하고 있습니다.
#
# - ②번 선택지는 "회사 출근을 포기하게 되고 늦잠 버릇이 사라진 상황은, 주인공의 일상이 변화된 모습을 보여 준다고 할 수 있겠군."이라고 설명하고 있습니다. 이는 지문에서 허원이 배꼽에 대한 사념에 집중하게 되면서 일상생활에 변화가 생긴 모습을 잘 설명하고 있습니다.
#
# - ③번 선택지는 "'배꼽'을 '탯줄'에 연관하여 이해하는 것은, 개인에 관련된 생각을 '우주와 만나'는 '심오하고 추상적인' 생각으로 확장하는 실마리가 된다고 할 수 있겠군."이라고 설명하고 있습니다. 이는 지문에서 허원이 배꼽을 통해 인간 존재와 우주에 대한 심오한 사색으로 확장해 나가는 과정을 잘 설명하고 있습니다.
#
# - ⑤번 선택지는 "'기묘한 현상'은, '배꼽 이야기'가 '일반화'되는 상황이 뜻밖이지만 '사실'로 나타나는 현상을 두고 일컬은 말이라고 할 수 있겠군."이라고 설명하고 있습니다. 이는 지문에서 배꼽에 대한 관심이 일반화되는 현상을 기묘하다고 표현한 부분과 일치합니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_32 (정답: 3) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ④
#
# [해설]
# - ④번 선택지는 "(가)" 지문에서 과거와 현재를 대비하여 악화된 처지를 보여주는 부분이 없기 때문에 적절하지 않습니다. 지문에서는 주로 현재의 상황에 대한 묘사와 그에 따른 부정적인 전망을 제시하고 있습니다.
#
# - ①번 선택지는 "허리 위로 볼작시면 베적삼이 깃만 남고 / 허리 아래 굽어보니 헌 잠방이 노닥노닥" 부분에서 대구 표현을 통해 외양을 묘사하여 대상의 처지를 드러내고 있습니다.
#
# - ②번 선택지는 "차라리 네 살던 곳에 아무렇게나 뿌리박혀" 부분에서 행위의 실행을 가정하여 부정적 전망을 제시하고 있습니다.
#
# - ③번 선택지는 "어와 생원인지 초관인지 / 그대 말씀 그만두고 이내 말씀 들어 보소" 부분에서 의문의 표현을 사용하여 상대의 행적에 대해 의심하고 있습니다.
#
# - ⑤번 선택지는 "한 몸 신역 삼 냥 오 전 돈피 두 장 의법이라 / 열두 사람 없는 구실 합쳐 보면 사십육 냥" 부분에서 구체적 수치를 제시하여 감당하기 힘든 현실을 드러내고 있습니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_33 (정답: 5) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ②
#
# [해설]
# - ②번 선택지는 ㉡을 언급하는 화자가 말을 건네는 상대에게 노동의 대가로 주는 보상이라고 설명하고 있습니다. (나)에서 "앞내 ㉡(고기) 뒷내 고기를 다 몽땅 잡아내 다래끼에 넣어 주거든 네 소 궁둥이에 얹어다가 주렴"이라는 구절을 통해, ㉡이 노동의 대가로 주는 보상임을 알 수 있습니다. 이는 상대에게 고기를 잡아 다래끼에 넣어 주면 그 대가로 소 궁둥이에 얹어 주라는 의미로 해석됩니다.
#
# - ①번 선택지는 ㉠을 언급하는 화자가 이주해 가려는 땅에서 재배할 약재라고 설명하고 있지만, (가)에서 ㉠(인삼)은 "칠팔월에 ㉠(인삼) 캐고 구시월에 돈피 잡아"라는 구절을 통해, 화자가 현재 살고 있는 곳에서 재배하는 약재임을 알 수 있습니다.
#
# - ③번 선택지는 ㉠과 ㉡이 모두 유흥을 목적으로 구하려는 물품이라고 설명하고 있지만, (가)와 (나) 모두에서 ㉠과 ㉡은 유흥과 관련이 없습니다. ㉠은 생계를 위한 약재이며, ㉡은 노동의 대가로 주는 보상입니다.
#
# - ④번 선택지는 ㉠과 ㉡이 모두 상대의 도움이 필요한 대상이라고 설명하고 있지만, (가)에서 ㉠은 화자가 스스로 재배하는 것이며, 상대의 도움이 필요하지 않습니다.
#
# - ⑤번 선택지는 ㉠과 ㉡이 모두 화자가 보기에 상대가 했으면 하는 행위의 대상이라고 설명하고 있지만, (가)에서 ㉠은 화자가 스스로 해야 하는 일이며, 상대가 해야 할 행위의 대상이 아닙니다.
#
#
# =============================== ✅ 문항 2024-수능-국어_34 (정답: 2) ===============================
#
# 📘 [문제에 대한 정답 및 해설]
# [정답]
# - ③
#
# [해설]
# - ③ (나)에서는 선행하는 화자가 아희들에게 고기를 다래끼에 넣어 소 궁둥이에 얹어 주라는 요청을 하고 있으며, 이에 대한 아희들의 대답이나 반응이 명시되어 있지 않아서 대화가 의외의 상황으로 전개되었다고 볼 수 없습니다. 따라서 선행하는 화자의 기대에 어긋난 대답이 있다는 설명은 부적절합니다.
#
# - ① (가)의 '그대'는 '자네'에게 도망가지 말고 고향에 남아 살라고 권유하며, 이는 갑산 백성들이 겪었던 고통을 사실적으로 보여주는 내용입니다. 따라서 적절한 설명입니다.
#
# - ② (가)의 '이내'는 자신의 집안 내력과 사회적 지위를 언급하며 사회의 부조리를 해결하자는 입장을 보이고 있으며, 이는 '그대'의 권유와 의견이 일치하지 않는다는 설명과 일치합니다.
#
# - ④ (나)의 경우, 선행하는 화자가 '고기'를 누구에게 주라고 명시하지 않아 불완전한 표현이 되었으며, 이는 대화의 전개 양상에 주목한다는 것을 드러냅니다. 따라서 적절한 설명입니다.
#
# - ⑤ (가)의 '그대'는 길 가는 '자네'에게, (나)의 선행하는 화자는 소 먹이는 '아희들'에게 말을 건네고 있어, 작품의 상황이 극 중 장면처럼 보이는 것은 적절한 설명입니다.

# %% [markdown]
# # **<테스트 결과>** 최소 8문제~최대 10문제

# %% [markdown]
# ❌ 오답 문항 수
#
# - 2025년 6월: 3개 (20, 26, 34)
#
# - 2025년 9월: 2개 (18, 27)
#
# - 2025년 수능: 4개 (20, 21, 26, 32)
#
# - 총 오답: 9문항

# %% [markdown]
# 🧾 요약
# - 총 문항 수: 51
#
# - 정답 수: 42
#
# - 오답 수: 9
#
# ### **정답률: 약 82.4%**
# - 오답 중 정답률이 50% 아래인 문제들이 많으며, 모델이 두번째로 높은 선택비율의 정답을 선택한 것이 많음. => LLM의 추론 능력 부족
# - 오답 중 대부분이 <보기>가 포함된 문제 => 보기의 조건을 지문에 정확히 적용해야 하는 문제에서 약한 경향이 있어보임
